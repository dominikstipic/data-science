# %% [markdown]
# # Assignment 2: Naive Bayes
# Welcome to week two of this specialization. You will learn about Naive Bayes. Concretely, you will be using Naive Bayes for sentiment analysis on tweets. Given a tweet, you will decide if it has a positive sentiment or a negative one. Specifically you will:
#
# * Train a naive bayes model on a sentiment analysis task
# * Test using your model
# * Compute ratios of positive words to negative words
# * Do some error analysis
# * Predict on your own tweet
#
# You may already be familiar with Naive Bayes and its justification in terms of conditional probabilities and independence.
# * In this week's lectures and assignments we used the ratio of probabilities between positive and negative sentiment.
# * This approach gives us simpler formulas for these 2-way classification tasks.
#
# ## Important Note on Submission to the AutoGrader
#
# Before submitting your assignment to the AutoGrader, please make sure you are not doing the following:
#
# 1. You have not added any _extra_ `print` statement(s) in the assignment.
# 2. You have not added any _extra_ code cell(s) in the assignment.
# 3. You have not changed any of the function parameters.
# 4. You are not using any global variables inside your graded exercises. Unless specifically instructed to do so, please refrain from it and use the local variables instead.
# 5. You are not changing the assignment code where it is not required, like creating _extra_ variables.
#
# If you do any of the following, you will get something like, `Grader Error: Grader feedback not found` (or similarly unexpected) error upon submitting your assignment. Before asking for help/debugging the errors in your assignment, check for these first. If this is the case, and you don't remember the changes you have made, you can get a fresh copy of the assignment by following these [instructions](https://www.coursera.org/learn/classification-vector-spaces-in-nlp/supplement/YLuAg/h-ow-to-refresh-your-workspace).
#
# Lets get started!
#
# Load the cell below to import some packages.
# You  may want to browse the documentation of unfamiliar libraries and functions.

# %% [markdown]
# ## Table of Contents
#
# - [Importing Functions and Data](#0)
# - [1 - Process the Data](#1)
#     - [1.1 - Implementing your Helper Functions](#1-1)
#         - [Exercise 1 - count_tweets (UNQ_C1)](#ex-1)
# - [2 - Train your Model using Naive Bayes](#2)
#     - [Exercise 2 - train_naive_bayes (UNQ_C2)](#ex-2)
# - [3 - Test your Naive Bayes](#3)
#     - [Exercise 3 - naive_bayes_predict  (UNQ_C4)](#ex-3)
#     - [Exercise 4 - test_naive_bayes (UNQ_C6)](#ex-4)
# - [4 - Filter words by Ratio of Positive to Negative Counts](#4)
#     - [Exercise 5 - get_ratio (UNQ_C8)](#ex-5)
#     - [Exercise 6 - get_words_by_threshold (UNQ_C9)](#ex-6)
# - [5 - Error Analysis](#5)
# - [6 - Predict with your own Tweet](#6)

# %% [markdown]
# <a name='0'></a>
# ## Importing Functions and Data

# %%
from utils import process_tweet, lookup
import pdb
from nltk.corpus import stopwords, twitter_samples
import numpy as np
import pandas as pd
import nltk
import string
from nltk.tokenize import TweetTokenizer
from os import getcwd
import w2_unittest

nltk.download('twitter_samples')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# If you are running this notebook in your local computer,
# don't forget to download the tweeter samples and stopwords from nltk.
#
# ```
# nltk.download('stopwords')
# nltk.download('twitter_samples')
# ```

# %%
filePath = f"{getcwd()}/../tmp2/"
nltk.data.path.append(filePath)

# %%
# get the sets of positive and negative tweets
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# split the data into two pieces, one for training and one for testing (validation set)
test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg
test_x = test_pos + test_neg

# avoid assumptions about the length of all_positive_tweets
train_y = np.append(np.ones(len(train_pos)), np.zeros(len(train_neg)))
test_y = np.append(np.ones(len(test_pos)), np.zeros(len(test_neg)))

# %% [markdown]
# <a name='1'></a>
# ## 1 - Process the Data
#
# For any machine learning project, once you've gathered the data, the first step is to process it to make useful inputs to your model.
# - **Remove noise**: You will first want to remove noise from your data -- that is, remove words that don't tell you much about the content. These include all common words like 'I, you, are, is, etc...' that would not give us enough information on the sentiment.
# - We'll also remove stock market tickers, retweet symbols, hyperlinks, and hashtags because they can not tell you a lot of information on the sentiment.
# - You also want to remove all the punctuation from a tweet. The reason for doing this is because we want to treat words with or without the punctuation as the same word, instead of treating "happy", "happy?", "happy!", "happy," and "happy." as different words.
# - Finally you want to use stemming to only keep track of one variation of each word. In other words, we'll treat "motivation", "motivated", and "motivate" similarly by grouping them within the same stem of "motiv-".
#
# We have given you the function `process_tweet` that does this for you.

# %%
custom_tweet = "RT @Twitter @chapagain Hello There! Have a great day. :) #good #morning http://chapagain.com.np"
print(process_tweet(custom_tweet))
# Out:
# ['hello', 'great', 'day', ':)', 'good', 'morn']

# %% [markdown]
# <a name='1-1'></a>
# ### 1.1 - Implementing your Helper Functions
#
# To help you train your naive bayes model, you will need to compute a dictionary where the keys are a tuple (word, label) and the values are the corresponding frequency.  Note that the labels we'll use here are 1 for positive and 0 for negative.
#
# You will also implement a lookup helper function that takes in the `freqs` dictionary, a word, and a label (1 or 0) and returns the number of times that word and label tuple appears in the collection of tweets.
#
# For example: given a list of tweets `["i am rather excited", "you are rather happy"]` and the label 1, the function will return a dictionary that contains the following key-value pairs:
#
# {
#     ("rather", 1): 2,
#     ("happi", 1) : 1,
#     ("excit", 1) : 1
# }
#
# - Notice how for each word in the given string, the same label 1 is assigned to each word.
# - Notice how the words "i" and "am" are not saved, since it was removed by process_tweet because it is a stopword.
# - Notice how the word "rather" appears twice in the list of tweets, and so its count value is 2.
#
# <a name='ex-1'></a>
# ### Exercise 1 - count_tweets
# Create a function `count_tweets` that takes a list of tweets as input, cleans all of them, and returns a dictionary.
# - The key in the dictionary is a tuple containing the stemmed word and its class label, e.g. ("happi",1).
# - The value the number of times this word appears in the given collection of tweets (an integer).

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Please use the `process_tweet` function that was imported above, and then store the words in their respective dictionaries and sets.</li>
#     <li>You may find it useful to use the `zip` function to match each element in `tweets` with each element in `ys`.</li>
#     <li>Remember to check if the key in the dictionary exists before adding that key to the dictionary, or incrementing its value.</li>
#     <li>Assume that the `result` dictionary that is input will contain clean key-value pairs (you can assume that the values will be integers that can be incremented).  It is good practice to check the datatype before incrementing the value, but it's not required here.</li>
# </ul>
# </p>

# %%
# UNQ_C1 GRADED FUNCTION: count_tweets

def count_tweets(result, tweets, ys):
    for y, tweet in zip(ys, tweets):
        for word in process_tweet(tweet):
            pair = (word, y)
            if pair in result:
                result[pair] += 1
            else:
                result[pair] = 1
    return result

# %%
# Testing your function

result = {}
tweets = ['i am happy', 'i am tricked', 'i am sad', 'i am tired', 'i am tired']
ys = [1, 0, 0, 0, 0]
count_tweets(result, tweets, ys)
# Out:
# {('happi', 1): 1, ('trick', 0): 1, ('sad', 0): 1, ('tire', 0): 2}

# %% [markdown]
# **Expected Output**: {('happi', 1): 1, ('trick', 0): 1, ('sad', 0): 1, ('tire', 0): 2}

# %%
# Test your function
w2_unittest.test_count_tweets(count_tweets)
# Out:
#  All tests passed

# %% [markdown]
# <a name='2'></a>
# ## 2 - Train your Model using Naive Bayes
#
# Naive bayes is an algorithm that could be used for sentiment analysis. It takes a short time to train and also has a short prediction time.
#
# #### So how do you train a Naive Bayes classifier?
# - The first part of training a naive bayes classifier is to identify the number of classes that you have.
# - You will create a probability for each class.
# $P(D_{pos})$ is the probability that the document is positive.
# $P(D_{neg})$ is the probability that the document is negative.
# Use the formulas as follows and store the values in a dictionary:
#
# $$P(D_{pos}) = \frac{D_{pos}}{D}\tag{1}$$
#
# $$P(D_{neg}) = \frac{D_{neg}}{D}\tag{2}$$
#
# Where $D$ is the total number of documents, or tweets in this case, $D_{pos}$ is the total number of positive tweets and $D_{neg}$ is the total number of negative tweets.

# %% [markdown]
# #### Prior and Logprior
#
# The prior probability represents the underlying probability in the target population that a tweet is positive versus negative.  In other words, if we had no specific information and blindly picked a tweet out of the population set, what is the probability that it will be positive versus that it will be negative? That is the "prior".
#
# The prior is the ratio of the probabilities $\frac{P(D_{pos})}{P(D_{neg})}$.
# We can take the log of the prior to rescale it, and we'll call this the logprior
#
# $$\text{logprior} = log \left( \frac{P(D_{pos})}{P(D_{neg})} \right) = log \left( \frac{D_{pos}}{D_{neg}} \right)$$.
#
# Note that $log(\frac{A}{B})$ is the same as $log(A) - log(B)$.  So the logprior can also be calculated as the difference between two logs:
#
# $$\text{logprior} = \log (P(D_{pos})) - \log (P(D_{neg})) = \log (D_{pos}) - \log (D_{neg})\tag{3}$$

# %% [markdown]
# #### Positive and Negative Probability of a Word
# To compute the positive probability and the negative probability for a specific word in the vocabulary, we'll use the following inputs:
#
# - $freq_{pos}$ and $freq_{neg}$ are the frequencies of that specific word in the positive or negative class. In other words, the positive frequency of a word is the number of times the word is counted with the label of 1.
# - $N_{pos}$ and $N_{neg}$ are the total number of positive and negative words for all documents (for all tweets), respectively.
# - $V$ is the number of unique words in the entire set of documents, for all classes, whether positive or negative.
#
# We'll use these to compute the positive and negative probability for a specific word using this formula:
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# Notice that we add the "+1" in the numerator for additive smoothing.  This [wiki article](https://en.wikipedia.org/wiki/Additive_smoothing) explains more about additive smoothing.

# %% [markdown]
# #### Log likelihood
# To compute the loglikelihood of that very same word, we can implement the following equations:
#
# $$\text{loglikelihood} = \log \left(\frac{P(W_{pos})}{P(W_{neg})} \right)\tag{6}$$

# %% [markdown]
# ##### Create `freqs` dictionary
# - Given your `count_tweets` function, you can compute a dictionary called `freqs` that contains all the frequencies.
# - In this `freqs` dictionary, the key is the tuple (word, label)
# - The value is the number of times it has appeared.
#
# We will use this dictionary in several parts of this assignment.

# %%
# Build the freqs dictionary for later uses
freqs = count_tweets({}, train_x, train_y)

# %% [markdown]
# <a name='ex-2'></a>
# ### Exercise 2 - train_naive_bayes
# Given a freqs dictionary, `train_x` (a list of tweets) and a `train_y` (a list of labels for each tweet), implement a naive bayes classifier.
#
# ##### Calculate $V$
# - You can then compute the number of unique words that appear in the `freqs` dictionary to get your $V$ (you can use the `set` function).
#
# ##### Calculate $freq_{pos}$ and $freq_{neg}$
# - Using your `freqs` dictionary, you can compute the positive and negative frequency of each word $freq_{pos}$ and $freq_{neg}$.
#
# ##### Calculate $N_{pos}$, and $N_{neg}$
# - Using `freqs` dictionary, you can also compute the total number of positive words and total number of negative words $N_{pos}$ and $N_{neg}$.
#
# ##### Calculate $D$, $D_{pos}$, $D_{neg}$
# - Using the `train_y` input list of labels, calculate the number of documents (tweets) $D$, as well as the number of positive documents (tweets) $D_{pos}$ and number of negative documents (tweets) $D_{neg}$.
# - Calculate the probability that a document (tweet) is positive $P(D_{pos})$, and the probability that a document (tweet) is negative $P(D_{neg})$
#
# ##### Calculate the logprior
# - the logprior is $log(D_{pos}) - log(D_{neg})$
#
# ##### Calculate log likelihood
# - Finally, you can iterate over each word in the vocabulary, use your `lookup` function to get the positive frequencies, $freq_{pos}$, and the negative frequencies, $freq_{neg}$, for that specific word.
# - Compute the positive probability of each word $P(W_{pos})$, negative probability of each word $P(W_{neg})$ using equations 4 & 5.
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# **Note:** We'll use a dictionary to store the log likelihoods for each word.  The key is the word, the value is the log likelihood of that word).
#
# - You can then compute the loglikelihood: $log \left( \frac{P(W_{pos})}{P(W_{neg})} \right)$.

# %%
# UNQ_C2 GRADED FUNCTION: train_naive_bayes

def train_naive_bayes(freqs, train_x, train_y):
    '''
    Input:
        freqs: dictionary from (word, label) to how often the word appears
        train_x: a list of tweets
        train_y: a list of labels corresponding to the tweets (0,1)
    Output:
        logprior: the log prior. (equation 3 above)
        loglikelihood: the log likelihood of you Naive bayes equation. (equation 6 above)
    '''
    loglikelihood = {}
    logprior = 0

    vocab = set([w for w, _ in freqs])
    V = len(vocab)    
    loglikelihood = {}
    N_pos = N_neg = 0
    for pair in freqs.keys():
        w, y = pair
        if pair[1] == 1:
            N_pos += freqs[w, y]
        else:
            N_neg += freqs[w, y]
        proba_plus = (N_pos + 1) / (N_pos + N_neg + V)    
        proba_neg  = (N_neg + 1)  / (N_pos + N_neg + V)    
        loglikelihood[w] = np.log(proba_plus / proba_neg)
    
    D_pos = sum(train_y)
    D_neg = len(train_y) - D_pos
    logprior = np.log(D_pos/D_neg)
    return logprior, loglikelihood

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
logprior, loglikelihood = train_naive_bayes(freqs, train_x, train_y)
print(logprior)
print(len(loglikelihood))
# Out:
# 0.0
# 9165

# %% [markdown]
# **Expected Output**:
#
# 0.0
#
# 9165

# %%
# Test your function
w2_unittest.test_train_naive_bayes(train_naive_bayes, freqs, train_x, train_y)
# Out:
# Wrong values for loglikelihood dictionary. Please check your implementation for the loglikelihood dictionary.
# Wrong values for loglikelihood dictionary. Please check your implementation for the loglikelihood dictionary.
# Wrong values for loglikelihood dictionary. Please check your implementation for the loglikelihood dictionary.
#  12  Tests passed
#  3  Tests failed

# %% [markdown]
# <a name='3'></a>
# ## 3 - Test your Naive Bayes
#
# Now that we have the `logprior` and `loglikelihood`, we can test the naive bayes function by making predicting on some tweets!
#
# <a name='ex-3'></a>
# ### Exercise 3 - naive_bayes_predict
# Implement `naive_bayes_predict`.
#
# **Instructions**:
# Implement the `naive_bayes_predict` function to make predictions on tweets.
# * The function takes in the `tweet`, `logprior`, `loglikelihood`.
# * It returns the probability that the tweet belongs to the positive or negative class.
# * For each tweet, sum up loglikelihoods of each word in the tweet.
# * Also add the logprior to this sum to get the predicted sentiment of that tweet.
#
# $$ p = logprior + \sum_i^N (loglikelihood_i)$$
#
# #### Note
# Note we calculate the prior from the training data, and that the training data is evenly split between positive and negative labels (4000 positive and 4000 negative tweets).  This means that the ratio of positive to negative 1, and the logprior is 0.
#
# The value of 0.0 means that when we add the logprior to the log likelihood, we're just adding zero to the log likelihood.  However, please remember to include the logprior, because whenever the data is not perfectly balanced, the logprior will be a non-zero value.

# %%
# UNQ_C4 GRADED FUNCTION: naive_bayes_predict

def naive_bayes_predict(tweet, logprior, loglikelihood):
    '''
    Input:
        tweet: a string
        logprior: a number
        loglikelihood: a dictionary of words mapping to numbers
    Output:
        p: the sum of all the logliklihoods of each word in the tweet (if found in the dictionary) + logprior (a number)

    '''
    word_l = process_tweet(tweet)
    p = 0
    p += logprior
    for word in word_l:
        if word in loglikelihood:
            p += loglikelihood[word]
    return p

# %%
# UNQ_C5 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
my_tweet = 'She smiled.'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is 1.7715640219920663

# %% [markdown]
# **Expected Output**:
# - The expected output is around 1.55
# - The sentiment is positive.

# %%
# Test your function
w2_unittest.test_naive_bayes_predict(naive_bayes_predict)
# Out:
#  All tests passed

# %%
# Experiment with your own tweet.
my_tweet = 'He laughed.'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print('The expected output is', p)
# Out:
# The expected output is 0.28213146332200456

# %% [markdown]
# <a name='ex-4'></a>
# ### Exercise 4 - test_naive_bayes
# Implement test_naive_bayes.
#
# **Instructions**:
# * Implement `test_naive_bayes` to check the accuracy of your predictions.
# * The function takes in your `test_x`, `test_y`, log_prior, and loglikelihood
# * It returns the accuracy of your model.
# * First, use `naive_bayes_predict` function to make predictions for each tweet in text_x.

# %%
# UNQ_C6 GRADED FUNCTION: test_naive_bayes

def test_naive_bayes(test_x, test_y, logprior, loglikelihood, naive_bayes_predict=naive_bayes_predict):
    """
    Input:
        test_x: A list of tweets
        test_y: the corresponding labels for the list of tweets
        logprior: the logprior
        loglikelihood: a dictionary with the loglikelihoods for each word
    Output:
        accuracy: (# of tweets classified correctly)/(total # of tweets)
    """
    accuracy = 0  
    y_hats = []
    for tweet in test_x:
        # if the prediction is > 0
        if naive_bayes_predict(tweet, logprior, loglikelihood) > 0:
            y_hat_i = 1
        else:
            y_hat_i = 0
        y_hats.append(y_hat_i)
    accuracy = sum(y_hats)/len(y_hats)
    return accuracy

# %%
print("Naive Bayes accuracy = %0.4f"%
      (test_naive_bayes(test_x, test_y, logprior, loglikelihood)))
# Out:
# Naive Bayes accuracy = 0.9995

# %% [markdown]
# **Expected Accuracy**:
#
# `Naive Bayes accuracy = 0.9955`

# %%
# UNQ_C7 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# Run this cell to test your function
for tweet in ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']:
    # print( '%s -> %f' % (tweet, naive_bayes_predict(tweet, logprior, loglikelihood)))
    p = naive_bayes_predict(tweet, logprior, loglikelihood)
#     print(f'{tweet} -> {p:.2f} ({p_category})')
    print(f'{tweet} -> {p:.2f}')
# Out:
# I am happy -> 1.59
# I am bad -> 0.89
# this movie should have been great. -> 1.77
# great -> 0.50
# great great -> 1.00
# great great great -> 1.50
# great great great great -> 1.99

# %% [markdown]
# **Expected Output**:
# - I am happy -> 2.14
# - I am bad -> -1.31
# - this movie should have been great. -> 2.12
# - great -> 2.13
# - great great -> 4.26
# - great great great -> 6.39
# - great great great great -> 8.52

# %%
# Feel free to check the sentiment of your own tweet below
my_tweet = 'you are bad :('
naive_bayes_predict(my_tweet, logprior, loglikelihood)
# Out:
# 2.9052010106985207

# %%
# Test your function
w2_unittest.unittest_test_naive_bayes(test_naive_bayes, test_x, test_y)
# Out:
# Wrong output value for accuracy.
# 	Expected: 0.9955.
# 	Got: 0.4995.
# Wrong output value for accuracy.
# 	Expected: 0.995.
# 	Got: 0.495.
# Wrong output value for accuracy.
# 	Expected: 0.995.
# 	Got: 0.495.
# Wrong output value for accuracy.
# 	Expected: 0.996.
# 	Got: 0.596.
# Wrong output value for accuracy.
# 	Expected: 0.996.
# 	Got: 0.596.
#  0  Tests passed
#  5  Tests failed

# %% [markdown]
# <a name='4'></a>
# ## 4 - Filter words by Ratio of Positive to Negative Counts
#
# - Some words have more positive counts than others, and can be considered "more positive".  Likewise, some words can be considered more negative than others.
# - One way for us to define the level of positiveness or negativeness, without calculating the log likelihood, is to compare the positive to negative frequency of the word.
#     - Note that we can also use the log likelihood calculations to compare relative positivity or negativity of words.
# - We can calculate the ratio of positive to negative frequencies of a word.
# - Once we're able to calculate these ratios, we can also filter a subset of words that have a minimum ratio of positivity / negativity or higher.
# - Similarly, we can also filter a subset of words that have a maximum ratio of positivity / negativity or lower (words that are at least as negative, or even more negative than a given threshold).
#
# <a name='ex-5'></a>
# ### Exercise 5 - get_ratio
# Implement get_ratio.
#
# - Given the freqs dictionary of words and a particular word, use `lookup(freqs,word,1)` to get the positive count of the word.
# - Similarly, use the `lookup` function to get the negative count of that word.
# - Calculate the ratio of positive divided by negative counts
#
# $$ ratio = \frac{\text{pos_words} + 1}{\text{neg_words} + 1} $$
#
# Where pos_words and neg_words correspond to the frequency of the words in their respective classes.
# <table>
#     <tr>
#         <td>
#             <b>Words</b>
#         </td>
#         <td>
#         Positive word count
#         </td>
#          <td>
#         Negative Word Count
#         </td>
#   </tr>
#     <tr>
#         <td>
#         glad
#         </td>
#          <td>
#         41
#         </td>
#     <td>
#         2
#         </td>
#   </tr>
#     <tr>
#         <td>
#         arriv
#         </td>
#          <td>
#         57
#         </td>
#     <td>
#         4
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :(
#         </td>
#          <td>
#         1
#         </td>
#     <td>
#         3663
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :-(
#         </td>
#          <td>
#         0
#         </td>
#     <td>
#         378
#         </td>
#   </tr>
# </table>

# %%
# UNQ_C8 GRADED FUNCTION: get_ratio

def get_ratio(freqs, word):
    '''
    Input:
        freqs: dictionary containing the words

    Output: a dictionary with keys 'positive', 'negative', and 'ratio'.
        Example: {'positive': 10, 'negative': 20, 'ratio': 0.5}
    '''
    pos_neg_ratio = {'positive': 0, 'negative': 0, 'ratio': 0.0}
    pos_neg_ratio['positive'] = freqs[word, 1] if (word, 1) in freqs else 0.0 
    pos_neg_ratio['negative'] = freqs[word, 0] if (word, 0) in freqs else 0.0
    pos_neg_ratio['ratio'] = (pos_neg_ratio['positive'] + 1) / (pos_neg_ratio['negative'] + 1)
    return pos_neg_ratio


print(get_ratio(freqs, "positive"))
print(get_ratio(freqs, "arriv"))
print(get_ratio(freqs, ":("))
print(get_ratio(freqs, ":-("))
# Out:
# {'positive': 0.0, 'negative': 0.0, 'ratio': 1.0}
# {'positive': 57, 'negative': 4, 'ratio': 11.6}
# {'positive': 1, 'negative': 3675, 'ratio': 0.000544069640914037}
# {'positive': 0.0, 'negative': 386, 'ratio': 0.002583979328165375}

# %%
# Test your function
w2_unittest.test_get_ratio(get_ratio, freqs)
# Out:
#  All tests passed

# %% [markdown]
# <a name='ex-6'></a>
# ### Exercise 6 - get_words_by_threshold
# Implement get_words_by_threshold(freqs,label,threshold)
#
# * If we set the label to 1, then we'll look for all words whose threshold of positive/negative is at least as high as that threshold, or higher.
# * If we set the label to 0, then we'll look for all words whose threshold of positive/negative is at most as low as the given threshold, or lower.
# * Use the `get_ratio` function to get a dictionary containing the positive count, negative count, and the ratio of positive to negative counts.
# * Append the `get_ratio` dictionary inside another dictinoary, where the key is the word, and the value is the dictionary `pos_neg_ratio` that is returned by the `get_ratio` function.
# An example key-value pair would have this structure:
# ```
# {'happi':
#     {'positive': 10, 'negative': 20, 'ratio': 0.524}
# }
# ```

# %%
# UNQ_C9 GRADED FUNCTION: get_words_by_threshold

def get_words_by_threshold(freqs, label, threshold, get_ratio=get_ratio):
    '''
    Input:
        freqs: dictionary of words
        label: 1 for positive, 0 for negative
        threshold: ratio that will be used as the cutoff for including a word in the returned dictionary
    Output:
        word_list: dictionary containing the word and information on its positive count, negative count, and ratio of positive to negative counts.
        example of a key value pair:
        {'happi':
            {'positive': 10, 'negative': 20, 'ratio': 0.5}
        }
    '''
    word_list = {}
    for key in freqs.keys():
        word, _ = key
        pos_neg_ratio = get_ratio(freqs, word)
        fwp = freqs[word, 1] if (word, 1) in freqs else 0
        fwn = freqs[word, 0] if (word, 0) in freqs else 0
        if label == 1 and pos_neg_ratio['ratio'] >= threshold:
            word_list[word] = get_ratio(freqs, word)
        elif label == 0 and pos_neg_ratio['ratio'] <= threshold:
            word_list[word] = get_ratio(freqs, word)
    return word_list

# %%
# Test your function: find negative words at or below a threshold
get_words_by_threshold(freqs, label=0, threshold=10000)
# Out:
# {'followfriday': {'positive': 23, 'negative': 0.0, 'ratio': 24.0},
#  'top': {'positive': 30, 'negative': 5, 'ratio': 5.166666666666667},
#  'engag': {'positive': 7, 'negative': 0.0, 'ratio': 8.0},
#  'member': {'positive': 14, 'negative': 6, 'ratio': 2.142857142857143},
#  'commun': {'positive': 27, 'negative': 1, 'ratio': 14.0},
#  'week': {'positive': 72, 'negative': 47, 'ratio': 1.5208333333333333},
#  ':)': {'positive': 2960, 'negative': 2, 'ratio': 987.0},
#  'hey': {'positive': 60, 'negative': 20, 'ratio': 2.9047619047619047},
#  'jame': {'positive': 7, 'negative': 3, 'ratio': 2.0},
#  'odd': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  ':/': {'positive': 5, 'negative': 8, 'ratio': 0.6666666666666666},
#  'pleas': {'positive': 81, 'negative': 243, 'ratio': 0.3360655737704918},
#  'call': {'positive': 27, 'negative': 22, 'ratio': 1.2173913043478262},
#  'contact': {'positive': 4, 'negative': 7, 'ratio': 0.625},
#  'centr': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  '02392441234': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'abl': {'positive': 6, 'negative': 17, 'ratio': 0.3888888888888889},
#  'assist': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'mani': {'positive': 28, 'negative': 24, 'ratio': 1.16},
#  'thank': {'positive': 522, 'negative': 94, 'ratio': 5.505263157894737},
#  'listen': {'positive': 15, 'negative': 14, 'ratio': 1.0666666666666667},
#  'last': {'positive': 39, 'negative': 52, 'ratio': 0.7547169811320755},
#  'night': {'positive': 55, 'negative': 33, 'ratio': 1.6470588235294117},
#  'bleed': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'amaz': {'positive': 41, 'negative': 12, 'ratio': 3.230769230769231},
#  'track': {'positive': 5, 'negative': 1, 'ratio': 3.0},
#  'scotland': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'congrat': {'positive': 15, 'negative': 2, 'ratio': 5.333333333333333},
#  'yeaaah': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'yipppi': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'accnt': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'verifi': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'rqst': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'succeed': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'got': {'positive': 57, 'negative': 90, 'ratio': 0.6373626373626373},
#  'blue': {'positive': 8, 'negative': 4, 'ratio': 1.8},
#  'tick': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'mark': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'fb': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'profil': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  '15': {'positive': 4, 'negative': 8, 'ratio': 0.5555555555555556},
#  'day': {'positive': 187, 'negative': 115, 'ratio': 1.6206896551724137},
#  'one': {'positive': 92, 'negative': 118, 'ratio': 0.7815126050420168},
#  'irresist': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'flipkartfashionfriday': {'positive': 16, 'negative': 0.0, 'ratio': 17.0},
#  'like': {'positive': 187, 'negative': 182, 'ratio': 1.0273224043715847},
#  'keep': {'positive': 55, 'negative': 31, 'ratio': 1.75},
#  'love': {'positive': 336, 'negative': 128, 'ratio': 2.612403100775194},
#  'custom': {'positive': 4, 'negative': 1, 'ratio': 2.5},
#  'wait': {'positive': 55, 'negative': 36, 'ratio': 1.5135135135135136},
#  'long': {'positive': 27, 'negative': 33, 'ratio': 0.8235294117647058},
#  'hope': {'positive': 115, 'negative': 91, 'ratio': 1.2608695652173914},
#  'enjoy': {'positive': 61, 'negative': 7, 'ratio': 7.75},
#  'happi': {'positive': 162, 'negative': 18, 'ratio': 8.578947368421053},
#  'friday': {'positive': 91, 'negative': 9, 'ratio': 9.2},
#  'lwwf': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'second': {'positive': 8, 'negative': 3, 'ratio': 2.25},
#  'thought': {'positive': 21, 'negative': 28, 'ratio': 0.7586206896551724},
#  '’': {'positive': 17, 'negative': 21, 'ratio': 0.8181818181818182},
#  'enough': {'positive': 16, 'negative': 18, 'ratio': 0.8947368421052632},
#  'time': {'positive': 101, 'negative': 125, 'ratio': 0.8095238095238095},
#  'dd': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'new': {'positive': 114, 'negative': 43, 'ratio': 2.6136363636363638},
#  'short': {'positive': 6, 'negative': 9, 'ratio': 0.7},
#  'enter': {'positive': 9, 'negative': 1, 'ratio': 5.0},
#  'system': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'sheep': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'must': {'positive': 14, 'negative': 12, 'ratio': 1.1538461538461537},
#  'buy': {'positive': 10, 'negative': 11, 'ratio': 0.9166666666666666},
#  'jgh': {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  'go': {'positive': 123, 'negative': 181, 'ratio': 0.6813186813186813},
#  'bayan': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  ':D': {'positive': 523, 'negative': 0.0, 'ratio': 524.0},
#  'bye': {'positive': 5, 'negative': 6, 'ratio': 0.8571428571428571},
#  'act': {'positive': 6, 'negative': 2, 'ratio': 2.3333333333333335},
#  'mischiev': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'etl': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'layer': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'in-hous': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'wareh': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'app': {'positive': 12, 'negative': 12, 'ratio': 1.0},
#  'katamari': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'well': {'positive': 66, 'negative': 49, 'ratio': 1.34},
#  '…': {'positive': 31, 'negative': 16, 'ratio': 1.8823529411764706},
#  'name': {'positive': 12, 'negative': 13, 'ratio': 0.9285714285714286},
#  'impli': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  ':p': {'positive': 104, 'negative': 0.0, 'ratio': 105.0},
#  'influenc': {'positive': 16, 'negative': 0.0, 'ratio': 17.0},
#  'big': {'positive': 28, 'negative': 17, 'ratio': 1.6111111111111112},
#  '...': {'positive': 228, 'negative': 283, 'ratio': 0.8063380281690141},
#  'juici': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'selfi': {'positive': 11, 'negative': 5, 'ratio': 2.0},
#  'follow': {'positive': 385, 'negative': 246, 'ratio': 1.562753036437247},
#  'u': {'positive': 204, 'negative': 151, 'ratio': 1.3486842105263157},
#  'back': {'positive': 139, 'negative': 98, 'ratio': 1.4141414141414141},
#  'perfect': {'positive': 17, 'negative': 2, 'ratio': 6.0},
#  'alreadi': {'positive': 19, 'negative': 41, 'ratio': 0.47619047619047616},
#  'know': {'positive': 128, 'negative': 112, 'ratio': 1.1415929203539823},
#  "what'": {'positive': 14, 'negative': 13, 'ratio': 1.0714285714285714},
#  'great': {'positive': 135, 'negative': 15, 'ratio': 8.5},
#  'opportun': {'positive': 17, 'negative': 1, 'ratio': 9.0},
#  'junior': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'triathlet': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'age': {'positive': 2, 'negative': 8, 'ratio': 0.3333333333333333},
#  '12': {'positive': 5, 'negative': 4, 'ratio': 1.2},
#  '13': {'positive': 5, 'negative': 2, 'ratio': 2.0},
#  'gatorad': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'seri': {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  'get': {'positive': 166, 'negative': 182, 'ratio': 0.912568306010929},
#  'entri': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'lay': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'greet': {'positive': 4, 'negative': 5, 'ratio': 0.8333333333333334},
#  'card': {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'rang': {'positive': 2, 'negative': 4, 'ratio': 0.6},
#  'print': {'positive': 4, 'negative': 0.0, 'ratio': 5.0},
#  'today': {'positive': 91, 'negative': 88, 'ratio': 1.0337078651685394},
#  'job': {'positive': 34, 'negative': 8, 'ratio': 3.888888888888889},
#  ':-)': {'positive': 552, 'negative': 0.0, 'ratio': 553.0},
#  "friend'": {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'lunch': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  'yummm': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'nostalgia': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'tb': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'ku': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'id': {'positive': 8, 'negative': 5, 'ratio': 1.5},
#  'conflict': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'help': {'positive': 40, 'negative': 44, 'ratio': 0.9111111111111111},
#  "here'": {'positive': 20, 'negative': 0.0, 'ratio': 21.0},
#  'screenshot': {'positive': 2, 'negative': 4, 'ratio': 0.6},
#  'work': {'positive': 89, 'negative': 102, 'ratio': 0.8737864077669902},
#  'hi': {'positive': 154, 'negative': 28, 'ratio': 5.344827586206897},
#  'liv': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'hello': {'positive': 49, 'negative': 8, 'ratio': 5.555555555555555},
#  'need': {'positive': 62, 'negative': 86, 'ratio': 0.7241379310344828},
#  'someth': {'positive': 25, 'negative': 21, 'ratio': 1.1818181818181819},
#  'fm': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'twitter': {'positive': 25, 'negative': 20, 'ratio': 1.2380952380952381},
#  '—': {'positive': 22, 'negative': 18, 'ratio': 1.2105263157894737},
#  'sure': {'positive': 38, 'negative': 26, 'ratio': 1.4444444444444444},
#  'thing': {'positive': 48, 'negative': 43, 'ratio': 1.1136363636363635},
#  'dm': {'positive': 34, 'negative': 20, 'ratio': 1.6666666666666667},
#  'x': {'positive': 50, 'negative': 35, 'ratio': 1.4166666666666667},
#  "i'v": {'positive': 25, 'negative': 64, 'ratio': 0.4},
#  'heard': {'positive': 9, 'negative': 5, 'ratio': 1.6666666666666667},
#  'four': {'positive': 5, 'negative': 3, 'ratio': 1.5},
#  'season': {'positive': 5, 'negative': 7, 'ratio': 0.75},
#  'pretti': {'positive': 17, 'negative': 12, 'ratio': 1.3846153846153846},
#  'dope': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'penthous': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'obv': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'gobigorgohom': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'fun': {'positive': 45, 'negative': 20, 'ratio': 2.1904761904761907},
#  "y'all": {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  'yeah': {'positive': 30, 'negative': 35, 'ratio': 0.8611111111111112},
#  'suppos': {'positive': 6, 'negative': 4, 'ratio': 1.4},
#  'lol': {'positive': 48, 'negative': 31, 'ratio': 1.53125},
#  'chat': {'positive': 9, 'negative': 5, 'ratio': 1.6666666666666667},
#  'bit': {'positive': 16, 'negative': 12, 'ratio': 1.3076923076923077},
#  'youth': {'positive': 14, 'negative': 0.0, 'ratio': 15.0},
#  '💅': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  '🏽': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  '💋': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'seen': {'positive': 6, 'negative': 15, 'ratio': 0.4375},
#  'year': {'positive': 33, 'negative': 37, 'ratio': 0.8947368421052632},
#  'rest': {'positive': 9, 'negative': 17, 'ratio': 0.5555555555555556},
#  'goe': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  'quickli': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'bed': {'positive': 8, 'negative': 10, 'ratio': 0.8181818181818182},
#  'music': {'positive': 15, 'negative': 12, 'ratio': 1.2307692307692308},
#  'fix': {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'dream': {'positive': 17, 'negative': 17, 'ratio': 1.0},
#  'spiritu': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'ritual': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'festiv': {'positive': 7, 'negative': 2, 'ratio': 2.6666666666666665},
#  'népal': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'begin': {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  'line-up': {'positive': 4, 'negative': 0.0, 'ratio': 5.0},
#  'left': {'positive': 10, 'negative': 22, 'ratio': 0.4782608695652174},
#  'see': {'positive': 157, 'negative': 104, 'ratio': 1.5047619047619047},
#  'sarah': {'positive': 4, 'negative': 0.0, 'ratio': 5.0},
#  'send': {'positive': 18, 'negative': 7, 'ratio': 2.375},
#  'us': {'positive': 96, 'negative': 35, 'ratio': 2.6944444444444446},
#  'email': {'positive': 22, 'negative': 10, 'ratio': 2.090909090909091},
#  'bitsy@bitdefender.com': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  "we'll": {'positive': 12, 'negative': 6, 'ratio': 1.8571428571428572},
#  'asap': {'positive': 5, 'negative': 2, 'ratio': 2.0},
#  'kik': {'positive': 16, 'negative': 55, 'ratio': 0.30357142857142855},
#  'hatessuc': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  '32429': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'kikm': {'positive': 1, 'negative': 7, 'ratio': 0.25},
#  'lgbt': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'tinder': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'nsfw': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'akua': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'cumshot': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'come': {'positive': 63, 'negative': 73, 'ratio': 0.8648648648648649},
#  'hous': {'positive': 5, 'negative': 12, 'ratio': 0.46153846153846156},
#  'nsn_supplement': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'effect': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'press': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'releas': {'positive': 11, 'negative': 5, 'ratio': 2.0},
#  'distribut': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'result': {'positive': 2, 'negative': 4, 'ratio': 0.6},
#  'link': {'positive': 14, 'negative': 9, 'ratio': 1.5},
#  'remov': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'pressreleas': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'newsdistribut': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'bam': {'positive': 44, 'negative': 0.0, 'ratio': 45.0},
#  'bestfriend': {'positive': 50, 'negative': 6, 'ratio': 7.285714285714286},
#  'lot': {'positive': 80, 'negative': 18, 'ratio': 4.2631578947368425},
#  'warsaw': {'positive': 44, 'negative': 0.0, 'ratio': 45.0},
#  '<3': {'positive': 119, 'negative': 19, 'ratio': 6.0},
#  'x46': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'everyon': {'positive': 45, 'negative': 18, 'ratio': 2.4210526315789473},
#  'watch': {'positive': 32, 'negative': 57, 'ratio': 0.5689655172413793},
#  'documentari': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'earthl': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'youtub': {'positive': 8, 'negative': 4, 'ratio': 1.8},
#  'support': {'positive': 25, 'negative': 24, 'ratio': 1.04},
#  'buuut': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'oh': {'positive': 44, 'negative': 78, 'ratio': 0.569620253164557},
#  'look': {'positive': 111, 'negative': 79, 'ratio': 1.4},
#  'forward': {'positive': 20, 'negative': 5, 'ratio': 3.5},
#  'visit': {'positive': 25, 'negative': 10, 'ratio': 2.3636363636363638},
#  'next': {'positive': 37, 'negative': 31, 'ratio': 1.1875},
#  'letsgetmessi': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'jo': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'make': {'positive': 70, 'negative': 90, 'ratio': 0.7802197802197802},
#  'feel': {'positive': 33, 'negative': 131, 'ratio': 0.25757575757575757},
#  'better': {'positive': 40, 'negative': 31, 'ratio': 1.28125},
#  'never': {'positive': 31, 'negative': 42, 'ratio': 0.7441860465116279},
#  'anyon': {'positive': 7, 'negative': 14, 'ratio': 0.5333333333333333},
#  'kpop': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'flesh': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'good': {'positive': 191, 'negative': 83, 'ratio': 2.2857142857142856},
#  'girl': {'positive': 34, 'negative': 17, 'ratio': 1.9444444444444444},
#  'best': {'positive': 49, 'negative': 16, 'ratio': 2.9411764705882355},
#  'wish': {'positive': 29, 'negative': 63, 'ratio': 0.46875},
#  'reason': {'positive': 10, 'negative': 3, 'ratio': 2.75},
#  'epic': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'soundtrack': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'shout': {'positive': 11, 'negative': 0.0, 'ratio': 12.0},
#  'ad': {'positive': 10, 'negative': 1, 'ratio': 5.5},
#  'video': {'positive': 30, 'negative': 20, 'ratio': 1.4761904761904763},
#  'playlist': {'positive': 5, 'negative': 2, 'ratio': 2.0},
#  'im': {'positive': 41, 'negative': 108, 'ratio': 0.3853211009174312},
#  'twitch': {'positive': 7, 'negative': 0.0, 'ratio': 8.0},
#  'leagu': {'positive': 6, 'negative': 1, 'ratio': 3.5},
#  '1': {'positive': 63, 'negative': 19, 'ratio': 3.2},
#  '4': {'positive': 23, 'negative': 16, 'ratio': 1.411764705882353},
#  'would': {'positive': 70, 'negative': 54, 'ratio': 1.290909090909091},
#  'dear': {'positive': 15, 'negative': 11, 'ratio': 1.3333333333333333},
#  'jordan': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'okay': {'positive': 31, 'negative': 29, 'ratio': 1.0666666666666667},
#  'fake': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'gameplay': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  ';)': {'positive': 22, 'negative': 0.0, 'ratio': 23.0},
#  'haha': {'positive': 44, 'negative': 24, 'ratio': 1.8},
#  'kid': {'positive': 13, 'negative': 16, 'ratio': 0.8235294117647058},
#  'stuff': {'positive': 11, 'negative': 8, 'ratio': 1.3333333333333333},
#  'exactli': {'positive': 5, 'negative': 5, 'ratio': 1.0},
#  'product': {'positive': 11, 'negative': 3, 'ratio': 3.0},
#  'line': {'positive': 6, 'negative': 7, 'ratio': 0.875},
#  'etsi': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'shop': {'positive': 12, 'negative': 8, 'ratio': 1.4444444444444444},
#  'check': {'positive': 39, 'negative': 16, 'ratio': 2.3529411764705883},
#  'boxroomcraft': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'vacat': {'positive': 5, 'negative': 2, 'ratio': 2.0},
#  'recharg': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'normal': {'positive': 5, 'negative': 5, 'ratio': 1.0},
#  'charger': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'asleep': {'positive': 7, 'negative': 17, 'ratio': 0.4444444444444444},
#  'talk': {'positive': 38, 'negative': 41, 'ratio': 0.9285714285714286},
#  'sooo': {'positive': 6, 'negative': 12, 'ratio': 0.5384615384615384},
#  'someon': {'positive': 29, 'negative': 39, 'ratio': 0.75},
#  'text': {'positive': 12, 'negative': 13, 'ratio': 0.9285714285714286},
#  'ye': {'positive': 60, 'negative': 39, 'ratio': 1.525},
#  'bet': {'positive': 6, 'negative': 8, 'ratio': 0.7777777777777778},
#  "he'll": {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'fit': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'hear': {'positive': 24, 'negative': 26, 'ratio': 0.9259259259259259},
#  'speech': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'piti': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'green': {'positive': 2, 'negative': 7, 'ratio': 0.375},
#  'garden': {'positive': 5, 'negative': 2, 'ratio': 2.0},
#  'midnight': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'sun': {'positive': 6, 'negative': 8, 'ratio': 0.7777777777777778},
#  'beauti': {'positive': 45, 'negative': 10, 'ratio': 4.181818181818182},
#  'canal': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'dasvidaniya': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'till': {'positive': 16, 'negative': 6, 'ratio': 2.4285714285714284},
#  'scout': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'sg': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'futur': {'positive': 9, 'negative': 4, 'ratio': 2.0},
#  'wlan': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'pro': {'positive': 4, 'negative': 0.0, 'ratio': 5.0},
#  'confer': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'asia': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'chang': {'positive': 20, 'negative': 23, 'ratio': 0.875},
#  'lollipop': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  '🍭': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'nez': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'agnezmo': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'oley': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'mama': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'stand': {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'stronger': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'god': {'positive': 14, 'negative': 13, 'ratio': 1.0714285714285714},
#  'misti': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'babi': {'positive': 17, 'negative': 37, 'ratio': 0.47368421052631576},
#  'cute': {'positive': 22, 'negative': 37, 'ratio': 0.6052631578947368},
#  'woohoo': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  "can't": {'positive': 31, 'negative': 148, 'ratio': 0.21476510067114093},
#  'sign': {'positive': 9, 'negative': 8, 'ratio': 1.1111111111111112},
#  'yet': {'positive': 12, 'negative': 30, 'ratio': 0.41935483870967744},
#  'still': {'positive': 37, 'negative': 104, 'ratio': 0.3619047619047619},
#  'think': {'positive': 54, 'negative': 64, 'ratio': 0.8461538461538461},
#  'mka': {'positive': 5, 'negative': 0.0, 'ratio': 6.0},
#  'liam': {'positive': 5, 'negative': 1, 'ratio': 3.0},
#  'access': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'welcom': {'positive': 54, 'negative': 5, 'ratio': 9.166666666666666},
#  'stat': {'positive': 51, 'negative': 0.0, 'ratio': 52.0},
#  'arriv': {'positive': 57, 'negative': 4, 'ratio': 11.6},
#  'unfollow': {'positive': 53, 'negative': 8, 'ratio': 6.0},
#  'via': {'positive': 73, 'negative': 8, 'ratio': 8.222222222222221},
#  'surpris': {'positive': 10, 'negative': 5, 'ratio': 1.8333333333333333},
#  'figur': {'positive': 5, 'negative': 5, 'ratio': 1.0},
#  'happybirthdayemilybett': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'sweet': {'positive': 16, 'negative': 5, 'ratio': 2.8333333333333335},
#  'talent': {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  '2': {'positive': 41, 'negative': 34, 'ratio': 1.2},
#  'plan': {'positive': 21, 'negative': 13, 'ratio': 1.5714285714285714},
#  'drain': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'gotta': {'positive': 4, 'negative': 7, 'ratio': 0.625},
#  'timezon': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'parent': {'positive': 4, 'negative': 7, 'ratio': 0.625},
#  'proud': {'positive': 11, 'negative': 8, 'ratio': 1.3333333333333333},
#  'least': {'positive': 14, 'negative': 13, 'ratio': 1.0714285714285714},
#  'mayb': {'positive': 17, 'negative': 19, 'ratio': 0.9},
#  'sometim': {'positive': 11, 'negative': 15, 'ratio': 0.75},
#  'grade': {'positive': 4, 'negative': 1, 'ratio': 2.5},
#  'al': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'grand': {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  'manila_bro': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'chosen': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'let': {'positive': 70, 'negative': 33, 'ratio': 2.088235294117647},
#  'around': {'positive': 14, 'negative': 17, 'ratio': 0.8333333333333334},
#  '..': {'positive': 100, 'negative': 89, 'ratio': 1.1222222222222222},
#  'side': {'positive': 13, 'negative': 6, 'ratio': 2.0},
#  'world': {'positive': 23, 'negative': 15, 'ratio': 1.5},
#  'eh': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'take': {'positive': 30, 'negative': 37, 'ratio': 0.8157894736842105},
#  'care': {'positive': 12, 'negative': 13, 'ratio': 0.9285714285714286},
#  'final': {'positive': 24, 'negative': 32, 'ratio': 0.7575757575757576},
#  'fuck': {'positive': 20, 'negative': 47, 'ratio': 0.4375},
#  'weekend': {'positive': 61, 'negative': 21, 'ratio': 2.8181818181818183},
#  'real': {'positive': 18, 'negative': 17, 'ratio': 1.0555555555555556},
#  'x45': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'join': {'positive': 21, 'negative': 4, 'ratio': 4.4},
#  'hushedcallwithfraydo': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'gift': {'positive': 7, 'negative': 9, 'ratio': 0.8},
#  'yeahhh': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'hushedpinwithsammi': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'event': {'positive': 8, 'negative': 2, 'ratio': 3.0},
#  'might': {'positive': 21, 'negative': 10, 'ratio': 2.0},
#  'luv': {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  'realli': {'positive': 66, 'negative': 105, 'ratio': 0.6320754716981132},
#  'appreci': {'positive': 28, 'negative': 2, 'ratio': 9.666666666666666},
#  'share': {'positive': 41, 'negative': 8, 'ratio': 4.666666666666667},
#  'wow': {'positive': 14, 'negative': 4, 'ratio': 3.0},
#  'tom': {'positive': 6, 'negative': 3, 'ratio': 1.75},
#  '3': {'positive': 28, 'negative': 31, 'ratio': 0.90625},
#  'gym': {'positive': 3, 'negative': 5, 'ratio': 0.6666666666666666},
#  'monday': {'positive': 7, 'negative': 7, 'ratio': 1.0},
#  'invit': {'positive': 15, 'negative': 1, 'ratio': 8.0},
#  'scope': {'positive': 5, 'negative': 0.0, 'ratio': 6.0},
#  'friend': {'positive': 43, 'negative': 30, 'ratio': 1.4193548387096775},
#  'nude': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'sleep': {'positive': 35, 'negative': 71, 'ratio': 0.5},
#  'birthday': {'positive': 53, 'negative': 16, 'ratio': 3.176470588235294},
#  'want': {'positive': 71, 'negative': 185, 'ratio': 0.3870967741935484},
#  't-shirt': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'cool': {'positive': 29, 'negative': 4, 'ratio': 6.0},
#  'haw': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'phela': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'mom': {'positive': 7, 'negative': 10, 'ratio': 0.7272727272727273},
#  'obvious': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'princ': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'charm': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'stage': {'positive': 2, 'negative': 12, 'ratio': 0.23076923076923078},
#  'luck': {'positive': 26, 'negative': 5, 'ratio': 4.5},
#  'tyler': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'hipster': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'glass': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'marti': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'glad': {'positive': 41, 'negative': 2, 'ratio': 14.0},
#  'done': {'positive': 40, 'negative': 18, 'ratio': 2.1578947368421053},
#  'afternoon': {'positive': 7, 'negative': 2, 'ratio': 2.6666666666666665},
#  'read': {'positive': 28, 'negative': 15, 'ratio': 1.8125},
#  'kahfi': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'finish': {'positive': 15, 'negative': 10, 'ratio': 1.4545454545454546},
#  'ohmyg': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'yaya': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'dub': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'stalk': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'ig': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'gondooo': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'moo': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'tologooo': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'becom': {'positive': 8, 'negative': 4, 'ratio': 1.8},
#  'detail': {'positive': 8, 'negative': 3, 'ratio': 2.25},
#  'zzz': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'xx': {'positive': 33, 'negative': 15, 'ratio': 2.125},
#  'physiotherapi': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'hashtag': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  '💪': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'monica': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'miss': {'positive': 17, 'negative': 239, 'ratio': 0.075},
#  'sound': {'positive': 20, 'negative': 16, 'ratio': 1.2352941176470589},
#  'morn': {'positive': 68, 'negative': 23, 'ratio': 2.875},
#  "that'": {'positive': 49, 'negative': 46, 'ratio': 1.0638297872340425},
#  'x43': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'definit': {'positive': 20, 'negative': 2, 'ratio': 7.0},
#  'tri': {'positive': 34, 'negative': 58, 'ratio': 0.5932203389830508},
#  'tonight': {'positive': 15, 'negative': 20, 'ratio': 0.7619047619047619},
#  'took': {'positive': 7, 'negative': 7, 'ratio': 1.0},
#  'advic': {'positive': 6, 'negative': 0.0, 'ratio': 7.0},
#  'treviso': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'concert': {'positive': 23, 'negative': 9, 'ratio': 2.4},
#  'citi': {'positive': 26, 'negative': 11, 'ratio': 2.25},
#  'countri': {'positive': 22, 'negative': 6, 'ratio': 3.2857142857142856},
#  "i'll": {'positive': 74, 'negative': 36, 'ratio': 2.027027027027027},
#  'start': {'positive': 56, 'negative': 37, 'ratio': 1.5},
#  'fine': {'positive': 7, 'negative': 6, 'ratio': 1.1428571428571428},
#  'gorgeou': {'positive': 9, 'negative': 1, 'ratio': 5.0},
#  'xo': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'oven': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'roast': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'garlic': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'oliv': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'oil': {'positive': 4, 'negative': 1, 'ratio': 2.5},
#  'dri': {'positive': 4, 'negative': 1, 'ratio': 2.5},
#  'tomato': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'basil': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'centuri': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'tuna': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'right': {'positive': 38, 'negative': 41, 'ratio': 0.9285714285714286},
#  'atchya': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'even': {'positive': 26, 'negative': 52, 'ratio': 0.5094339622641509},
#  'almost': {'positive': 8, 'negative': 7, 'ratio': 1.125},
#  'chanc': {'positive': 3, 'negative': 14, 'ratio': 0.26666666666666666},
#  'cheer': {'positive': 18, 'negative': 3, 'ratio': 4.75},
#  'po': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'ice': {'positive': 6, 'negative': 29, 'ratio': 0.23333333333333334},
#  'cream': {'positive': 6, 'negative': 27, 'ratio': 0.25},
#  'agre': {'positive': 13, 'negative': 4, 'ratio': 2.8},
#  '100': {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'heheheh': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'that': {'positive': 10, 'negative': 9, 'ratio': 1.1},
#  'point': {'positive': 11, 'negative': 9, 'ratio': 1.2},
#  'stay': {'positive': 21, 'negative': 21, 'ratio': 1.0},
#  'home': {'positive': 20, 'negative': 52, 'ratio': 0.39622641509433965},
#  'soon': {'positive': 38, 'negative': 41, 'ratio': 0.9285714285714286},
#  'promis': {'positive': 4, 'negative': 3, 'ratio': 1.25},
#  'web': {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  'whatsapp': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'volta': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'funcionar': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'com': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'iphon': {'positive': 7, 'negative': 4, 'ratio': 1.6},
#  'jailbroken': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'later': {'positive': 12, 'negative': 10, 'ratio': 1.1818181818181819},
#  '34': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'min': {'positive': 7, 'negative': 5, 'ratio': 1.3333333333333333},
#  'leia': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'appear': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'hologram': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'r2d2': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'w': {'positive': 16, 'negative': 16, 'ratio': 1.0},
#  'messag': {'positive': 9, 'negative': 8, 'ratio': 1.1111111111111112},
#  'obi': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'wan': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'sit': {'positive': 7, 'negative': 5, 'ratio': 1.3333333333333333},
#  'luke': {'positive': 4, 'negative': 5, 'ratio': 0.8333333333333334},
#  'inter': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'ucl': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'arsen': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'small': {'positive': 2, 'negative': 8, 'ratio': 0.3333333333333333},
#  'team': {'positive': 24, 'negative': 13, 'ratio': 1.7857142857142858},
#  'pass': {'positive': 10, 'negative': 12, 'ratio': 0.8461538461538461},
#  '🚂': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'dewsburi': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'railway': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'station': {'positive': 4, 'negative': 3, 'ratio': 1.25},
#  'dew': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'west': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'yorkshir': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  '430': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'smh': {'positive': 2, 'negative': 4, 'ratio': 0.6},
#  '9:25': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'live': {'positive': 23, 'negative': 33, 'ratio': 0.7058823529411765},
#  'strang': {'positive': 4, 'negative': 0.0, 'ratio': 5.0},
#  'imagin': {'positive': 5, 'negative': 1, 'ratio': 3.0},
#  'megan': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'masaantoday': {'positive': 4, 'negative': 0.0, 'ratio': 5.0},
#  'a4': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'shweta': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'tripathi': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  '5': {'positive': 15, 'negative': 11, 'ratio': 1.3333333333333333},
#  '20': {'positive': 5, 'negative': 7, 'ratio': 0.75},
#  'kurta': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'half': {'positive': 6, 'negative': 9, 'ratio': 0.7},
#  'number': {'positive': 11, 'negative': 5, 'ratio': 2.0},
#  'wsalelov': {'positive': 14, 'negative': 5, 'ratio': 2.5},
#  'ah': {'positive': 12, 'negative': 15, 'ratio': 0.8125},
#  'larri': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'anyway': {'positive': 14, 'negative': 10, 'ratio': 1.3636363636363635},
#  'kinda': {'positive': 12, 'negative': 9, 'ratio': 1.3},
#  'goood': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'life': {'positive': 36, 'negative': 29, 'ratio': 1.2333333333333334},
#  'enn': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'could': {'positive': 25, 'negative': 51, 'ratio': 0.5},
#  'warmup': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  '15th': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'bath': {'positive': 6, 'negative': 0.0, 'ratio': 7.0},
#  'dum': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'andar': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'ram': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'sampath': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'sona': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'mohapatra': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'samantha': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'edward': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'mein': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'tulan': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'razi': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'wah': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'josh': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'alway': {'positive': 48, 'negative': 48, 'ratio': 1.0},
#  'smile': {'positive': 47, 'negative': 9, 'ratio': 4.8},
#  'pictur': {'positive': 7, 'negative': 14, 'ratio': 0.5333333333333333},
#  '16.20': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'giveitup': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'given': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'ga': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'subsidi': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'initi': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'propos': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'delight': {'positive': 4, 'negative': 1, 'ratio': 2.5},
#  'yesterday': {'positive': 4, 'negative': 9, 'ratio': 0.5},
#  'x42': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'lmaoo': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'song': {'positive': 16, 'negative': 25, 'ratio': 0.6538461538461539},
#  'ever': {'positive': 19, 'negative': 25, 'ratio': 0.7692307692307693},
#  'shall': {'positive': 5, 'negative': 1, 'ratio': 3.0},
#  'littl': {'positive': 29, 'negative': 17, 'ratio': 1.6666666666666667},
#  'throwback': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'outli': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'island': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'cheung': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'chau': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'mui': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'wo': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'total': {'positive': 6, 'negative': 9, 'ratio': 0.7},
#  'differ': {'positive': 10, 'negative': 9, 'ratio': 1.1},
#  'kfckitchentour': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'kitchen': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'clean': {'positive': 1, 'negative': 6, 'ratio': 0.2857142857142857},
#  "i'm": {'positive': 140, 'negative': 266, 'ratio': 0.5280898876404494},
#  'cusp': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'test': {'positive': 7, 'negative': 6, 'ratio': 1.1428571428571428},
#  'water': {'positive': 7, 'negative': 8, 'ratio': 0.8888888888888888},
#  'reward': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'arummzz': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  "let'": {'positive': 20, 'negative': 2, 'ratio': 7.0},
#  'drive': {'positive': 9, 'negative': 13, 'ratio': 0.7142857142857143},
#  'travel': {'positive': 19, 'negative': 9, 'ratio': 2.0},
#  'yogyakarta': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'jeep': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'indonesia': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'instamood': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'wanna': {'positive': 23, 'negative': 76, 'ratio': 0.3116883116883117},
#  'skype': {'positive': 3, 'negative': 6, 'ratio': 0.5714285714285714},
#  'may': {'positive': 16, 'negative': 15, 'ratio': 1.0625},
#  'nice': {'positive': 71, 'negative': 17, 'ratio': 4.0},
#  'friendli': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'pretend': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'film': {'positive': 8, 'negative': 2, 'ratio': 3.0},
#  'congratul': {'positive': 9, 'negative': 2, 'ratio': 3.3333333333333335},
#  'winner': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'cheesydelight': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'contest': {'positive': 5, 'negative': 0.0, 'ratio': 6.0},
#  'address': {'positive': 8, 'negative': 3, 'ratio': 2.25},
#  'guy': {'positive': 48, 'negative': 45, 'ratio': 1.065217391304348},
#  'market': {'positive': 5, 'negative': 2, 'ratio': 2.0},
#  '24/7': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'regret': {'positive': 4, 'negative': 3, 'ratio': 1.25},
#  '14': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'hour': {'positive': 24, 'negative': 26, 'ratio': 0.9259259259259259},
#  'leav': {'positive': 12, 'negative': 31, 'ratio': 0.40625},
#  'without': {'positive': 9, 'negative': 20, 'ratio': 0.47619047619047616},
#  'delay': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'actual': {'positive': 13, 'negative': 20, 'ratio': 0.6666666666666666},
#  'easi': {'positive': 7, 'negative': 5, 'ratio': 1.3333333333333333},
#  'guess': {'positive': 8, 'negative': 13, 'ratio': 0.6428571428571429},
#  'train': {'positive': 7, 'negative': 10, 'ratio': 0.7272727272727273},
#  'wd': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'shift': {'positive': 4, 'negative': 5, 'ratio': 0.8333333333333334},
#  'engin': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'etc': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'sunburn': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'peel': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'blog': {'positive': 27, 'negative': 0.0, 'ratio': 28.0},
#  'huge': {'positive': 9, 'negative': 2, 'ratio': 3.3333333333333335},
#  'warm': {'positive': 4, 'negative': 3, 'ratio': 1.25},
#  '☆': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'complet': {'positive': 10, 'negative': 6, 'ratio': 1.5714285714285714},
#  'triangl': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'northern': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'ireland': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'sight': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'smthng': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'fr': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'hug': {'positive': 11, 'negative': 21, 'ratio': 0.5454545454545454},
#  'xoxo': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'uu': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'jaann': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'topnewfollow': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'connect': {'positive': 13, 'negative': 2, 'ratio': 4.666666666666667},
#  'wonder': {'positive': 26, 'negative': 9, 'ratio': 2.7},
#  'made': {'positive': 38, 'negative': 21, 'ratio': 1.7727272727272727},
#  'fluffi': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'insid': {'positive': 7, 'negative': 9, 'ratio': 0.8},
#  'pirouett': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'moos': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'trip': {'positive': 12, 'negative': 11, 'ratio': 1.0833333333333333},
#  'philli': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'decemb': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  "i'd": {'positive': 13, 'negative': 10, 'ratio': 1.2727272727272727},
#  'dude': {'positive': 6, 'negative': 10, 'ratio': 0.6363636363636364},
#  'x41': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'question': {'positive': 15, 'negative': 5, 'ratio': 2.6666666666666665},
#  'flaw': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'pain': {'positive': 8, 'negative': 17, 'ratio': 0.5},
#  'negat': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'strength': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'went': {'positive': 10, 'negative': 27, 'ratio': 0.39285714285714285},
#  'solo': {'positive': 4, 'negative': 6, 'ratio': 0.7142857142857143},
#  'move': {'positive': 9, 'negative': 11, 'ratio': 0.8333333333333334},
#  'fav': {'positive': 11, 'negative': 0.0, 'ratio': 12.0},
#  'nirvana': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'smell': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'teen': {'positive': 3, 'negative': 5, 'ratio': 0.6666666666666666},
#  'spirit': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'rip': {'positive': 3, 'negative': 8, 'ratio': 0.4444444444444444},
#  'ami': {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  'winehous': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'coupl': {'positive': 5, 'negative': 2, 'ratio': 2.0},
#  'tomhiddleston': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'elizabetholsen': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'yaytheylookgreat': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'goodnight': {'positive': 18, 'negative': 1, 'ratio': 9.5},
#  'vid': {'positive': 8, 'negative': 0.0, 'ratio': 9.0},
#  'wake': {'positive': 10, 'negative': 18, 'ratio': 0.5789473684210527},
#  'gonna': {'positive': 16, 'negative': 44, 'ratio': 0.37777777777777777},
#  'shoot': {'positive': 5, 'negative': 6, 'ratio': 0.8571428571428571},
#  'itti': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'bitti': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'teeni': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'bikini': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'much': {'positive': 73, 'negative': 116, 'ratio': 0.6324786324786325},
#  '4th': {'positive': 4, 'negative': 1, 'ratio': 2.5},
#  'togeth': {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'end': {'positive': 13, 'negative': 36, 'ratio': 0.3783783783783784},
#  'xfile': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'content': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'rain': {'positive': 18, 'negative': 36, 'ratio': 0.5135135135135135},
#  'fabul': {'positive': 4, 'negative': 0.0, 'ratio': 5.0},
#  'fantast': {'positive': 9, 'negative': 0.0, 'ratio': 10.0},
#  '♡': {'positive': 12, 'negative': 8, 'ratio': 1.4444444444444444},
#  'jb': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'forev': {'positive': 5, 'negative': 7, 'ratio': 0.75},
#  'belieb': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'nighti': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'bug': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'bite': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'bracelet': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'idea': {'positive': 24, 'negative': 8, 'ratio': 2.7777777777777777},
#  'foundri': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'game': {'positive': 23, 'negative': 25, 'ratio': 0.9230769230769231},
#  'sens': {'positive': 6, 'negative': 0.0, 'ratio': 7.0},
#  'pic': {'positive': 21, 'negative': 14, 'ratio': 1.4666666666666666},
#  'ef': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'phone': {'positive': 16, 'negative': 26, 'ratio': 0.6296296296296297},
#  'woot': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'derek': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'use': {'positive': 32, 'negative': 31, 'ratio': 1.03125},
#  'parkshar': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'gloucestershir': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'aaaahhh': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'man': {'positive': 16, 'negative': 24, 'ratio': 0.68},
#  'traffic': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'stress': {'positive': 4, 'negative': 9, 'ratio': 0.5},
#  'reliev': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  "how'r": {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'arbeloa': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'turn': {'positive': 14, 'negative': 13, 'ratio': 1.0714285714285714},
#  '17': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'omg': {'positive': 13, 'negative': 48, 'ratio': 0.2857142857142857},
#  'say': {'positive': 43, 'negative': 47, 'ratio': 0.9166666666666666},
#  'europ': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'rise': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'find': {'positive': 22, 'negative': 45, 'ratio': 0.5},
#  'hard': {'positive': 9, 'negative': 30, 'ratio': 0.3225806451612903},
#  'believ': {'positive': 7, 'negative': 11, 'ratio': 0.6666666666666666},
#  'uncount': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'coz': {'positive': 2, 'negative': 3, 'ratio': 0.75},
#  'unlimit': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'cours': {'positive': 11, 'negative': 7, 'ratio': 1.5},
#  'teamposit': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'aldub': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  '☕': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'rita': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'info': {'positive': 11, 'negative': 1, 'ratio': 6.0},
#  "we'd": {'positive': 4, 'negative': 0.0, 'ratio': 5.0},
#  'way': {'positive': 34, 'negative': 31, 'ratio': 1.09375},
#  'boy': {'positive': 13, 'negative': 10, 'ratio': 1.2727272727272727},
#  'x40': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'true': {'positive': 19, 'negative': 19, 'ratio': 1.0},
#  'sethi': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'high': {'positive': 6, 'negative': 8, 'ratio': 0.7777777777777778},
#  'exe': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'skeem': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'saam': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'peopl': {'positive': 43, 'negative': 57, 'ratio': 0.7586206896551724},
#  'polit': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'izzat': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'wese': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'trust': {'positive': 7, 'negative': 1, 'ratio': 4.0},
#  'khawateen': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'k': {'positive': 8, 'negative': 8, 'ratio': 1.0},
#  'sath': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'mana': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'kar': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'deya': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'sort': {'positive': 7, 'negative': 6, 'ratio': 1.1428571428571428},
#  'smart': {'positive': 5, 'negative': 1, 'ratio': 3.0},
#  'hair': {'positive': 7, 'negative': 16, 'ratio': 0.47058823529411764},
#  'tbh': {'positive': 5, 'negative': 12, 'ratio': 0.46153846153846156},
#  'jacob': {'positive': 2, 'negative': 4, 'ratio': 0.6},
#  'g': {'positive': 8, 'negative': 7, 'ratio': 1.125},
#  'upgrad': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'tee': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'famili': {'positive': 14, 'negative': 9, 'ratio': 1.5},
#  'person': {'positive': 14, 'negative': 14, 'ratio': 1.0},
#  'two': {'positive': 15, 'negative': 13, 'ratio': 1.1428571428571428},
#  'convers': {'positive': 6, 'negative': 6, 'ratio': 1.0},
#  'onlin': {'positive': 4, 'negative': 13, 'ratio': 0.35714285714285715},
#  'mclaren': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'fridayfeel': {'positive': 5, 'negative': 1, 'ratio': 3.0},
#  'tgif': {'positive': 8, 'negative': 1, 'ratio': 4.5},
#  'squar': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'enix': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'bissmillah': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'ya': {'positive': 19, 'negative': 11, 'ratio': 1.6666666666666667},
#  'allah': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  "we'r": {'positive': 26, 'negative': 20, 'ratio': 1.2857142857142858},
#  'socent': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'startup': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'drop': {'positive': 9, 'negative': 6, 'ratio': 1.4285714285714286},
#  'your': {'positive': 3, 'negative': 5, 'ratio': 0.6666666666666666},
#  'arnd': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'town': {'positive': 3, 'negative': 11, 'ratio': 0.3333333333333333},
#  'basic': {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  'piss': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'cup': {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  'also': {'positive': 29, 'negative': 17, 'ratio': 1.6666666666666667},
#  'terribl': {'positive': 2, 'negative': 11, 'ratio': 0.25},
#  'complic': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'discuss': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'snapchat': {'positive': 31, 'negative': 64, 'ratio': 0.49230769230769234},
#  'lynettelow': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'kikmenow': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'snapm': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'hot': {'positive': 20, 'negative': 9, 'ratio': 2.1},
#  'amazon': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'kikmeguy': {'positive': 2, 'negative': 5, 'ratio': 0.5},
#  'defin': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'grow': {'positive': 6, 'negative': 3, 'ratio': 1.75},
#  'sport': {'positive': 4, 'negative': 0.0, 'ratio': 5.0},
#  'rt': {'positive': 9, 'negative': 5, 'ratio': 1.6666666666666667},
#  'rakyat': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'write': {'positive': 11, 'negative': 8, 'ratio': 1.3333333333333333},
#  'sinc': {'positive': 11, 'negative': 33, 'ratio': 0.35294117647058826},
#  'mention': {'positive': 18, 'negative': 6, 'ratio': 2.7142857142857144},
#  'fli': {'positive': 5, 'negative': 8, 'ratio': 0.6666666666666666},
#  'fish': {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  'promot': {'positive': 3, 'negative': 3, 'ratio': 1.0},
#  'post': {'positive': 16, 'negative': 9, 'ratio': 1.7},
#  'cyber': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'ourdaughtersourprid': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'mypapamyprid': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'papa': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'coach': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'posit': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'kha': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'atleast': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'x39': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'mango': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  "lassi'": {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  "monty'": {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'marvel': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'though': {'positive': 16, 'negative': 44, 'ratio': 0.37777777777777777},
#  'suspect': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'meant': {'positive': 2, 'negative': 4, 'ratio': 0.6},
#  '24': {'positive': 3, 'negative': 9, 'ratio': 0.4},
#  'hr': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'touch': {'positive': 7, 'negative': 5, 'ratio': 1.3333333333333333},
#  'kepler': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  '452b': {'positive': 4, 'negative': 0.0, 'ratio': 5.0},
#  'chalna': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'hai': {'positive': 7, 'negative': 8, 'ratio': 0.8888888888888888},
#  'thankyou': {'positive': 12, 'negative': 2, 'ratio': 4.333333333333333},
#  'hazel': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'food': {'positive': 10, 'negative': 12, 'ratio': 0.8461538461538461},
#  'brooklyn': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'pta': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'awak': {'positive': 8, 'negative': 8, 'ratio': 1.0},
#  'okayi': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'awww': {'positive': 12, 'negative': 19, 'ratio': 0.65},
#  'ha': {'positive': 18, 'negative': 6, 'ratio': 2.7142857142857144},
#  'doc': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'splendid': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'spam': {'positive': 1, 'negative': 5, 'ratio': 0.3333333333333333},
#  'folder': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'amount': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'nigeria': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'claim': {'positive': 1, 'negative': 3, 'ratio': 0.5},
#  'rted': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'leg': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'hurt': {'positive': 4, 'negative': 33, 'ratio': 0.14705882352941177},
#  'bad': {'positive': 14, 'negative': 54, 'ratio': 0.2727272727272727},
#  'mine': {'positive': 11, 'negative': 10, 'ratio': 1.0909090909090908},
#  'saturday': {'positive': 5, 'negative': 10, 'ratio': 0.5454545454545454},
#  'thaaank': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'puhon': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'happinesss': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'tnc': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'prior': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'notif': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'probabl': {'positive': 8, 'negative': 6, 'ratio': 1.2857142857142858},
#  'funni': {'positive': 16, 'negative': 4, 'ratio': 3.4},
#  '2:22': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'fat': {'positive': 1, 'negative': 4, 'ratio': 0.4},
#  'co': {'positive': 1, 'negative': 6, 'ratio': 0.2857142857142857},
#  'ate': {'positive': 4, 'negative': 10, 'ratio': 0.45454545454545453},
#  'yuna': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'tamesid': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  '´': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'googl': {'positive': 5, 'negative': 5, 'ratio': 1.0},
#  'account': {'positive': 17, 'negative': 17, 'ratio': 1.0},
#  'scouser': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'everyth': {'positive': 10, 'negative': 14, 'ratio': 0.7333333333333333},
#  'zoe': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'mate': {'positive': 5, 'negative': 2, 'ratio': 2.0},
#  'liter': {'positive': 6, 'negative': 13, 'ratio': 0.5},
#  "they'r": {'positive': 10, 'negative': 13, 'ratio': 0.7857142857142857},
#  'samee': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'edgar': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'updat': {'positive': 12, 'negative': 10, 'ratio': 1.1818181818181819},
#  'log': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'bring': {'positive': 14, 'negative': 8, 'ratio': 1.6666666666666667},
#  'abe': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'meet': {'positive': 26, 'negative': 23, 'ratio': 1.125},
#  'x38': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'sigh': {'positive': 3, 'negative': 12, 'ratio': 0.3076923076923077},
#  'dreamili': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'pout': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'eye': {'positive': 12, 'negative': 11, 'ratio': 1.0833333333333333},
#  'quacketyquack': {'positive': 6, 'negative': 0.0, 'ratio': 7.0},
#  'happen': {'positive': 13, 'negative': 43, 'ratio': 0.3181818181818182},
#  'phil': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'em': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'del': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'rodder': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'els': {'positive': 8, 'negative': 4, 'ratio': 1.8},
#  'play': {'positive': 37, 'negative': 39, 'ratio': 0.95},
#  'newest': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'gamejam': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'irish': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'literatur': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'inaccess': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  "kareena'": {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'fan': {'positive': 21, 'negative': 17, 'ratio': 1.2222222222222223},
#  'brain': {'positive': 10, 'negative': 2, 'ratio': 3.6666666666666665},
#  'dot': {'positive': 8, 'negative': 2, 'ratio': 3.0},
#  'braindot': {'positive': 8, 'negative': 0.0, 'ratio': 9.0},
#  'fair': {'positive': 4, 'negative': 8, 'ratio': 0.5555555555555556},
#  'rush': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'either': {'positive': 10, 'negative': 11, 'ratio': 0.9166666666666666},
#  'brandi': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  '18': {'positive': 5, 'negative': 6, 'ratio': 0.8571428571428571},
#  'carniv': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'men': {'positive': 8, 'negative': 0.0, 'ratio': 9.0},
#  'put': {'positive': 11, 'negative': 10, 'ratio': 1.0909090909090908},
#  'mask': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'xavier': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'forneret': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'jennif': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'site': {'positive': 7, 'negative': 3, 'ratio': 2.0},
#  'free': {'positive': 32, 'negative': 14, 'ratio': 2.2},
#  '50.000': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  '8': {'positive': 11, 'negative': 7, 'ratio': 1.5},
#  'ball': {'positive': 7, 'negative': 2, 'ratio': 2.6666666666666665},
#  'pool': {'positive': 5, 'negative': 3, 'ratio': 1.5},
#  'coin': {'positive': 5, 'negative': 0.0, 'ratio': 6.0},
#  'edit': {'positive': 6, 'negative': 4, 'ratio': 1.4},
#  'trish': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  '♥': {'positive': 13, 'negative': 20, 'ratio': 0.6666666666666666},
#  'grate': {'positive': 5, 'negative': 1, 'ratio': 3.0},
#  'three': {'positive': 8, 'negative': 6, 'ratio': 1.2857142857142858},
#  'comment': {'positive': 8, 'negative': 3, 'ratio': 2.25},
#  'wakeup': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'besid': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'dirti': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'sex': {'positive': 4, 'negative': 5, 'ratio': 0.8333333333333334},
#  'lmaooo': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  '😤': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'loui': {'positive': 4, 'negative': 4, 'ratio': 1.0},
#  "he'": {'positive': 11, 'negative': 19, 'ratio': 0.6},
#  'throw': {'positive': 3, 'negative': 2, 'ratio': 1.3333333333333333},
#  'caus': {'positive': 11, 'negative': 10, 'ratio': 1.0909090909090908},
#  'inspir': {'positive': 6, 'negative': 0.0, 'ratio': 7.0},
#  'ff': {'positive': 40, 'negative': 4, 'ratio': 8.2},
#  'twoof': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'gr8': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'wkend': {'positive': 3, 'negative': 0.0, 'ratio': 4.0},
#  'kind': {'positive': 22, 'negative': 9, 'ratio': 2.3},
#  'exhaust': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'word': {'positive': 17, 'negative': 13, 'ratio': 1.2857142857142858},
#  'cheltenham': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'area': {'positive': 4, 'negative': 1, 'ratio': 2.5},
#  'kale': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'crisp': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'ruin': {'positive': 5, 'negative': 10, 'ratio': 0.5454545454545454},
#  'x37': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'open': {'positive': 12, 'negative': 13, 'ratio': 0.9285714285714286},
#  'worldwid': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'outta': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'sfvbeta': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'vantast': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'xcylin': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'bundl': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'show': {'positive': 20, 'negative': 19, 'ratio': 1.05},
#  'internet': {'positive': 2, 'negative': 7, 'ratio': 0.375},
#  'price': {'positive': 3, 'negative': 4, 'ratio': 0.8},
#  'realisticli': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'pay': {'positive': 8, 'negative': 8, 'ratio': 1.0},
#  'net': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'educ': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'power': {'positive': 6, 'negative': 5, 'ratio': 1.1666666666666667},
#  'weapon': {'positive': 1, 'negative': 2, 'ratio': 0.6666666666666666},
#  'nelson': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'mandela': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'recent': {'positive': 8, 'negative': 0.0, 'ratio': 9.0},
#  'j': {'positive': 2, 'negative': 1, 'ratio': 1.5},
#  'chenab': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'flow': {'positive': 5, 'negative': 0.0, 'ratio': 6.0},
#  'pakistan': {'positive': 1, 'negative': 1, 'ratio': 1.0},
#  'incredibleindia': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'teenchoic': {'positive': 7, 'negative': 5, 'ratio': 1.3333333333333333},
#  'choiceinternationalartist': {'positive': 7,
#   'negative': 5,
#   'ratio': 1.3333333333333333},
#  'superjunior': {'positive': 7, 'negative': 5, 'ratio': 1.3333333333333333},
#  'caught': {'positive': 4, 'negative': 1, 'ratio': 2.5},
#  'first': {'positive': 41, 'negative': 22, 'ratio': 1.826086956521739},
#  'salmon': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'super-blend': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'project': {'positive': 6, 'negative': 3, 'ratio': 1.75},
#  'youth@bipolaruk.org.uk': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'awesom': {'positive': 35, 'negative': 5, 'ratio': 6.0},
#  'stream': {'positive': 12, 'negative': 21, 'ratio': 0.5909090909090909},
#  'artist': {'positive': 2, 'negative': 2, 'ratio': 1.0},
#  'alma': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'mater': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'highschoolday': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'clientvisit': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'faith': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'christian': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'school': {'positive': 9, 'negative': 22, 'ratio': 0.43478260869565216},
#  'lizaminnelli': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  'upcom': {'positive': 2, 'negative': 0.0, 'ratio': 3.0},
#  'uk': {'positive': 4, 'negative': 6, 'ratio': 0.7142857142857143},
#  '😄': {'positive': 3, 'negative': 1, 'ratio': 2.0},
#  'singl': {'positive': 4, 'negative': 2, 'ratio': 1.6666666666666667},
#  'hill': {'positive': 4, 'negative': 1, 'ratio': 2.5},
#  'everi': {'positive': 23, 'negative': 11, 'ratio': 2.0},
#  'beat': {'positive': 7, 'negative': 1, 'ratio': 4.0},
#  'wrong': {'positive': 9, 'negative': 27, 'ratio': 0.35714285714285715},
#  'readi': {'positive': 22, 'negative': 9, 'ratio': 2.3},
#  'natur': {'positive': 1, 'negative': 0.0, 'ratio': 2.0},
#  ...}

# %%
# Test your function; find positive words at or above a threshold
get_words_by_threshold(freqs, label=1, threshold=10)
# Out:
# {'followfriday': {'positive': 23, 'negative': 0.0, 'ratio': 24.0},
#  'commun': {'positive': 27, 'negative': 1, 'ratio': 14.0},
#  ':)': {'positive': 2960, 'negative': 2, 'ratio': 987.0},
#  'flipkartfashionfriday': {'positive': 16, 'negative': 0.0, 'ratio': 17.0},
#  ':D': {'positive': 523, 'negative': 0.0, 'ratio': 524.0},
#  ':p': {'positive': 104, 'negative': 0.0, 'ratio': 105.0},
#  'influenc': {'positive': 16, 'negative': 0.0, 'ratio': 17.0},
#  ':-)': {'positive': 552, 'negative': 0.0, 'ratio': 553.0},
#  "here'": {'positive': 20, 'negative': 0.0, 'ratio': 21.0},
#  'youth': {'positive': 14, 'negative': 0.0, 'ratio': 15.0},
#  'bam': {'positive': 44, 'negative': 0.0, 'ratio': 45.0},
#  'warsaw': {'positive': 44, 'negative': 0.0, 'ratio': 45.0},
#  'shout': {'positive': 11, 'negative': 0.0, 'ratio': 12.0},
#  ';)': {'positive': 22, 'negative': 0.0, 'ratio': 23.0},
#  'stat': {'positive': 51, 'negative': 0.0, 'ratio': 52.0},
#  'arriv': {'positive': 57, 'negative': 4, 'ratio': 11.6},
#  'glad': {'positive': 41, 'negative': 2, 'ratio': 14.0},
#  'blog': {'positive': 27, 'negative': 0.0, 'ratio': 28.0},
#  'fav': {'positive': 11, 'negative': 0.0, 'ratio': 12.0},
#  'fantast': {'positive': 9, 'negative': 0.0, 'ratio': 10.0},
#  'fback': {'positive': 26, 'negative': 0.0, 'ratio': 27.0},
#  'pleasur': {'positive': 10, 'negative': 0.0, 'ratio': 11.0},
#  '←': {'positive': 9, 'negative': 0.0, 'ratio': 10.0},
#  'aqui': {'positive': 9, 'negative': 0.0, 'ratio': 10.0}}

# %% [markdown]
# Notice the difference between the positive and negative ratios. Emojis like :( and words like 'me' tend to have a negative connotation. Other words like glad, community, arrives, tend to be found in the positive tweets.

# %%
# Test your function
w2_unittest.test_get_words_by_threshold(get_words_by_threshold, freqs)
# Out:
#  All tests passed

# %% [markdown]
# <a name='5'></a>
# ## 5 - Error Analysis
#
# In this part you will see some tweets that your model missclassified. Why do you think the missclassifications happened? Were there any assumptions made by your naive bayes model?

# %%
# Some error analysis done for you
print('Truth Predicted Tweet')
for x, y in zip(test_x, test_y):
    y_hat = naive_bayes_predict(x, logprior, loglikelihood)
    if y != (np.sign(y_hat) > 0):
        print('%d\t%0.2f\t%s' % (y, np.sign(y_hat) > 0, ' '.join(
            process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# Truth Predicted Tweet
# 0	1.00	b'help ... stop cri :('
# 0	1.00	b'otl nevermind :( least got jeon'
# 0	1.00	b'soon tweet plant claw thigh traction zoom away :('
# 0	1.00	b'damnit :('
# 0	1.00	b'use pri pv ... wish could reliv day becom nyc pv buy way commun nyc usa klm :('
# 0	1.00	b'realli hot :-('
# 0	1.00	b'monday :('
# 0	1.00	b"go stop breakfast earli might want remov 11am websit even mcd' pull trick :("
# 0	1.00	b'mean way :( 3rd load hung'
# 0	1.00	b':( wtf suppos without'
# 0	1.00	b'headach strike :('
# 0	1.00	b'english weather need fix :('
# 0	1.00	b'live fam bam cough :('
# 0	1.00	b'absolut gut jame bay ticket sold manchest :('
# 0	1.00	b'seventh spot na lang :( otwolgrandtrail'
# 0	1.00	b'splendour :('
# 0	1.00	b'omg swedish hair metal legend hirfrc studio leav nooo :( givecodpieceach'
# 0	1.00	b'sore alic :('
# 0	1.00	b"i'm readi work yet :("
# 0	1.00	b'someon unfav :('
# 0	1.00	b'stile :('
# 0	1.00	b'funni mo :('
# 0	1.00	b'someon explain sandrabland :('
# 0	1.00	b'dont sad :( ili'
# 0	1.00	b'go spend night pragu leav tomorrow :('
# 0	1.00	b'one friend follow littl heart attack im sorri your block :( sadi'
# 0	1.00	b"i'm annoy :("
# 0	1.00	b'consid lucki favourit charact even make season final 100 :('
# 0	1.00	b'boo alreadi turn ye 915 :('
# 0	1.00	b"itun i'm wait notanapolog :("
# 0	1.00	b'layout match closest could find header :( someon help'
# 0	1.00	b"hayee :( hayee :( patwari mam ik' vision would say noth rather lil laugh"
# 0	1.00	b'agh sorri :-('
# 0	1.00	b'vidcon :( :( :('
# 0	1.00	b'ga :('
# 0	1.00	b'awhhh ok ok :( see nalang class open hehe'
# 0	1.00	b'last night one worst night :( pretti sure albanian women curs'
# 0	1.00	b'air max tava pl pl pl pl :('
# 0	1.00	b'taken :( anoth chara mayb teteh'
# 0	1.00	b'dev verri sad caus twitter :('
# 0	1.00	b"imagin would shatter dream :-( we'll let colleagu know sb"
# 0	1.00	b'much miss :('
# 0	1.00	b'nawe :('
# 0	1.00	b'want white french bulldog :('
# 0	1.00	b'wanna feel love :('
# 0	1.00	b"aww poor wish help even though can't realli help much :("
# 0	1.00	b"i'm sorri see tweet :( 2 point x"
# 0	1.00	b'miss macho man :('
# 0	1.00	b'hav puriti back :('
# 0	1.00	b'kwento :( fbc'
# 0	1.00	b'3 day without talk bae :('
# 0	1.00	b'whaaat nooo :('
# 0	1.00	b"pleas tweet someth i'm sad :( cheer pleas .."
# 0	1.00	b'miss brown hair :('
# 0	1.00	b'nakakapikon yung nagbabasa ka ng blog comment info full peopl ask damn question answer post :('
# 0	1.00	b'lead caus cancer children five :('
# 0	1.00	b"alon :-( :'( :-\\"
# 0	1.00	b'hello info possibl interest jonatha close join beti :( great'
# 0	1.00	b"i'm sorri peopl shit respect person space :("
# 0	1.00	b'nooo :( sogok ice cream'
# 0	1.00	b'thank send premium write instrument howev dastardli swine stole envelop :('
# 0	1.00	b'im get sick tire pipol say im short ... short ... tini :('
# 0	1.00	b'fair enough :( would anyon seem tad fuck  .. wiper wiper'
# 0	1.00	b'supposedli one worst kernel devic :('
# 0	1.00	b"i'm bore :("
# 0	1.00	b'true doubt :( zayniscomingbackonjuli 26'
# 0	1.00	b'today  job anoth fack intel extra mega care get bent socket pin :-( pcgame pcupgrad'
# 0	1.00	b'hate messeng :('
# 0	1.00	b'everyon asleep alreadi :('
# 0	1.00	b"they'v brainwash :("
# 0	1.00	b'1 pl download smosh movi free onlin hahahaha :('
# 0	1.00	b'kik plawnew 837 kik kikmenow amateur sf snapm summer hotti :('
# 0	1.00	b'omg way guy aswel :-( btw cat litter isnt good pregnanc make sure u dont go near'
# 0	1.00	b'ah mensch :('
# 0	1.00	b'sepanx one :('
# 0	1.00	b'cannot view pictur unhappi seat bu :('
# 0	1.00	b"there' huge bag present luke can't open he' back work :-("
# 0	1.00	b'pci mine :-('
# 0	1.00	b'last time went caerphilli find anywher sell local chees :-('
# 0	1.00	b'eye realli bad today even glass :('
# 0	1.00	b"i'm omw  lol wish :("
# 0	1.00	b'joke lang eh :( hahdhdhshh'
# 0	1.00	b'never see dad midnight bc work hard fuck :( growinguppoor'
# 0	1.00	b'number one america    wish could buy money :('
# 0	1.00	b"wish buy bangtan' merch :("
# 0	1.00	b'pain ubericecream driver busi :('
# 0	1.00	b'oh gosh say aw hun :( cuddl'
# 0	1.00	b'want :('
# 0	1.00	b'taimoor meray dost :('
# 0	1.00	b'tya mind refollow :('
# 0	1.00	b'stomach kill :('
# 0	1.00	b'apolog avail australia :('
# 0	1.00	b'ksoo u dumb butt :('
# 0	1.00	b"omg get hate sex offend :( poor :( i'm stupid pissbabi"
# 0	1.00	b'want finish death parad weekend :('
# 0	1.00	b"i'm frustrat plank time super inconsist idea i'm wrong :("
# 0	1.00	b'rip tom moor ... love read comic book ... anoth great artist truli miss :('
# 0	1.00	b'miss much :('
# 0	1.00	b'awww miss swear twitter day truli bore rather watch movi footbal :('
# 0	1.00	b'sch get better ... :-('
# 0	1.00	b'throat sore :('
# 0	1.00	b'one awak :('
# 0	1.00	b'im hungri :('
# 0	1.00	b'get bin osx chrome voiceov >:('
# 0	1.00	b'  night :( devo xxx'
# 0	1.00	b'im sad :('
# 0	1.00	b'hope wrong hulkhogan think know deep hurt wake kind unpleas :('
# 0	1.00	b'even know say :('
# 0	1.00	b'daaamn :('
# 0	1.00	b'grabe ang harsh huhuhu u like :('
# 0	1.00	b'aw babe :('
# 0	1.00	b'boy r play :( cant watch :( rip'
# 0	1.00	b'dada uh iphon na :( :( pic '
# 0	1.00	b"sorri i'm fulli book :-( xx"
# 0	1.00	b'unfollow unni :('
# 0	1.00	b'lucki spike :-('
# 0	1.00	b'omg miss 2 :('
# 0	1.00	b"panic' new album come 22nd :("
# 0	1.00	b'bigbang need rest :( travel one place anoth must realli tire :('
# 0	1.00	b':( rude'
# 0	1.00	b'mention south africa mani time song time come south africa :('
# 0	1.00	b"hate can't rememb dream love share :("
# 0	1.00	b'go america man r p victim louisiana :('
# 0	1.00	b'school come twitter :('
# 0	1.00	b'take 190 horribl time :('
# 0	1.00	b'ella :( cheer pl'
# 0	1.00	b"that' excus launch attack lizardz feel like shit deepli asham >:("
# 0	1.00	b'noth wors :('
# 0	1.00	b'sorri :( need get emerg engin home next 4 hour laura'
# 0	1.00	b'never go sleep earli :( lol'
# 0	1.00	b'home dormtel near st scho girl siya tho :( want help find onee'
# 0	1.00	b'talk exclus :( u know carri u want play '
# 0	1.00	b'7pm friday dead :('
# 0	1.00	b"sorri nat school holiday .. :( i'm work 1pm"
# 0	1.00	b'im work :('
# 0	1.00	b'everi time feta chees head start blaaaz sometim vision mess nausea come :('
# 0	1.00	b"oh that' good :( we'r awar issu abl top-up"
# 0	1.00	b'sharknado one hour never get back :('
# 0	1.00	b'yeah leav read :-('
# 0	1.00	b'cannot even sleep right :('
# 0	1.00	b'erni :('
# 0	1.00	b'tl :( hungri af'
# 0	1.00	b'rain :-('
# 0	1.00	b'ezoo year sorri :-('
# 0	1.00	b'look fun snapchat lilybutl 18 snapchat kikmenow amateur kikmeboy seduc hannib kiksext :('
# 0	1.00	b'ed sheeran preform countri tonight ur go :('
# 0	1.00	b'cannot seem get one powai :('
# 0	1.00	b'neighbor let sleep :-('
# 0	1.00	b'back delhi :('
# 0	1.00	b'feet cold point take sock okay stop :('
# 0	1.00	b"can't belieb rain :("
# 0	1.00	b"sinc model stop stock boot can't get can't even order onlin tell unsaf :("
# 0	1.00	b"summer holiday great i'm bore alreadi :("
# 0	1.00	b'oh plan stream halo xbox one today :('
# 0	1.00	b'drop dead fred use favorit movi wish :-('
# 0	1.00	b"rememb 2 gaon bad 6 infnt elig apink :( acub why'd u"
# 0	1.00	b'sad everi time apink event .. understand korean :(  '
# 0	1.00	b':( fun'
# 0	1.00	b'bullshit ... :('
# 0	1.00	b':( know happen internet light connect drop thank kei'
# 0	1.00	b'wish could hear food :('
# 0	1.00	b'hanaaa birthday ya allah sorri wish van jn tak tau :( happi birthday gorgeou'
# 0	1.00	b"omg realli i'm sorri babe :("
# 0	1.00	b'happen soul si :('
# 0	1.00	b'faith :('
# 0	1.00	b'last present receiv  haha basta :('
# 0	1.00	b'went bed headach ... woke headach :('
# 0	1.00	b'snapchat guy jasmingarrick snapchat kiksext chat sext addm mpoint hotmusicdeloco :('
# 0	1.00	b'relat full lie :('
# 0	1.00	b"aw fuck there' dress bag floor dammit that' realli loud :("
# 0	1.00	b'dhi  block twitter :( thank good time  play 8ball fakmarey'
# 0	1.00	b'unfortun smell like doo doo :('
# 0	1.00	b'wanna go six flag :('
# 0	1.00	b'sorri :('
# 0	1.00	b'shop fun :('
# 0	1.00	b'miss cat :('
# 0	1.00	b'miss :('
# 0	1.00	b"would like abl work full time stuff move i'm consid take fulltim job :("
# 0	1.00	b"yeah i'v seen someth tinder fb root :( woman frustrat awkward"
# 0	1.00	b'food kitchen money wallet thank barcelona dad home month beet juic either :('
# 0	1.00	b'dci today wish go :-('
# 0	1.00	b'work freez :('
# 0	1.00	b'srsli u :('
# 0	1.00	b'hate see granddad like :('
# 0	1.00	b'sorri pre :('
# 0	1.00	b'want minion bucket pleas :( yesterday :('
# 0	1.00	b'fair love war kapan updat :( oh ya udah dihapu hilang dari muka bumi want read someon give link '
# 0	1.00	b'girl quick :('
# 0	1.00	b'mani nasti narrow mind peopl :('
# 0	1.00	b'want room :-('
# 0	1.00	b"friend respect life :-( i'm sorri"
# 0	1.00	b'sadli :('
# 0	1.00	b"suck i'm gona miss chello parti :("
# 0	1.00	b'hello info possibl interest jonatha close join beti :('
# 0	1.00	b"can't watch phone sorri :( thank still <3"
# 0	1.00	b'taxi driver thought sophi work nintendo took us gate :( secur guard gave us dirtiest look haha'
# 0	1.00	b'omg :-( love much monica see soon aaahhh'
# 0	1.00	b':( crepe 40 '
# 0	1.00	b'kick bae :('
# 0	1.00	b'haha sound like  fun game :('
# 0	1.00	b'follow :('
# 0	1.00	b'school monday wanna meet new peopl :('
# 0	1.00	b'... havent finish yet :('
# 0	1.00	b'u forsaken ran gf :('
# 0	1.00	b'kanin pleas :( xd'
# 0	1.00	b'get hypixel :( want record grrr thestruggleisr geek gamer gamer youtub'
# 0	1.00	b'want afterbirth :('
# 0	1.00	b"bummer :( apink' digit physic sale super great bc time album releas win"
# 0	1.00	b'overperhatian :( :('
# 0	1.00	b'sad :('
# 0	1.00	b"that' aw :( son miss physic exam chicken pox gave predict grade poor girl"
# 0	1.00	b'srsli tho bae look :('
# 0	1.00	b"ahm ... i'v never london ... holiday outsid ireland nearli 8 year :( never got chanc cash go"
# 0	1.00	b'pleas follow :('
# 0	1.00	b'omg :-('
# 0	1.00	b"5am i'm wit ha damn headach :("
# 0	1.00	b'dream met karli kloss sweet want take like bunch goofi photo :('
# 0	1.00	b'realiz 3 watch concert video pcd extrem hard rn :('
# 0	1.00	b'sorri antagonis call writer sever polit nudg ... :('
# 0	1.00	b'delv enough seen heard fuck horrend :('
# 0	1.00	b'follow :('
# 0	1.00	b'duo drop doubl digit :( twice'
# 0	1.00	b'got :( come'
# 0	1.00	b'theyr cute wish knew say :('
# 0	1.00	b'care :('
# 0	1.00	b"wish could'v met :("
# 0	1.00	b'grandad realli well :( worri much'
# 0	1.00	b"u gray' followk omg hard day u know :( :("
# 0	1.00	b'idk bc money leav :-('
# 0	1.00	b'lot peopl suggest still :('
# 0	1.00	b'follback pl :('
# 0	1.00	b'get pace maker oh :('
# 0	1.00	b'ah minc :('
# 0	1.00	b'molli deserv much higher place :('
# 0	1.00	b"i'm hungri :("
# 0	1.00	b'wanna good time one hit date much ask :('
# 0	1.00	b'feel sucki w run nose cough sore throat fever :-('
# 0	1.00	b'hate hot weather :( graduat ceremoni later boy gonna wear suit everyon go die'
# 0	1.00	b"let' go parti ... pant ew :( gross"
# 0	1.00	b'someon niall layout give :('
# 0	1.00	b'hey christin moodi :('
# 0	1.00	b'miss :('
# 0	1.00	b'throwback :('
# 0	1.00	b'that good enough reason :( pleas dont leav your one fav barb'
# 0	1.00	b"cooper i'm convinc neither 2 pleas i'm concern creasi win deputi :("
# 0	1.00	b'tast bad though :('
# 0	1.00	b'joke man :('
# 0	1.00	b"never remov minion car 23 day run batteri banana' :("
# 0	1.00	b'want sponsor acc new even 1k :('
# 0	1.00	b'told u guy bday today :( gift want paypal'
# 0	1.00	b'goodby stage alreadi :-('
# 0	1.00	b'shit idk time :('
# 0	1.00	b'today tire :-('
# 0	1.00	b'pretti :('
# 0	1.00	b':( matt'
# 0	1.00	b'hello info possibl interest jonatha close join beti :( saludo'
# 0	1.00	b'hey someon text :('
# 0	1.00	b'anoth dissapoint review :( bblogger makeup beauti'
# 0	1.00	b" <-- face everi guy pull get head feel bae' teeth dick :("
# 0	1.00	b'ahhh well :('
# 0	1.00	b'wanna see paper town w :('
# 0	1.00	b'get long last black pump :('
# 0	1.00	b'omfg beauti place ever miss much :('
# 0	1.00	b'hate pimpl :('
# 0	1.00	b"almost 12 i'm tire :("
# 0	1.00	b"honey brown sugar good ur lip :/ amount stuff use face could'v use food instead :("
# 0	1.00	b'ikr hai would someon sell preciou thing :('
# 0	1.00	b"i'm tire :( got good sleep"
# 0	1.00	b'yea man ... suppos footbal tdi man plan fail :('
# 0	1.00	b'pleas god wanna go work :('
# 0	1.00	b'kinda miss pamela good anna :('
# 0	1.00	b"pleas woe can't run six though live mexico :("
# 0	1.00	b"idk i'm get mini bu idk time i'm go get :("
# 0	1.00	b"hi harri sorri :( we'r work mast area caus intermitt servic work complet"
# 0	1.00	b'look fun snapchat janniecam snapchat kikm webcam snapchatm kikhorni musicbiz hotmusicdeloco :('
# 0	1.00	b'braxton gone pro :( feel bad urban unpreced brainwash see tebow alex smith'
# 0	1.00	b'wat okaaay huhu :( sayanggg find yah phone'
# 0	1.00	b'1 taxi servic 2 second schedul blog post 3 housework bust :('
# 0	1.00	b'mum say done leav step dad :-('
# 0	1.00	b'want go disneyland badli :-('
# 0	1.00	b'bc thoma tommyy :('
# 0	1.00	b'billi ... :('
# 0	1.00	b"fanci kevin clifton strictli come danc much he' marri :( whyyi"
# 0	1.00	b'nsc mat 0 tomorrow :('
# 0	1.00	b"awhh see guy would'v ram car :("
# 0	1.00	b"that' ok :( reason voucher can't use onlin"
# 0	1.00	b'kik smadvow 544 kik kikgirl lgbt photo model free hotti :('
# 0	1.00	b"everyone' work can't even get :("
# 0	1.00	b'would love see acdc .. miss ticket :('
# 0	1.00	b':( aker ive send ka gmail u get :('
# 0	1.00	b"last stage today :( i'm go miss see almost everyday"
# 0	1.00	b'never give best thing take time weh :('
# 0	1.00	b'guy add kik sprevelink 633 kik hornykik chat porno orgasm free webcamsex :('
# 0	1.00	b'lana :('
# 0	1.00	b'miss 11:11 :( btw wish follow  loveyoutilltheendcart '
# 0	1.00	b'aw sound great better lunch :('
# 0	1.00	b'want play sfv capcom plz :('
# 0	1.00	b'tip onlin 6/7 winner yesterday 1 goal nice 20/1 :( hope similar strike rate today'
# 0	1.00	b'u prob fun david'
# 0	1.00	b'sooo burnt ... :-('
# 0	1.00	b'need new phone :('
# 0	1.00	b'miss tito daddi :('
# 0	1.00	b'rosi hayoung shut :('
# 0	1.00	b'want ram nlb :-('
# 0	1.00	b'hahahah holi shit comfort :('
# 0	1.00	b'could flat ab time ... @_ gym tayo g :('
# 0	1.00	b'yeah :('
# 0	1.00	b'first two day kati summer back forth doctor suspect mening viral tonsil :( poorli girl '
# 0	1.00	b'wanna go movi today one :('
# 0	1.00	b'want watch paper town :-('
# 0	1.00	b"i'v repli yet :( ang given work next 3 week  x"
# 0	1.00	b'say :-('
# 0	1.00	b'babyy :('
# 0	1.00	b'dont either :( ugli cushion littl longer thank help'
# 0	1.00	b'happi birthday pleas come back singapor :-(                 '
# 0	1.00	b"weigh risk premium go :( lot money 1 reason i'm keen get dog"
# 0	1.00	b'know feel man :('
# 0	1.00	b'yeah look :('
# 0	1.00	b"can't see say ice cream uber app :( set locat"
# 0	1.00	b'wish could see ben :('
# 0	1.00	b'think ever win petrofac cup :-( ;-)'
# 0	1.00	b"15 day ago danni took wig put onto mark' head want go back :( "
# 0	1.00	b'pathet emot burden.say like care hug respect toler call name :-('
# 0	1.00	b'allerg cat ... itchi throat :('
# 0	1.00	b'like dog :('
# 0	1.00	b"man right wish someon would bring food offic i'm starv :("
# 0	1.00	b'gosh cheaper malaysia :( worth 130 ship'
# 0	1.00	b'weather set sleep respons :-('
# 0	1.00	b'think someon hack acc :('
# 0	1.00	b'guy nooo :-( wow wow wow wow'
# 0	1.00	b'boy snapchattimg happi bc friend ruin said wanna fun   :('
# 0	1.00	b'look 12 still :('
# 0	1.00	b'tbh forget donat manag sin due hp corrupt restor data lost lor :('
# 0	1.00	b'worst pain :('
# 0	1.00	b'never dedic anyth :( smh lol'
# 0	1.00	b'iren unni bite finger worriedli stare staff :( okay unni'
# 0	1.00	b'feel sick :('
# 0	1.00	b':('
# 0	1.00	b'guy add kik toneadi 46532 kik kikmeboy wife porno snapdirti premiostumundo sheskindahot :('
# 0	1.00	b'omfg hug corps :('
# 0	1.00	b'taeni fyeah link broken :('
# 0	1.00	b'hello info possibl interest jonatha he close beti :('
# 0	1.00	b'cant watch tonight andromeda :('
# 0	1.00	b'la time right ye yunni im seriou :('
# 0	1.00	b'develop releas good game school :('
# 0	1.00	b'thank feel aw sick long time :('
# 0	1.00	b'lot write boy section whdjwksja idk ziam write still fuck go 100k school :('
# 0	1.00	b"noo i'v ben watch like hawk week gut :("
# 0	1.00	b'spoil :('
# 0	1.00	b'none hide behind shower curtain :('
# 0	1.00	b':( want good least watchabl account neither'
# 0	1.00	b'want watch :('
# 0	1.00	b'last day indiana :('
# 0	1.00	b'fav chees give migrin :('
# 0	1.00	b"still sad fix car window bc can't drive anywher without scare it'll shatter :("
# 0	1.00	b'morn work unfortun :( gdce gamescom'
# 0	1.00	b'hay idk babi :(   '
# 0	1.00	b"oh :( do't think parcel come yodel hit follow dm track num chelsea"
# 0	1.00	b'wish could friend everybodi :( lmfaooo'
# 0	1.00	b'oooouch poor pinki toe  good thing work podiatrist wait morn go hurri morn :('
# 0	1.00	b'morn miss :('
# 0	1.00	b"miss old hous could hear parent door open act like i'm asleep :("
# 0	1.00	b"gusto ko ng rodic' :( someon share order one' big"
# 0	1.00	b'adoohh :('
# 0	1.00	b'b-butt black cat bad luck ene'
# 0	1.00	b'miss ticket show morn :( get tigermilk fix'
# 0	1.00	b'ye hope next year :('
# 0	1.00	b'want meet jacob bad :('
# 0	1.00	b'pleas tell :('
# 0	1.00	b'use recommend east dulwich gone super crazi last five year :('
# 0	1.00	b'awww miss :('
# 0	1.00	b'last episod realli intens :( kagami n kuroko forev <3'
# 0	1.00	b"can't sleep :-("
# 0	1.00	b"can't say nah food :("
# 0	1.00	b'want see :( sana makita na kita ang'
# 0	1.00	b'spooki jim smol bean :('
# 0	1.00	b'one guy true blood st fagan yesterday :( :( :('
# 0	1.00	b'buy book memem live finland :('
# 0	1.00	b'whaaat fair :('
# 0	1.00	b'nooo stay uk im :('
# 0	1.00	b'aw poor thing :('
# 0	1.00	b'also want :('
# 0	1.00	b"look amaz think saw meadowhal day actual unfortun weekend i'll work :("
# 0	1.00	b'sorri :( spend time instagram'
# 0	1.00	b"rip lola :( i'll miss sorri di kita nadalaw last day thank everyth .. sa memori sa warm hug sa lahat labyu la"
# 0	1.00	b'oki :-('
# 0	1.00	b'dont want anyth happen bae :('
# 0	1.00	b'even start trend wanna know jot truth :( zayniscomingbackonjuli 26'
# 0	1.00	b'snapchat guy ivypowel 19 snapchat kikhorni chat girl like 4like travel phonesex :('
# 0	1.00	b'schade :('
# 0	1.00	b'missin homeslic bday :( 333'
# 0	1.00	b'poor throat :('
# 0	1.00	b'fav emoticon right :( emoticon'
# 0	1.00	b"see i'd get eyebrow done prettylook wanna tri differ style :("
# 0	1.00	b'rip whitney houston :('
# 0	1.00	b'aur ap bhi shamil ho :('
# 0	1.00	b"much past 2 day bc need save 3g feel like i'v miss tonn :("
# 0	1.00	b'hey sorri hear :( check servic statu page  gen'
# 0	1.00	b'hold back like way :('
# 0	1.00	b"amount i'm eat day ridicul know i'm suddenli alway hungri :("
# 0	1.00	b'omg alli hug mani wrap arm around neck pull closer :-('
# 0	1.00	b'love toothsensit :-('
# 0	1.00	b'ye :('
# 0	1.00	b'heartbroken :('
# 0	1.00	b'chover :('
# 0	1.00	b'want cebu lechon :('
# 0	1.00	b'head kill :('
# 0	1.00	b'want kitten badli oh god :('
# 0	1.00	b'sleep wake time :('
# 0	1.00	b'add snapchat jannygreen 22 snapchat kiksex xxx seduc tagsforlik nakamaforev hotel :('
# 0	1.00	b'probabl fault lost phone :('
# 0	1.00	b'told suicid kill ran away forev :('
# 0	1.00	b'mad wrong :( make forgiv :('
# 0	1.00	b"pleas follow conno i'm late time zone could freak never see :("
# 0	1.00	b'biggest dream u follow brooo :('
# 0	1.00	b"i'm lone girl england :("
# 0	1.00	b'time last week rout lovebox :( share day new prod'
# 0	1.00	b'im osad :-('
# 0	1.00	b'hate break :('
# 0	1.00	b':('
# 0	1.00	b'still happen lot unfortun still report peopl fall scam :('
# 0	1.00	b'eric made still tell love :-( fake ass'
# 0	1.00	b'miss itb omigod :('
# 0	1.00	b'need job learn drive fricken health put back :('
# 0	1.00	b"hi unfortun we'r unabl locat origin complaint :( pl dm us product detail we'll get back"
# 0	1.00	b'miss boyfriend :-('
# 0	1.00	b':-('
# 0	1.00	b'ehem   haha ala yeke :( okay fun kk jumpa next time     mayb '
# 0	1.00	b'come home empti hous ape :('
# 0	1.00	b"i'v shit bestfriend :("
# 0	1.00	b"i'm gonna inact next month :("
# 0	1.00	b'miss :('
# 0	1.00	b":( well tri someth keep mind bad thing we'r alway"
# 0	1.00	b"i'v never seen felt snow :("
# 0	1.00	b"i'm work :( show get home 1.2 lost map accid lost build"
# 0	1.00	b'dont know huhu test kasi namin didnt finish ap test :-('
# 0	1.00	b'want hot dog :('
# 0	1.00	b'reject section uk govt e-petit site die :('
# 0	1.00	b"i'm sad :("
# 0	1.00	b'cant find :('
# 0	1.00	b'oh :( build suit'
# 0	1.00	b"wanna cut k i'm friend threw sleepov parti :( i'm pretend ok like usual"
# 0	1.00	b'leav alon :('
# 0	1.00	b'pray khami ... :( ... kadhafi'
# 0	1.00	b'damn forgot hot chocol :('
# 0	1.00	b"i'm crave oreo milk :("
# 0	1.00	b'love island finish feel like summer gone :('
# 0	1.00	b'miss :('
# 0	1.00	b'push client way host mayb better wait till next week :('
# 0	1.00	b'im irk :('
# 0	1.00	b'someon say thank u goodby chri tomorrow pl :('
# 0	1.00	b'need nate ruess album :('
# 0	1.00	b'could realli use hug mayb icecream :('
# 0	1.00	b'lot good comic event seem kid :( part school program'
# 0	1.00	b'look like dog food ... :( ugh'
# 0	1.00	b'miss bad :('
# 0	1.00	b'aigoo babi :('
# 0	1.00	b'want watch paper town :-('
# 0	1.00	b'wanna recov :('
# 0	1.00	b':-( poor boy'
# 0	1.00	b'u guy togeth :('
# 0	1.00	b'saw one doujin think killua get fuck ging bit sad caus didnt show dick hope ginggon :('
# 0	1.00	b'comput broken wait fix miss much twitter guys.al love .. :('
# 0	1.00	b'feel like ytd :('
# 0	1.00	b"joe i'm sick come round make soup :("
# 0	1.00	b'cri :( pdapaghimok'
# 0	1.00	b"stori life :( haha look who' talk"
# 0	1.00	b'work :( smh'
# 0	1.00	b'anyon awak :-('
# 0	1.00	b'ya sorri :-('
# 0	1.00	b'friend :('
# 0	1.00	b'use flexibl :('
# 0	1.00	b"taxi driver go realli fast i'm scare :("
# 0	1.00	b'bet wonder happen :('
# 0	1.00	b'sheet hurt nanaman :('
# 0	1.00	b'need small ladi walk back sore ... :('
# 0	1.00	b'want meet :('
# 0	1.00	b'alex fell asleep :('
# 0	1.00	b'justin come scotland :('
# 0	1.00	b"ok i'll write u everi week :("
# 0	1.00	b'curv tummi big .. get flat ab :('
# 0	1.00	b'look like :('
# 0	1.00	b"feel sick stomach hurt i'v done cri night can't sleep :("
# 0	1.00	b'wait gone liter :('
# 0	1.00	b"that' quot tweet :("
# 0	1.00	b'cream pinay pie soup :('
# 0	1.00	b'one :('
# 0	1.00	b'jadi langsung flasback .. :( dont cri babyy ;('
# 0	1.00	b'okay miss :('
# 0	1.00	b'listen album live franc :('
# 0	1.00	b'time like style :| like :('
# 0	1.00	b'feel sick :('
# 0	1.00	b'account meant hit us lunch time :('
# 0	1.00	b'miss lo :('
# 0	1.00	b'pl stop say rude nicknam involv short im sick yall :('
# 0	1.00	b'miss :('
# 0	1.00	b'pl write english :( dont understand'
# 0	1.00	b'snow cold gross ew big mess everyon scrape pile anyway :('
# 0	1.00	b'hey went home na :('
# 0	1.00	b"i'm still hope :( zayniscomingbackonjuli 26"
# 0	1.00	b'nigga dalla look like :( sale sare bandar varg'
# 0	1.00	b'hammer right ... look set day ... :('
# 0	1.00	b':( vidcon :('
# 0	1.00	b'abbi :('
# 0	1.00	b'feel like cri reason right :('
# 0	1.00	b'poor must tire :('
# 0	1.00	b'ur crazi af hurt much bc u know shit aint real edit :('
# 0	1.00	b'forev miss love lolo :('
# 0	1.00	b'xbsbabnb poor :('
# 0	1.00	b"although mum ask watch w  stilll :( read yet she'd ask question middl movi"
# 0	1.00	b'work 5 everyday exhaust :('
# 0	1.00	b'end state last night :( :( :( :('
# 0	1.00	b'tbh prefer apma 14 idk man there someth right year apma :('
# 0	1.00	b'u give 350 ill give u 350 350 rt anyth pl :('
# 0	1.00	b'lmao back get realli realli seriou ... :('
# 0	1.00	b'wonder happen earlier realiz leadership :-( wakeupgop'
# 0	1.00	b'ah dude :('
# 0	1.00	b'wanna take adam candi eat :('
# 0	1.00	b"pleas watch infinite' mv :("
# 0	1.00	b"can't believ ill go work today wish :("
# 0	1.00	b':( hate school u dont understand miss lot blame school'
# 0	1.00	b"like can't actual put pressur ankl hop around hous lost balanc fell :("
# 0	1.00	b'bull shark :( late trafficcc'
# 0	1.00	b'miss oscar :('
# 0	1.00	b'need translat :('
# 0	1.00	b'last time one work :( fb gone check long time lol'
# 0	1.00	b'asian ummm mayb ur film child pornographi slutsham fake suicid ect :-('
# 0	1.00	b'poland faraway germani girl :( still believ one day meet'
# 0	1.00	b"good quit full time job last week can't find anoth one :("
# 0	1.00	b':( well cooki better worth'
# 0	1.00	b"lmao catch point watch weekli i'll ok make 700 there' 800 ep :("
# 0	1.00	b"cake look amaz can't believ i'm miss :("
# 0	1.00	b'keep forget area :-( want visit next time xx'
# 0	1.00	b'make want watch whole film cgi kick oop pun start grumbl turn :('
# 0	1.00	b'see delph anoth kit upset :('
# 0	1.00	b"miss :( haha x'   still rememb u hate xxx"
# 0	1.00	b'zayniscomingbackonjuli 26 funni :('
# 0	1.00	b"we'r allow cheat meal :("
# 0	1.00	b'fun osaka super junior :( would love watch comeback stage though'
# 0	1.00	b'aytona hala guy get readi na mathird wheel :( jkjk'
# 0	1.00	b'worst day ever :( pain ...'
# 0	1.00	b'backtrack 3 hour :( ... time start actual util list'
# 0	1.00	b'surviv anoth week without phone :('
# 0	1.00	b'wish :('
# 0	1.00	b'pat jay'
# 0	1.00	b'sad stori broh :('
# 0	1.00	b'uh asleep :('
# 0	1.00	b'need boyfriend rn answer calll :('
# 0	1.00	b'icaru 500 awn unfortun fit 600 size :('
# 0	1.00	b'2 bach :('
# 0	1.00	b'6 day left :('
# 0	1.00	b'pleas babi follow :('
# 0	1.00	b"there' noth :-("
# 0	1.00	b"can't feel tomorrow :("
# 0	1.00	b'give work old staff come polic later court look anoth job :( bye bye'
# 0	1.00	b"landlord like mp' though that' go easi :-("
# 0	1.00	b'look old photo get sad :('
# 0	1.00	b'oh :( hope everyth okay'
# 0	1.00	b"want want want follow want want want that' crazi :( pleas love (:  "
# 0	1.00	b'bullshit :('
# 0	1.00	b'nugget fri :-('
# 0	1.00	b'love warrior :-('
# 0	1.00	b'tire eat :('
# 0	1.00	b'dame assign :('
# 0	1.00	b"i'm watch gossip girl make sad :("
# 0	1.00	b'tomorrow :('
# 0	1.00	b'still realli miss purpl hair tie :('
# 0	1.00	b"can't deal match unless ishii fuck everyth :("
# 0	1.00	b'clara yile left :('
# 0	1.00	b'whatev stil l young >:-('
# 0	1.00	b'last chanc :('
# 0	1.00	b':('
# 0	1.00	b'look like cri look like cri bit :('
# 0	1.00	b'come onlin follow peopl :/ z wrong u ignor sidharth :( :('
# 0	1.00	b"lol i'm lazi learn ps :("
# 0	1.00	b"sleep i'm"
# 0	1.00	b'bad day :-('
# 0	1.00	b'tagal :('
# 0	1.00	b'oh ndabenhl :-( pleas let us know feel way sa'
# 0	1.00	b"i'v got one poorli doggi :("
# 0	1.00	b'repli pleas antag :('
# 0	1.00	b'window 7 :('
# 0	1.00	b"well i'm p 41 8 page note thu far :-( i'v read twice"
# 0	1.00	b'want kyli jenner cloth :('
# 0	1.00	b"ye unfortun done whole troubleshoot box i'm still issu :("
# 0	1.00	b"miss convo' bad damn :("
# 0	1.00	b'dem free tix big bang concert :('
# 0	1.00	b'your gonna guess what insid box :('
# 0	1.00	b'idk :-( mayb think boob fun play'
# 0	1.00	b'jahat :('
# 0	1.00	b"we'r sorri :( longer abl access site automat redirect local site"
# 0	1.00	b'mad gigi dream hang didnt want talk :('
# 0	1.00	b'carter deserv hate :( deserv singl corn chip deserv two corn chip'
# 0	1.00	b"nnnooo cz he' daddi gorilla anymor ... :("
# 0	1.00	b'still 6 hour work left omg :('
# 0	1.00	b'link miss hbm :('
# 0	1.00	b"freak humid think never get use even i'm 100 japanes :("
# 0	1.00	b'school work :('
# 0	1.00	b":( longer admir consist jason shackell' hair podcast"
# 0	1.00	b"envi peopl get meet pictur laura taylor lana etc they'r lucki meet babi :("
# 0	1.00	b'want sa bday ko :( :( :( <3'
# 0	1.00	b':-( pleas notic gonna spam u till u follow babi'
# 0	1.00	b'kik twer 782 kik kikhorni lesbian hornykik girl countrymus hornykik :('
# 0	1.00	b'need hug :('
# 0	1.00	b'word explain much miss hope know :('
# 0	1.00	b'oh gfriend perform rn :('
# 0	1.00	b'ok :-( w hahaahahahaha'
# 0	1.00	b'sm1 bad mean got mutil robot shot wall know could destroy ... >:('
# 0	1.00	b'dare :('
# 0	1.00	b'good morn twitter friend hope amaz day freakin tire need sleep :('
# 0	1.00	b' haestarr  :('
# 0	1.00	b'wish help :('
# 0	1.00	b'good alway  fli back today though :('
# 0	1.00	b'need car function car :('
# 0	1.00	b'wish twitter would support audio record would send yall snippet amaz :('
# 0	1.00	b'et brotherhood steel :('
# 0	1.00	b':-( pleas notic mefd'
# 0	1.00	b'miss diana :('
# 0	1.00	b"master figur turn led gold we'r doom :("
# 0	1.00	b"want pull nighter i'm sleepi alreadi :("
# 0	1.00	b'ever wanna sleeep :( let mee'
# 0	1.00	b"oh allow vote teen choic award :( said i'm area"
# 0	1.00	b'want icon selfi jack :('
# 0	1.00	b':-( pleas notic meowkd'
# 0	1.00	b"twitter turn much complic can't find trend :("
# 0	1.00	b"right i'm tire :( good night alli love  "
# 0	1.00	b' wish channel watch :( usual watch onlin laptop anymor :/'
# 0	1.00	b'rude :('
# 0	1.00	b"would want peopl understand busi daili schedul  c'mon guy bare even get 5 hour sleep :-("
# 0	1.00	b':( kill'
# 0	1.00	b'think she busi :('
# 0	1.00	b"swimmer' ear kasi :("
# 0	1.00	b'want bday answer pleas  idk leh :( b'
# 0	1.00	b'yeahhh ... :( tht corner b rememb alway coz gg ... :( n bb didnot show th clip episod :('
# 0	1.00	b'releas onlin album know :('
# 0	1.00	b':-( pleas notic h'
# 0	1.00	b'   thank san  wanna chang avi usanel :('
# 0	1.00	b'sad day nathan :('
# 0	1.00	b'noo sad time :( rubi replac shuffl act'
# 0	1.00	b'got excit micha rt fave tweet creep :-('
# 0	1.00	b"anyon wanna friend i'm lone girl england bore hell throughout summer holiday .. :("
# 0	1.00	b'home alon :('
# 0	1.00	b'whose idea ave tripl busi lectur friday afternoon 2-5 :('
# 0	1.00	b':('
# 0	1.00	b"that' damn lie :("
# 0	1.00	b"i'm allow give blood :("
# 0	1.00	b'six month ago bottom jaw second tooth back broke quarter ... thing chew gum :('
# 0	1.00	b'go sleep 12 last night rn im :('
# 0	1.00	b':-( pleas notic'
# 0	1.00	b'twitter decid take featur away :-('
# 0	1.00	b"i'm okay tire plan go today rain :("
# 0	1.00	b'that push emoji give soni five :-( :-( :-( :-( :-( :-('
# 0	1.00	b'late :( followmeaaron'
# 0	1.00	b'tzelumxoxo dont realli use line ipod :-( use whatsapp actual'
# 0	1.00	b'buy someth drank caus noth :('
# 0	1.00	b"slept day can't sleep :("
# 0	1.00	b':-( pleas notic mew'
# 0	1.00	b'peopl :( r u'
# 0	1.00	b'indic sm receiv :('
# 0	1.00	b'got regular :('
# 0	1.00	b'kik ouliv 70748 kik kikmenow photo babe loveofmylif brasileirao viernesderolenahot :('
# 0	1.00	b'feel u :('
# 0	1.00	b'longmorn 30 suppos replac tobermori 32 ... begin strong tail miss :('
# 0	1.00	b'wait love recuerda tanto bath :('
# 0	1.00	b'sun gone :('
# 0	1.00	b'die movi :('
# 0	1.00	b'shit .. suggest na suck muna :( know hard nurs import right'
# 0	1.00	b':(  issu'
# 0	1.00	b'hrryok fact harri still hold mom  hand :( :( :('
# 0	1.00	b'much await excit go bore friday weekend :('
# 0	1.00	b':( asleep'
# 0	1.00	b'babi :('
# 0	1.00	b'hp curs child book play :('
# 0	1.00	b'ur crazi af u want hurt urslef edit stuff lime u know shit aint real :( '
# 0	1.00	b'omg r hahah :( omg debut mo na next year :('
# 0	1.00	b'wish could meet boy one day :('
# 0	1.00	b'tri keep hous use buy truckload miss 13 favour :('
# 0	1.00	b':-('
# 0	1.00	b"best spectat sail uk w'end bbc show highlight :(  fli  foil ac45 catamaran"
# 0	1.00	b'mayb :('
# 0	1.00	b'guy add kik peli 829 kik kikmenow fuck model amateur elfindelmundo sextaatequemfimseguesdvcomvalentino :('
# 0	1.00	b"could pl take care server befor send valu long can't get :("
# 0	1.00	b'love babi sweet cinnamon best :('
# 0	1.00	b'comfort :('
# 0	1.00	b'mtap tomorrow mean sleep earli tonight :-('
# 0	1.00	b'peng bestfriend :( psygustokita'
# 0	1.00	b'frozen bagu emang :('
# 0	1.00	b'wish could dm cute thing :( prefer cute kitten puppi'
# 0	1.00	b'still get paper engg go back cmc mage okay :('
# 0	1.00	b"that' kind dumb statement like moodsw like make tweet say hate termin diseas :( like wow uniqu"
# 0	1.00	b'slow news day :-('
# 0	1.00	b':-( pleas notic men'
# 0	1.00	b'watch us :('
# 0	1.00	b'regret regret :('
# 0	1.00	b'even though seen whole peep show multipl time noth could prepar netflix remov seri 1 7 ... :('
# 0	1.00	b"that' said ... :("
# 0	1.00	b'way get bandana :('
# 0	1.00	b"hi oh :( let' take look pleas chat us"
# 0	1.00	b'sad moment u r leav two day :('
# 0	1.00	b':-( pleas notic mef'
# 0	1.00	b'rebound run away alreadi pooor :('
# 0	1.00	b"lol 2am last night face though peopl think i'm perpetu piss sad b c rest bitchfac :("
# 0	1.00	b':-( miss fun'
# 0	1.00	b':-( pleas notic z'
# 0	1.00	b'peopl wish birthday :('
# 0	1.00	b':( world aw'
# 0	1.00	b'let feel like complet shit :('
# 0	1.00	b"uh huh :( two time i'm super clever like"
# 0	1.00	b':( bitch realli went'
# 0	1.00	b'fave unfollow :(  '
# 0	1.00	b'realli want visit iceland :('
# 0	1.00	b'zayn_come_back_we_miss_y <3 <3 :( much'
# 0	1.00	b'starv :-('
# 0	1.00	b'bc feel creepi today pmsl mianh milkeu :('
# 0	1.00	b'wanna meet boy :('
# 0	1.00	b'internet total bitch'
# 0	1.00	b'lrt bambam like soda :( meant :('
# 0	1.00	b'1 :('
# 0	1.00	b'wish could go shop whole weekend taken :( annoy'
# 0	1.00	b'peopl usual stay asleep wtf :('
# 0	1.00	b'cheer :-('
# 0	1.00	b'payback like video tri help get kit kat :('
# 0	1.00	b"i'm even tire :-("
# 0	1.00	b'one come smoke :('
# 0	1.00	b'87000 jobe deliveri pl :('
# 0	1.00	b'happi birthday be enjoy day beb love miss sooo muchi :( see soon sana     '
# 0	1.00	b'cuti :('
# 0	1.00	b"alway fall asleep earli i'm text someon :("
# 0	1.00	b'say icecream avail :('
# 0	1.00	b"ask go bathroom :-( i'm realli enjoy show though"
# 0	1.00	b'lagg much certain peopl :('
# 0	1.00	b'need clear head :('
# 0	1.00	b"babi went back sleep i'm bore :-("
# 0	1.00	b'ughh got noth pain :('
# 0	1.00	b'laper banget :('
# 0	1.00	b"naw :( deep dream novel hope there'd invis page beast scuttl around there' worm track"
# 0	1.00	b'bauuukkk :('
# 0	1.00	b"bad guy cant attend today' music bank :("
# 0	1.00	b'worri :-('
# 0	1.00	b' mine ... damnnn finee omaigoshhh :('
# 0	1.00	b'care muslim :('
# 0	1.00	b':('
# 0	1.00	b'jessica call quit power ab 5:15 :-('
# 0	1.00	b'lost us friend ... :( one start argument'
# 0	1.00	b'hope fun vidcon rlli bum couldnt go :( love sunshin   '
# 0	1.00	b"yepp .. i'm get bore :("
# 0	1.00	b'last night good :(    '
# 0	1.00	b'follow :('
# 0	1.00	b'feelin sick :('
# 0	1.00	b'want biscuit slather chocol definit tax boo :('
# 0	1.00	b'investig answer especi pup die within free insur period :('
# 0	1.00	b'jsut end :('
# 0	1.00	b'heart hurt real bad :('
# 0	1.00	b'aw :('
# 0	1.00	b'follow pl :('
# 0	1.00	b"i'm realist ... :("
# 0	1.00	b'happi princess today :( sigh get work done x purpl princess edit'
# 0	1.00	b'babee :( demn hotaisndonwyvauwjoqhsjsnaihsuswtf'
# 0	1.00	b'someth wrong :('
# 0	1.00	b'word explain way miss :('
# 0	1.00	b'think need 2 year train beat record sia :('
# 0	1.00	b'niram ya geng :( fikri anna 6 other tirtagangga hotel '
# 0	1.00	b'char im realli sick :( one font size 8 minion float font size 12 sick kid pl :('
# 0	1.00	b'bestfriend like ed plsss :('
# 0	1.00	b'riprishikeshwari soul rest peac :('
# 0	1.00	b':( unfollow like 300 peopl caus follow 1k peopl difficult'
# 0	1.00	b'enough time listen artist music :-('
# 0	1.00	b'take ice creamist pleasee :('
# 0	1.00	b'alway go terribl time :('
# 0	1.00	b':-( challeng though pleas check fb page entri rather substitut thank'
# 0	1.00	b"can't even see hyungwon :("
# 0	1.00	b'tell pl eat :-('
# 0	1.00	b'that life get call peopl havent seen 20 year alway favour'
# 0	1.00	b'omg :( everi time would complain skin mom everyon get pimpl like although'
# 0	1.00	b'letsfootbal atk greymind 43 break news chri gayl say cricket 2-3 month due back surgeri :( cplt 20 cp '
# 0	1.00	b"miss hannah montana that' raven sooo much :-("
# 0	1.00	b'want rt :('
# 0	1.00	b'gonna okay love :('
# 0	1.00	b'awh :-(  stay '
# 0	1.00	b'last full night greec :( opu inner pleasur'
# 0	1.00	b'disappoint hear especi invest one :-('
# 0	1.00	b'ye :( bbq attend'
# 0	1.00	b'work :('
# 0	1.00	b'three 190 row 33 :('
# 0	1.00	b'throat hurt bad :('
# 0	1.00	b'lolliv :('
# 0	1.00	b'im watch disney channel :('
# 0	1.00	b'nobodi pick one right :('
# 0	1.00	b'someon gift :( calibraskaep need bad'
# 0	1.00	b'lol got split hard lol singl singl split collat spilt singl singl spilt singl split singl singl collat :('
# 0	1.00	b'hope feel better jay :('
# 0	1.00	b'ye mani time :( quitkarwaoyaaro'
# 0	1.00	b'stu deactiv :('
# 0	1.00	b'disappoint :( never ever lucki handl jabongatpumaurbanstamped'
# 0	1.00	b'hello need 2.5 g2a code pl :('
# 0	1.00	b'thesi thesi thesi thesi thesi thesi thesi thesi thesi thesi sherep nemen ng behey ke :('
# 0	1.00	b'deactiv acc :( otwolgrandtrail'
# 0	1.00	b'still sad kick epic motherfuck :('
# 0	1.00	b'realli want anoth tattoo :('
# 0	1.00	b'someon get mad reec vm tomorrow pleas never one :('
# 0	1.00	b'deth deth dont leav :('
# 0	1.00	b'true :-('
# 0	1.00	b"let' go  cast vote got 7 today :("
# 0	1.00	b'someon hug pl :('
# 0	1.00	b'omg :( gonna happen yeah wish ..'
# 0	1.00	b':( lest gp get'
# 0	1.00	b'aww :( catch departur'
# 0	1.00	b'appar isnt :('
# 0	1.00	b'miss day :( toothsensit'
# 0	1.00	b'unavail :('
# 0	1.00	b"mean can't wipe :-("
# 0	1.00	b'found flight home 13 hour long :('
# 0	1.00	b'ugh yuck :( make sure rest next two day'
# 0	1.00	b'omg sad birthday sorri didnt send someth ystrday ill later cuz dont phone :('
# 0	1.00	b'seolhyun isnt first ep she film drama :('
# 0	1.00	b'sorri :('
# 0	1.00	b'alway get like 5 4 piec spici nugget :('
# 0	1.00	b'im sooo hungri though :('
# 0	1.00	b'thigh cramp :-('
# 0	1.00	b'fellow morn owl sure notic sun alreadi rise bit later ... sign winter come :('
# 0	1.00	b'nowher near tire :('
# 0	1.00	b'hot :('
# 0	1.00	b"dude :( i'm scare lol"
# 0	1.00	b'rain whole day mumbai  feel like work :('
# 0	1.00	b"best get littl ladi pj' need go wallpap mom :( realli cba today"
# 0	1.00	b'ye pl far need :('
# 0	1.00	b'even know could get hotter fml :('
# 0	1.00	b"aw bless made smile i'm miss :("
# 0	1.00	b'hi life :('
# 0	1.00	b'mood whole day :-('
# 0	1.00	b'almost done park rec :( lol'
# 0	1.00	b'u come back :('
# 0	1.00	b"hi we'r sorri hear :( log abl see inform need"
# 0	1.00	b'gotdamn :-('
# 0	1.00	b'want phone baaack :('
# 0	1.00	b'honest miss dubai dubai miss want come back :('
# 0	1.00	b'final get star driver srw mobag :('
# 0	1.00	b'sad reason suck u dunno stop sad u gotta chill ur room listen music b alon :('
# 0	1.00	b'stream pass melon pleas stream much  digit bad :('
# 0	1.00	b'snapchat jannygreen 18 snapchat kiksex hot teen lgbt goodmus sexcam :('
# 0	1.00	b'aw :( stroke'
# 0	1.00	b'first saw gnr open alic cooper famou parti backstag alic r slash :('
# 0	1.00	b"tag  i'm sorri lot music prolli know half :( also"
# 0	1.00	b'24 hour enough :('
# 0	1.00	b'awww poor bunni :('
# 0	1.00	b'stress let go :('
# 0	1.00	b'wish blooper :('
# 0	1.00	b'love u fuck know :('
# 0	1.00	b'yeah :('
# 0	1.00	b'noth though :('
# 0	1.00	b"aww i'v alreadi left would come said hey seen sooner :( good night x"
# 0	1.00	b'weird :('
# 0	1.00	b'sr financi analyst expedia inc bellevu wa financ expediajob job job hire'
# 0	1.00	b'serious :('
# 0	1.00	b'tri make prison style alcohol fail badli end massiv dose shit ... :('
# 0	1.00	b'fair still look cute :('
# 0	1.00	b'hi love u :( :('
# 0	1.00	b'overli attach :('
# 0	1.00	b"m' voic :( lord help"
# 0	1.00	b'want bandana bottl set huhuh :('
# 0	1.00	b"can't sleep bc heartburn :-("
# 0	1.00	b'meet steven kid listen :('
# 0	1.00	b"i'm fuck jealou everyon holiday :("
# 0	1.00	b'terribl thing doin yoga work stop start ... awalmu njareeem :('
# 0	1.00	b'nooo last day today :('
# 0	1.00	b'care maggi psycho bitch want kill take two day vacat twitter :( wahhh'
# 0	1.00	b'realli look forward work tonight though :('
# 0	1.00	b'miss abudhabi :('
# 0	1.00	b'go home blue :-( back monday hiby social action plan shareyoursumm'
# 0	1.00	b'pro soccer play would cool :('
# 0	1.00	b'wish b8 strong :('
# 0	1.00	b"hey girl must.b dairi produxt want can't lactos intoler :("
# 0	1.00	b'midland ye thank depress weather forecast word rain mention sever time :-('
# 0	1.00	b'cri :('
# 0	1.00	b'old one day ... :('
# 0	1.00	b"liter spent day yesterday sleep bed i'm still absolut fuck knacker today :("
# 0	1.00	b'new sandra bland footag realli ice cake .. heartbreak drag lifeless bodi polic car :('
# 0	1.00	b'knowww :('
# 0	1.00	b"we'r sorri feel way shell :( regularli review price offer best"
# 0	1.00	b'sorri hear jess :( quickest way call 44 7782 333 333 add account within 72 hour'
# 0	1.00	b'pengen box :( '
# 0	1.00	b'girlll u hear abt possibl tsunami us west indi im island im afraid lol :('
# 0	1.00	b'snap :('
# 0	1.00	b'would love see w nick pick one waist tv time never work anyway :('
# 0	1.00	b'hulk hogan news racial tirad :( thought couldnt stoop lower role thunder paradis'
# 0	1.00	b'sorri forget import day huhu fight im sorri :('
# 0	1.00	b"break habit lifetim ... i'm play call duti game .. :("
# 0	1.00	b'apolog annoy much snapchat :('
# 0	1.00	b'adult take thing seriou realli miss kid :('
# 0	1.00	b'facad democraci drop quickli :('
# 0	1.00	b'confus brat :('
# 0	1.00	b"someon come i'll make popcorn watch movi pl cuddl :("
# 0	1.00	b'final home drive sinc 5am :('
# 0	1.00	b"tb mr o' class :("
# 0	1.00	b'bade fursat se usey banaya hai usey uppar waal ney afso hums dur hai wo :('
# 0	1.00	b"oh realli :( saw gif post seen realli happi mayb peopl who'd happi naruhina"
# 0	1.00	b"can't :("
# 0	1.00	b'that english namee :( haiqal isnt english name rememb'
# 0	1.00	b'want dont paypal :('
# 0	1.00	b"that' 360hr summer end ... huhuhu miss picc lot :("
# 0	1.00	b'heart hurt :('
# 0	1.00	b'instor card expir june havent sent new one :('
# 0	1.00	b'mcountdown pre-vot begin 5th place :('
# 0	1.00	b'felt bad iren forgot go say :('
# 0	1.00	b"wow that' great what' usernam :("
# 0	1.00	b'minho still injur :( get well oppa miss <3'
# 0	1.00	b"can't even deliv ice cream tri twice ice cream van busi :("
# 0	1.00	b'want durian strudel :('
# 0	1.00	b'vidcon :('
# 0	1.00	b'guy add snapchat amargolonnard snapchat kikmeboy sexi french dirtykik newmus sexcam :('
# 0	1.00	b'u chang u say chang tsk :('
# 0	1.00	b'damn .. wish could sleep :('
# 0	1.00	b'like join marin :-('
# 0	1.00	b"i'm sad yall thought real :("
# 0	1.00	b"i'm go :( kailan ba may tix ka"
# 0	1.00	b'alreadi kill tho :('
# 0	1.00	b'hotel dog pretti sad brother sister got separ :('
# 0	1.00	b'miss cute someon la :('
# 0	1.00	b'payday feel like payhour gone bill immedi :('
# 0	1.00	b"lmao :( natur hair i'v seen ugli swear"
# 0	1.00	b'nope :( best place get first pre-ord amazon'
# 0	1.00	b'sunday littl abl get much year busi :( look great tho'
# 0	1.00	b'fwm :('
# 0	1.00	b"what' wrong :("
# 0	1.00	b'miss guppi :-('
# 0	1.00	b'go away ... must go dentist :( poorkid'
# 0	1.00	b'thank lack time problem :('
# 0	1.00	b'get misunderstood :('
# 0	1.00	b'ur cat super nice cuddli suddenli scratch tri bite :( like trust anymor'
# 0	1.00	b'hit thumb :('
# 0	1.00	b'almost got see cute ankl sock :('
# 0	1.00	b'honestli point care compens want abl play bf :('
# 0	1.00	b'song :('
# 0	1.00	b'awww babi :( '
# 0	1.00	b'sleep last night n help wake 8 morn n phone even charg :('
# 0	1.00	b'pleas tell everyon didnt go vidcon :('
# 0	1.00	b'need like tell na na okay lang :('
# 0	1.00	b'follow back :('
# 0	1.00	b'heart current tortur :( lol wat'
# 0	1.00	b'femal student kill cast love kirkiri :('
# 0	1.00	b"i'v run bread feel well enough make :("
# 0	1.00	b'dream :('
# 0	1.00	b":( broken heart that' phase worri"
# 0	1.00	b'stop sour :( suit  '
# 0	1.00	b'wonho remind someon >:( cant put finger'
# 0	1.00	b'wont work today feel ill :( tummi bug xx'
# 0	1.00	b'last day beach :-( :-( :-( ...'
# 0	1.00	b'rain :('
# 0	1.00	b'visual studio 2015 got switch alreadi broke lot code :('
# 0	1.00	b"serious unfair ask question readi answer win :( ='( busi ask question"
# 0	1.00	b'mission bear fail :('
# 0	1.00	b':-( ugli af :-('
# 0	1.00	b'pap spirit anim  dont :('
# 0	1.00	b"total ship danzel i'm craft can't go vidcon would sell soul devil get hug dan phil :("
# 0	1.00	b'hate :('
# 0	1.00	b"he' gona miss sheff utd york probabl wait visa leav gim 1 friendli bet start season bench :("
# 0	1.00	b'lead us gone :('
# 0	1.00	b'   mess :('
# 0	1.00	b'ironi harm .. :('
# 0	1.00	b'miss much :( xxx'
# 0	1.00	b'motiv :('
# 0	1.00	b'point yolo sort die lactos ... ugh like 3 month pregnant bloat :('
# 0	1.00	b'realli sorri cant find imag mention :('
# 0	1.00	b'im get olli tweet notif :('
# 0	1.00	b'go home tomorrow :-('
# 0	1.00	b"bad i'm poor :("
# 0	1.00	b'team kill :('
# 0	1.00	b'way :('
# 0	1.00	b"i'm inact :("
# 0	1.00	b':( world alterni kill realli sad leav place everyon die'
# 0	1.00	b'everyon gonna talk abt rat boy today bc :('
# 0	1.00	b'earth assum rain london like influenc overal warm dri past week continent europ :('
# 0	1.00	b'rememb fab four 24 hour call damn miss much :('
# 0	1.00	b'  r u sure u want b r u h bare surviv w tank top :('
# 0	1.00	b'thirsti :('
# 0	1.00	b'konami polici pe pc version happen version :('
# 0	1.00	b'sound effect :('
# 0	1.00	b'blame ranti :('
# 0	1.00	b'ummm ok new develop :('
# 0	1.00	b"guy never :(  aw sorri we'r realli bust atm .. shall back soon"
# 0	1.00	b'bad :( like video mani pervers'
# 0	1.00	b'first time go school without bracelet :( feel odd'
# 0	1.00	b"can't fall back asleep :("
# 0	1.00	b'im twin follow back bylfnnz :('
# 0	1.00	b'unfair .. u ban film pakistan :('
# 0	1.00	b'want one :('
# 0	1.00	b'feel sick :('
# 0	1.00	b"hmmm 10 min get train i'm current 15 min away :( failsatlif"
# 0	1.00	b"i'm hungri :("
# 0	1.00	b'want birthday alreadi :('
# 0	1.00	b'complet agre press :('
# 0	1.00	b'im super duper tire :('
# 0	1.00	b'bore time :( know ...'
# 0	1.00	b'ill soon promis :( waaah'
# 0	1.00	b'wanna chang avi usanel :('
# 0	1.00	b'puppi broke foot :('
# 0	1.00	b"where' jaebum babi pictur :("
# 0	1.00	b'mr ahmad maslan cook :('
# 0	1.00	b'hull support expect misser week :-('

# %% [markdown]
# <a name='6'></a>
# ## 6 - Predict with your own Tweet
#
# In this part you can predict the sentiment of your own tweet.

# %%
# Test with your own tweet - feel free to modify `my_tweet`
my_tweet = 'I am happy because I am learning :)'

p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print(p)
# Out:
# 2.168743348944261

# %% [markdown]
# Congratulations on completing this assignment. See you next week!
