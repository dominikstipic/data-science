# %%
# run this cell to import nltk
import nltk
from os import getcwd
import numpy as np
import pandas as pd
from nltk.corpus import twitter_samples

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from collections import Counter 
import re

def remove_special_characters(text):
    pattern = r'[^a-zA-Z\s]'
    cleaned_text = re.sub(pattern, '', text)
    return cleaned_text

def is_link(word):
    return word.startswith("http")

def flatten(words):
    result = []
    for ws in words:
        for w in ws:
            result.append(w)
    return result

def process_tweet(tweet, stopwords):
    words = tweet.split()
    mask = lambda w : (w not in stopwords and not is_link(w) and not w.startswith("#") and not w.startswith("@") and len(w) > 1)
    words = [remove_special_characters(w) for w in words if mask(w)]
    words = [w for w in words if w != ""]
    porter_stemmer = PorterStemmer()
    stemmed_words = [porter_stemmer.stem(word) for word in words]
    return stemmed_words

def normalize(X):
    X[:,0] = (X[:,0] - X[:,0].mean()) / X[:,0].std()
    X[:,1] = (X[:,1] - X[:,1].mean()) / X[:,1].std()
    return X

    
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')    
stopwords = stopwords.words('english')

ws = [process_tweet(w, stopwords) for w in all_positive_tweets]
ws = [process_tweet(w, stopwords) for w in all_negative_tweets]
positive_ws = flatten(ws)
negative_ws = flatten(ws)
all_words = positive_ws + negative_ws



ds = dict(Counter(all_words))
ds = {k:np.array([v, all_words.index(k)]) for k,v in ds.items()}
X = np.array(list(ds.values())).astype(float)

X  = normalize(X)

zeros = [0]*(len(X)//2)
ones  = [1]*(len(X)//2)
labels = np.array([*ones, *zeros])
ys = labels.reshape(-1,1)
y = ys.astype(int)
# Out:
#   Cell In[6], line 30
#     def normalize()
#                    ^
# SyntaxError: expected ':'

# %%
ds
# Out:
# {'hopeless': array([4, 0]),
#  'tmr': array([6, 1]),
#  'everyth': array([34,  2]),
#  'kid': array([40,  3]),
#  'section': array([6, 4]),
#  'ikea': array([2, 5]),
#  'cute': array([86,  6]),
#  'shame': array([36,  7]),
#  'im': array([950,   8]),
#  'nearli': array([6, 9]),
#  'month': array([44, 10]),
#  'that': array([310,  11]),
#  'heart': array([54, 12]),
#  'slide': array([ 2, 13]),
#  'wast': array([10, 14]),
#  'basket': array([ 2, 15]),
#  'ketchburn': array([ 2, 16]),
#  'hate': array([114,  17]),
#  'japanes': array([ 8, 18]),
#  'call': array([58, 19]),
#  'bani': array([ 4, 20]),
#  'me': array([476,  21]),
#  'dang': array([ 4, 22]),
#  'start': array([86, 23]),
#  'next': array([80, 24]),
#  'week': array([114,  25]),
#  'work': array([264,  26]),
#  'oh': array([184,  27]),
#  'god': array([30, 28]),
#  'babi': array([94, 29]),
#  'face': array([40, 30]),
#  'make': array([204,  31]),
#  'smile': array([20, 32]),
#  'neighbour': array([ 2, 34]),
#  'motor': array([ 2, 35]),
#  'ask': array([58, 36]),
#  'said': array([66, 37]),
#  'updat': array([22, 39]),
#  'search': array([ 6, 40]),
#  'whytahuodyy': array([ 2, 41]),
#  'sialan': array([ 2, 42]),
#  'athabasca': array([ 2, 43]),
#  'glacier': array([ 2, 44]),
#  'realli': array([264,  45]),
#  'good': array([200,  46]),
#  'mampg': array([ 4, 47]),
#  'idea': array([20, 48]),
#  'never': array([114,  50]),
#  'go': array([446,  51]),
#  'meet': array([64, 52]),
#  'mare': array([ 2, 53]),
#  'ivan': array([ 2, 54]),
#  'happi': array([50, 55]),
#  'trip': array([20, 56]),
#  'keep': array([68, 57]),
#  'safe': array([10, 58]),
#  'see': array([250,  59]),
#  'soon': array([90, 60]),
#  'tire': array([100,  62]),
#  'hahahah': array([ 6, 63]),
#  'with': array([24, 64]),
#  'knee': array([ 4, 65]),
#  'replac': array([ 8, 66]),
#  'get': array([466,  67]),
#  'amp': array([188,  68]),
#  'day': array([300,  69]),
#  'ouch': array([ 6, 70]),
#  'relat': array([ 4, 71]),
#  'sweet': array([14, 72]),
#  'n': array([ 2, 73]),
#  'sour': array([ 4, 74]),
#  'kind': array([22, 75]),
#  'bipolar': array([ 2, 76]),
#  'peopl': array([150,  77]),
#  'life': array([64, 78]),
#  'cuz': array([ 8, 79]),
#  'full': array([32, 81]),
#  'them': array([24, 82]),
#  'pleass': array([ 4, 83]),
#  'sure': array([62, 85]),
#  'tho': array([54, 86]),
#  'feel': array([314,  87]),
#  'stupid': array([16, 88]),
#  'cant': array([460,  89]),
#  'seem': array([30, 90]),
#  'grasp': array([ 2, 91]),
#  'basic': array([ 4, 92]),
#  'digit': array([16, 93]),
#  'paint': array([ 6, 94]),
#  'noth': array([50, 95]),
#  'ive': array([170,  96]),
#  'research': array([ 2, 97]),
#  'help': array([106,  98]),
#  'lord': array([  4, 100]),
#  'lone': array([ 18, 102]),
#  'someon': array([118, 103]),
#  'talk': array([ 84, 104]),
#  'guy': array([124, 105]),
#  'girl': array([ 52, 106]),
#  'no': array([134, 107]),
#  'assign': array([ 10, 108]),
#  'project': array([  6, 109]),
#  'want': array([492, 111]),
#  'play': array([ 96, 112]),
#  'video': array([ 40, 113]),
#  'gameswatch': array([  2, 114]),
#  'movi': array([ 48, 115]),
#  'choreograph': array([  2, 117]),
#  'hard': array([ 70, 118]),
#  'email': array([ 20, 119]),
#  'link': array([ 24, 120]),
#  'still': array([248, 121]),
#  'say': array([126, 122]),
#  'longer': array([ 22, 123]),
#  'avail': array([ 26, 124]),
#  'cri': array([ 92, 125]),
#  'bc': array([100, 126]),
#  'miss': array([600, 127]),
#  'mingm': array([  2, 128]),
#  'much': array([278, 129]),
#  'sorri': array([296, 130]),
#  'mom': array([ 30, 131]),
#  'far': array([ 36, 132]),
#  'away': array([ 56, 133]),
#  'were': array([ 68, 134]),
#  'truli': array([ 10, 135]),
#  'flight': array([ 12, 138]),
#  'friend': array([ 76, 139]),
#  'happen': array([102, 142]),
#  'sad': array([234, 144]),
#  'dog': array([ 34, 146]),
#  'peed': array([  2, 147]),
#  'bag': array([ 16, 148]),
#  'so': array([262, 149]),
#  'take': array([ 98, 151]),
#  'doushit': array([  2, 152]),
#  'late': array([ 54, 153]),
#  'it': array([324, 154]),
#  'suck': array([ 46, 155]),
#  'sick': array([ 86, 157]),
#  'plan': array([ 34, 158]),
#  'first': array([ 54, 161]),
#  'gundam': array([  2, 162]),
#  'night': array([ 92, 163]),
#  'nope': array([ 12, 164]),
#  'my': array([234, 165]),
#  'dollar': array([  2, 166]),
#  'listen': array([ 36, 167]),
#  'back': array([242, 168]),
#  'old': array([ 34, 169]),
#  'show': array([ 52, 170]),
#  'i': array([ 14, 171]),
#  'know': array([264, 172]),
#  'weird': array([ 20, 174]),
#  'just': array([ 62, 175]),
#  'got': array([202, 176]),
#  'leav': array([ 82, 177]),
#  'might': array([ 22, 178]),
#  'give': array([ 72, 179]),
#  'up': array([ 38, 180]),
#  'pale': array([  4, 182]),
#  'imit': array([  2, 183]),
#  'went': array([ 64, 184]),
#  'sea': array([  2, 185]),
#  'massiv': array([  8, 186]),
#  'fuck': array([112, 187]),
#  'rash': array([  2, 188]),
#  'bodi': array([ 24, 189]),
#  'pain': array([ 40, 190]),
#  'thing': array([102, 191]),
#  'ever': array([ 62, 192]),
#  'home': array([126, 195]),
#  'hi': array([ 70, 196]),
#  'whi': array([138, 197]),
#  'absent': array([  2, 198]),
#  'gran': array([  4, 200]),
#  'she': array([ 34, 202]),
#  'knew': array([ 12, 203]),
#  'care': array([ 38, 204]),
#  'tell': array([ 52, 205]),
#  'same': array([ 30, 206]),
#  'love': array([302, 210]),
#  'wish': array([180, 214]),
#  'there': array([ 82, 215]),
#  'would': array([140, 216]),
#  'be': array([ 30, 217]),
#  'sequel': array([  2, 218]),
#  'busi': array([ 56, 219]),
#  'sa': array([ 30, 220]),
#  'school': array([ 64, 221]),
#  'time': array([332, 223]),
#  'yah': array([  6, 225]),
#  'xx': array([ 34, 226]),
#  'ouucchhh': array([  2, 227]),
#  'one': array([300, 228]),
#  'wisdom': array([  4, 229]),
#  'teeth': array([ 12, 230]),
#  'come': array([184, 231]),
#  'frighten': array([  2, 232]),
#  'case': array([ 12, 233]),
#  'pret': array([  2, 237]),
#  'wkwkwwlkjhope': array([  2, 238]),
#  'verfi': array([  2, 239]),
#  'activ': array([ 12, 240]),
#  'forget': array([ 16, 241]),
#  'follow': array([526, 242]),
#  'member': array([ 12, 243]),
#  'thank': array([214, 244]),
#  'join': array([ 16, 245]),
#  'goodby': array([ 28, 246]),
#  'youv': array([  2, 247]),
#  'chain': array([  2, 249]),
#  'sentirs': array([  2, 251]),
#  'incompleta': array([  2, 252]),
#  'okay': array([ 74, 253]),
#  'but': array([134, 254]),
#  'wednesday': array([ 10, 256]),
#  'marvel': array([  2, 257]),
#  'not': array([ 78, 258]),
#  'how': array([ 60, 259]),
#  'thwart': array([  2, 260]),
#  'awh': array([  6, 261]),
#  'what': array([108, 262]),
#  'chanc': array([ 30, 263]),
#  'zant': array([  2, 264]),
#  'we': array([102, 265]),
#  'need': array([214, 266]),
#  'someth': array([ 56, 267]),
#  'when': array([ 64, 268]),
#  'birthday': array([ 46, 269]),
#  'worst': array([ 28, 270]),
#  'part': array([ 22, 271]),
#  'bad': array([132, 274]),
#  'audraesar': array([  2, 275]),
#  'all': array([ 52, 276]),
#  'sushi': array([  6, 277]),
#  'pic': array([ 28, 278]),
#  'tl': array([ 16, 279]),
#  'drive': array([ 32, 280]),
#  'craaaazzyy': array([  4, 281]),
#  'pop': array([  6, 284]),
#  'like': array([442, 285]),
#  'helium': array([  2, 286]),
#  'balloon': array([  2, 287]),
#  'california': array([  4, 288]),
#  'power': array([ 12, 289]),
#  'influenti': array([  2, 290]),
#  'air': array([  6, 291]),
#  'pollut': array([  2, 292]),
#  'watchdog': array([  2, 293]),
#  'califor': array([  2, 294]),
#  'elhaida': array([  2, 296]),
#  'rob': array([  4, 297]),
#  'juri': array([  2, 298]),
#  'came': array([ 32, 299]),
#  'th': array([ 42, 300]),
#  'televot': array([  2, 301]),
#  'idaho': array([  4, 302]),
#  'restrict': array([  4, 303]),
#  'fish': array([  4, 304]),
#  'despit': array([  4, 305]),
#  'region': array([  4, 306]),
#  'droughtlink': array([  2, 307]),
#  'dieof': array([  2, 308]),
#  'abrupt': array([  2, 309]),
#  'climat': array([  2, 310]),
#  'chang': array([ 54, 311]),
#  'may': array([ 32, 312]),
#  'doom': array([  4, 313]),
#  'mammoth': array([  2, 314]),
#  'megafauna': array([  2, 315]),
#  'sc': array([  6, 316]),
#  'australia': array([  8, 317]),
#  'dirtiest': array([  4, 318]),
#  'station': array([  6, 320]),
#  'consid': array([ 10, 321]),
#  'clean': array([ 12, 322]),
#  'energi': array([  6, 323]),
#  'biomass': array([  2, 324]),
#  'aint': array([ 24, 326]),
#  'easi': array([ 12, 327]),
#  'green': array([ 14, 328]),
#  'golf': array([  2, 329]),
#  'cours': array([ 14, 330]),
#  'ulti': array([  2, 332]),
#  'well': array([126, 333]),
#  'mine': array([ 26, 337]),
#  'gonna': array([102, 339]),
#  'sexi': array([  6, 341]),
#  'prexi': array([  2, 342]),
#  'kindergarten': array([  2, 344]),
#  'hungri': array([ 38, 346]),
#  'find': array([106, 348]),
#  'book': array([ 40, 349]),
#  'sane': array([  2, 351]),
#  'liter': array([ 30, 352]),
#  'three': array([ 14, 353]),
#  'loung': array([  2, 354]),
#  'event': array([  8, 355]),
#  'turn': array([ 34, 358]),
#  'boss': array([  8, 362]),
#  'hozier': array([  2, 364]),
#  'true': array([ 44, 366]),
#  'soooooooner': array([  2, 368]),
#  'ahh': array([ 14, 369]),
#  'fam': array([  6, 370]),
#  'hypercholesteloremia': array([  2, 374]),
#  'are': array([ 28, 375]),
#  'ok': array([ 66, 376]),
#  'look': array([194, 379]),
#  'can': array([ 62, 381]),
#  'gift': array([ 20, 383]),
#  'calibraska': array([  2, 384]),
#  'actual': array([ 48, 388]),
#  'genuin': array([  4, 389]),
#  'contend': array([  2, 390]),
#  'head': array([ 46, 393]),
#  'alway': array([112, 394]),
#  'hurt': array([ 82, 395]),
#  'stay': array([ 48, 396]),
#  'lmao': array([ 26, 398]),
#  'older': array([ 10, 399]),
#  'sound': array([ 38, 401]),
#  'upset': array([ 22, 402]),
#  'infinit': array([ 24, 407]),
#  'ao': array([  2, 408]),
#  'stick': array([  2, 410]),
#  'either': array([ 26, 412]),
#  'seriou': array([ 16, 414]),
#  'yun': array([  2, 415]),
#  'eh': array([  8, 416]),
#  'room': array([ 20, 418]),
#  'way': array([ 84, 419]),
#  'hot': array([ 26, 420]),
#  'havent': array([ 30, 422]),
#  'found': array([ 22, 423]),
#  'handsom': array([  4, 424]),
#  'jack': array([  8, 425]),
#  'draw': array([  4, 426]),
#  'shit': array([ 70, 427]),
#  'cut': array([ 28, 429]),
#  'encor': array([  8, 430]),
#  'baymax': array([  2, 432]),
#  'french': array([  4, 434]),
#  'mixer': array([  2, 435]),
#  'wft': array([  2, 438]),
#  'watch': array([152, 440]),
#  'awesom': array([ 10, 441]),
#  'replay': array([  2, 442]),
#  'parti': array([ 30, 444]),
#  'promot': array([  6, 445]),
#  'music': array([ 30, 446]),
#  'bank': array([ 18, 447]),
#  'short': array([ 24, 450]),
#  'boy': array([ 36, 452]),
#  'order': array([ 30, 453]),
#  'receiv': array([ 14, 454]),
#  'hub': array([  2, 455]),
#  'nearest': array([  2, 456]),
#  'deliv': array([  6, 459]),
#  'today': array([216, 460]),
#  'mum': array([ 28, 462]),
#  'loud': array([  4, 465]),
#  'the': array([144, 466]),
#  'final': array([ 70, 467]),
#  'parasyt': array([  2, 468]),
#  'alllllll': array([  2, 471]),
#  'bye': array([ 16, 475]),
#  'era': array([  2, 477]),
#  'too': array([180, 479]),
#  'nathann': array([  2, 480]),
#  'hug': array([ 56, 487]),
#  'you': array([296, 493]),
#  'beauti': array([ 22, 498]),
#  'dieididieieiei': array([  2, 500]),
#  'stage': array([ 30, 504]),
#  'mean': array([ 84, 505]),
#  'hello': array([ 26, 506]),
#  'lion': array([  6, 507]),
#  'think': array([150, 510]),
#  'screw': array([  8, 512]),
#  'herself': array([  2, 513]),
#  'netflix': array([ 10, 516]),
#  'chill': array([ 14, 517]),
#  'own': array([  6, 518]),
#  'di': array([ 14, 519]),
#  'ervin': array([  2, 520]),
#  'ohh': array([ 16, 521]),
#  'yeah': array([ 82, 522]),
#  'hope': array([204, 523]),
#  'am': array([ 52, 527]),
#  'accept': array([  4, 529]),
#  'offerbut': array([  2, 530]),
#  'desper': array([  4, 532]),
#  'year': array([ 92, 534]),
#  'out': array([ 36, 535]),
#  'snapchat': array([ 82, 538]),
#  'amargolonnard': array([  4, 539]),
#  'ugh': array([ 48, 540]),
#  'stream': array([ 48, 542]),
#  'have': array([ 58, 544]),
#  'duti': array([  6, 545]),
#  'uve': array([  2, 546]),
#  'gone': array([ 48, 547]),
#  'alien': array([  2, 550]),
#  'aww': array([ 42, 552]),
#  'wanna': array([188, 554]),
#  'sorka': array([  2, 559]),
#  'funer': array([  8, 563]),
#  'text': array([ 30, 565]),
#  'phone': array([ 68, 566]),
#  'sunni': array([  4, 567]),
#  'nonexist': array([  2, 571]),
#  'wowza': array([  2, 572]),
#  'fah': array([  2, 574]),
#  'taylor': array([  6, 576]),
#  'crop': array([  2, 577]),
#  'boo': array([ 10, 578]),
#  'count': array([ 12, 579]),
#  'new': array([110, 580]),
#  'guitar': array([  2, 581]),
#  'jonghyun': array([  2, 583]),
#  'hyung': array([  2, 584]),
#  'pleas': array([546, 585]),
#  'predict': array([  4, 586]),
#  'sj': array([  6, 588]),
#  'nomin': array([  2, 589]),
#  'vs': array([  8, 592]),
#  'pl': array([ 94, 594]),
#  'dude': array([ 24, 596]),
#  'calm': array([  4, 598]),
#  'brace': array([ 10, 599]),
#  'sir': array([  8, 600]),
#  'plu': array([  8, 601]),
#  'they': array([ 44, 603]),
#  'shock': array([  6, 606]),
#  'omgggg': array([  2, 607]),
#  'yall': array([ 12, 608]),
#  'deserv': array([ 16, 609]),
#  'whenev': array([  6, 611]),
#  'spend': array([ 16, 613]),
#  'smoke': array([  6, 616]),
#  'end': array([ 80, 621]),
#  'fall': array([ 32, 622]),
#  'asleep': array([ 50, 623]),
#  'point': array([ 28, 625]),
#  'close': array([ 40, 626]),
#  'grand': array([  4, 627]),
#  'whyyi': array([  2, 629]),
#  'long': array([ 76, 631]),
#  'must': array([ 30, 634]),
#  'annoy': array([ 22, 635]),
#  'evan': array([  2, 636]),
#  'do': array([ 64, 637]),
#  'option': array([  6, 640]),
#  'opt': array([  2, 641]),
#  'who': array([ 24, 643]),
#  'giveaway': array([  6, 644]),
#  'muster': array([  2, 645]),
#  'merch': array([  8, 647]),
#  'ah': array([ 36, 648]),
#  'funni': array([ 12, 652]),
#  'drink': array([ 14, 654]),
#  'savanna': array([  2, 655]),
#  'straw': array([  2, 656]),
#  'and': array([204, 660]),
#  'did': array([ 18, 662]),
#  'ignor': array([ 32, 664]),
#  'yester': array([  2, 666]),
#  'afternoon': array([  6, 667]),
#  'sleep': array([180, 669]),
#  'ye': array([ 92, 673]),
#  'sadli': array([ 24, 674]),
#  'veri': array([ 18, 675]),
#  'album': array([ 32, 677]),
#  'last': array([146, 680]),
#  'chocol': array([ 16, 681]),
#  'consum': array([  2, 682]),
#  'werk': array([  2, 684]),
#  'morn': array([ 62, 685]),
#  'foreal': array([  2, 686]),
#  'wesen': array([  2, 687]),
#  'uwes': array([  2, 688]),
#  'mj': array([  2, 689]),
#  'catch': array([ 18, 690]),
#  'onlin': array([ 40, 691]),
#  'enough': array([ 48, 693]),
#  'haha': array([ 60, 694]),
#  'he': array([146, 695]),
#  'bosen': array([  2, 697]),
#  'dy': array([  6, 698]),
#  'egg': array([  8, 699]),
#  'benni': array([  2, 700]),
#  'sometim': array([ 32, 701]),
#  'followback': array([ 10, 704]),
#  'huhu': array([ 34, 705]),
#  'your': array([ 46, 708]),
#  'understand': array([ 30, 712]),
#  'badli': array([ 24, 713]),
#  'scare': array([ 32, 714]),
#  'gt': array([100, 716]),
#  'al': array([  8, 718]),
#  'kati': array([  6, 719]),
#  'zaz': array([  2, 720]),
#  'ami': array([  4, 721]),
#  'lot': array([ 54, 722]),
#  'more': array([ 24, 725]),
#  'sub': array([  2, 726]),
#  'plz': array([  8, 727]),
#  'diari': array([  2, 730]),
#  'read': array([ 40, 733]),
#  'rehash': array([  2, 734]),
#  'websit': array([ 14, 735]),
#  'mushroom': array([  2, 736]),
#  'piec': array([  8, 738]),
#  'except': array([ 10, 740]),
#  'reach': array([  6, 742]),
#  'anyway': array([ 24, 744]),
#  'vicki': array([  2, 746]),
#  'omg': array([124, 747]),
#  'wtf': array([ 24, 748]),
#  'lip': array([  6, 751]),
#  'virgin': array([  4, 753]),
#  'hahah': array([ 12, 759]),
#  'ninasti': array([  2, 760]),
#  'tsktsk': array([  2, 761]),
#  'oppa': array([  6, 762]),
#  'wont': array([ 18, 763]),
#  'dick': array([ 10, 766]),
#  'kawaii': array([  2, 767]),
#  'manli': array([  2, 768]),
#  'xbox': array([  6, 778]),
#  'alreadi': array([104, 780]),
#  'comfi': array([  2, 781]),
#  'bed': array([ 24, 782]),
#  'youu': array([  4, 784]),
#  'sigh': array([ 24, 785]),
#  'lol': array([ 84, 789]),
#  'potato': array([  2, 792]),
#  'fri': array([ 14, 793]),
#  'guess': array([ 28, 794]),
#  'ugli': array([ 18, 796]),
#  'asf': array([  2, 797]),
#  'huh': array([ 14, 798]),
#  'eish': array([  2, 799]),
#  'quit': array([ 18, 801]),
#  'knowi': array([  2, 802]),
#  'lost': array([ 48, 803]),
#  'twitter': array([ 56, 804]),
#  'mojo': array([  2, 805]),
#  'shamen': array([  2, 806]),
#  'dont': array([158, 807]),
#  'mara': array([  2, 811]),
#  'neh': array([  4, 815]),
#  'fever': array([ 14, 819]),
#  'lt': array([ 64, 820]),
#  'poor': array([ 70, 821]),
#  'bb': array([ 14, 822]),
#  'abl': array([ 46, 824]),
#  'associ': array([  2, 827]),
#  'councillor': array([  2, 829]),
#  'confer': array([  4, 830]),
#  'weekend': array([ 50, 831]),
#  'skype': array([  4, 833]),
#  'account': array([ 40, 834]),
#  'hack': array([ 16, 837]),
#  'contact': array([ 14, 839]),
#  'creat': array([  4, 843]),
#  'tweet': array([ 70, 848]),
#  'spree': array([  8, 849]),
#  'na': array([ 58, 852]),
#  'as': array([ 20, 853]),
#  'sholong': array([  2, 854]),
#  'reject': array([ 14, 855]),
#  'propos': array([  4, 856]),
#  'elzzika': array([  2, 857]),
#  'gee': array([  2, 858]),
#  'fli': array([ 20, 859]),
#  'gidi': array([  2, 861]),
#  'gatlinho': array([  2, 862]),
#  'pamper': array([  2, 866]),
#  'lago': array([  2, 867]),
#  'ehn': array([  2, 868]),
#  'arrest': array([  2, 871]),
#  'girlfriend': array([  4, 872]),
#  'nice': array([ 38, 874]),
#  'person': array([ 30, 875]),
#  'idk': array([ 52, 876]),
#  'anybodi': array([ 14, 877]),
#  'song': array([ 54, 882]),
#  'disappear': array([  2, 883]),
#  'itun': array([  6, 885]),
#  'daze': array([  2, 888]),
#  'confus': array([ 16, 889]),
#  'surviv': array([ 10, 893]),
#  'fragment': array([  2, 898]),
#  'wouldv': array([  6, 901]),
#  'forc': array([  4, 905]),
#  'horribl': array([ 18, 907]),
#  'weather': array([ 58, 908]),
#  'us': array([ 96, 912]),
#  'could': array([138, 913]),
#  'walao': array([  2, 915]),
#  'kb': array([  2, 916]),
#  'send': array([ 24, 920]),
#  'ill': array([114, 923]),
#  'mani': array([ 58, 931]),
#  'fun': array([ 64, 932]),
#  'gig': array([  6, 934]),
#  'absolut': array([ 12, 935]),
#  'legend': array([  6, 936]),
#  'wait': array([ 86, 940]),
#  'till': array([ 16, 941]),
#  'saturday': array([ 20, 942]),
#  'homework': array([  4, 945]),
#  'pa': array([ 16, 946]),
#  'if': array([ 32, 948]),
#  'made': array([ 44, 949]),
#  'da': array([ 10, 951]),
#  'greek': array([  2, 953]),
#  'tragedi': array([  2, 954]),
#  'rain': array([ 80, 957]),
#  'gym': array([ 12, 959]),
#  'wrong': array([ 66, 961]),
#  'struck': array([  2, 965]),
#  'anymor': array([ 40, 969]),
#  'belgium': array([  8, 971]),
#  'fabian': array([  4, 972]),
#  'delph': array([ 12, 973]),
#  'fallen': array([  6, 974]),
#  'where': array([ 28, 975]),
#  'been': array([ 26, 976]),
#  'hide': array([  8, 977]),
#  'drake': array([  2, 980]),
#  'silent': array([  2, 981]),
#  'hear': array([ 66, 983]),
#  'rest': array([ 42, 984]),
#  'peac': array([  8, 985]),
#  'mo': array([  8, 986]),
#  'game': array([ 52, 989]),
#  'tonight': array([ 48, 990]),
#  'ahhh': array([  6, 991]),
#  'wake': array([ 42, 993]),
#  'mumma': array([  4, 994]),
#  'dead': array([ 20, 999]),
#  'tomorrow': array([  72, 1000]),
#  'high': array([  16, 1002]),
#  'low': array([  16, 1003]),
#  'pray': array([  24, 1005]),
#  'appropri': array([   2, 1006]),
#  'him': array([  16, 1008]),
#  'awak': array([  20, 1011]),
#  'woke': array([  26, 1012]),
#  'upp': array([   2, 1013]),
#  'dm': array([  46, 1022]),
#  'luke': array([  10, 1023]),
#  'hey': array([  52, 1025]),
#  'babe': array([  34, 1026]),
#  'across': array([   8, 1028]),
#  'picwhat': array([   2, 1029]),
#  'about': array([   6, 1030]),
#  'hindi': array([   2, 1033]),
#  'reaction': array([   2, 1034]),
#  's': array([  14, 1035]),
#  'run': array([  30, 1039]),
#  'space': array([  10, 1040]),
#  'tbh': array([  28, 1041]),
#  'disabl': array([   4, 1046]),
#  'pension': array([   2, 1047]),
#  'ptsd': array([   2, 1048]),
#  'imposs': array([   8, 1050]),
#  'physic': array([  14, 1051]),
#  'financi': array([   4, 1052]),
#  'nooo': array([  10, 1055]),
#  'broke': array([  18, 1056]),
#  'soo': array([   6, 1059]),
#  'amaz': array([  32, 1060]),
#  'toghet': array([   2, 1061]),
#  'around': array([  40, 1066]),
#  'pm': array([  28, 1067]),
#  'hold': array([  18, 1073]),
#  'anoth': array([  56, 1074]),
#  'septemb': array([   4, 1076]),
#  'st': array([  22, 1077]),
#  'snsd': array([   4, 1082]),
#  'interact': array([   4, 1084]),
#  'anna': array([   8, 1087]),
#  'akana': array([   2, 1088]),
#  'askip': array([   2, 1090]),
#  'texist': array([   2, 1091]),
#  'channel': array([  12, 1094]),
#  'owner': array([   2, 1095]),
#  'decid': array([  20, 1096]),
#  'broadcast': array([  12, 1098]),
#  'to': array([  66, 1099]),
#  'kei': array([   4, 1101]),
#  'rate': array([   8, 1103]),
#  'se': array([   6, 1104]),
#  'notic': array([  52, 1108]),
#  'exist': array([   4, 1110]),
#  'traffic': array([  10, 1112]),
#  'terribl': array([  26, 1113]),
#  'eye': array([  26, 1115]),
#  'small': array([  18, 1116]),
#  'kate': array([   4, 1117]),
#  'spade': array([   2, 1118]),
#  'pero': array([   6, 1121]),
#  'walang': array([   2, 1122]),
#  'maganda': array([   2, 1123]),
#  'aw': array([  84, 1125]),
#  'seen': array([  46, 1129]),
#  'agessss': array([   2, 1130]),
#  'add': array([  52, 1132]),
#  'corinehurleigh': array([   2, 1134]),
#  'bum': array([   4, 1135]),
#  'zara': array([   2, 1136]),
#  'trouser': array([   2, 1137]),
#  'effect': array([   8, 1145]),
#  'spanish': array([   2, 1146]),
#  'itokay': array([   2, 1151]),
#  'health': array([   4, 1153]),
#  'luck': array([  12, 1154]),
#  'freed': array([   2, 1155]),
#  'rock': array([   6, 1156]),
#  'tri': array([ 130, 1158]),
#  'result': array([   8, 1159]),
#  'big': array([  42, 1164]),
#  'cuddl': array([  16, 1165]),
#  'lew': array([   2, 1166]),
#  'kiss': array([   8, 1167]),
#  'em': array([   2, 1171]),
#  'crave': array([  16, 1173]),
#  'banana': array([  10, 1174]),
#  'crumbl': array([   2, 1175]),
#  'mcflurri': array([   2, 1176]),
#  'cabl': array([   2, 1180]),
#  'car': array([  34, 1181]),
#  'brother': array([  20, 1182]),
#  'venuss': array([   2, 1188]),
#  'concept': array([   8, 1190]),
#  'rli': array([  10, 1192]),
#  'tea': array([  14, 1195]),
#  'tagal': array([   4, 1196]),
#  'weve': array([   6, 1197]),
#  'appoint': array([   2, 1203]),
#  'id': array([  34, 1205]),
#  'sinc': array([  70, 1211]),
#  'thi': array([ 136, 1213]),
#  'milk': array([   6, 1219]),
#  'left': array([  52, 1220]),
#  'cereal': array([   4, 1221]),
#  'via': array([  16, 1229]),
#  'film': array([  12, 1234]),
#  'date': array([  14, 1235]),
#  'at': array([  20, 1237]),
#  'previou': array([   4, 1246]),
#  'user': array([   2, 1252]),
#  'everywher': array([  12, 1257]),
#  'fansign': array([   2, 1259]),
#  'photo': array([  22, 1261]),
#  'expens': array([  14, 1262]),
#  'zzzzzzpleas': array([   2, 1263]),
#  'let': array([  88, 1264]),
#  'sun': array([  20, 1265]),
#  'yet': array([  66, 1267]),
#  'bff': array([   4, 1269]),
#  'extrem': array([   6, 1270]),
#  'stress': array([  20, 1271]),
#  'anyth': array([  40, 1273]),
#  'win': array([  54, 1276]),
#  'deosnt': array([   2, 1280]),
#  'liverpool': array([   4, 1282]),
#  'pool': array([   6, 1286]),
#  'though': array([ 114, 1287]),
#  'brolost': array([   2, 1289]),
#  'great': array([  44, 1296]),
#  'news': array([  34, 1297]),
#  'self': array([   2, 1308]),
#  'esteem': array([   2, 1309]),
#  'lowest': array([   2, 1310]),
#  'better': array([  72, 1313]),
#  'tacki': array([   2, 1320]),
#  'taken': array([  18, 1321]),
#  'man': array([  64, 1323]),
#  'lucki': array([  32, 1325]),
#  'charm': array([   2, 1326]),
#  'syria': array([   2, 1327]),
#  'continu': array([   2, 1328]),
#  'develop': array([  10, 1329]),
#  'chemic': array([   2, 1330]),
#  'weapon': array([   4, 1331]),
#  'offici': array([   6, 1332]),
#  'wsj': array([   4, 1334]),
#  'rep': array([   2, 1336]),
#  'bt': array([   8, 1338]),
#  'onli': array([  24, 1340]),
#  'should': array([   6, 1343]),
#  'mr': array([  18, 1346]),
#  'wong': array([   2, 1347]),
#  'confisc': array([   2, 1348]),
#  'art': array([   8, 1349]),
#  'thought': array([  62, 1353]),
#  'icepack': array([   2, 1354]),
#  'dose': array([   4, 1356]),
#  'killer': array([   4, 1358]),
#  'board': array([   2, 1359]),
#  'whimper': array([   2, 1364]),
#  'fan': array([  34, 1368]),
#  'will': array([  18, 1374]),
#  'senpai': array([   2, 1375]),
#  'buttsex': array([   2, 1378]),
#  'sabalabla': array([   4, 1379]),
#  'joke': array([  16, 1381]),
#  'headlin': array([   2, 1382]),
#  'dnt': array([   4, 1386]),
#  'brk': array([   2, 1387]),
#  'hit': array([  14, 1391]),
#  'voic': array([  16, 1393]),
#  'falsetto': array([   2, 1404]),
#  'zone': array([   4, 1409]),
#  'leannerin': array([   2, 1412]),
#  'spain': array([   8, 1415]),
#  'delay': array([  10, 1417]),
#  'kill': array([  44, 1418]),
#  'singl': array([  20, 1420]),
#  'untruth': array([   2, 1421]),
#  'cross': array([   8, 1424]),
#  'countri': array([  14, 1425]),
#  'ij': array([   2, 1426]),
#  'bear': array([   4, 1429]),
#  'littl': array([  42, 1433]),
#  'apart': array([  14, 1434]),
#  'live': array([  74, 1438]),
#  'soshi': array([   2, 1439]),
#  'didnt': array([  56, 1440]),
#  'buttt': array([   2, 1442]),
#  'congrat': array([   4, 1443]),
#  'sunday': array([  16, 1448]),
#  'friday': array([  26, 1449]),
#  'shoulda': array([   2, 1455]),
#  'move': array([  24, 1456]),
#  'caus': array([  32, 1460]),
#  'theyr': array([  34, 1461]),
#  'heyyyyy': array([   2, 1466]),
#  'yeol': array([   4, 1469]),
#  'solo': array([  12, 1470]),
#  'danceeeee': array([   2, 1471]),
#  'inter': array([   2, 1472]),
#  'offer': array([  18, 1473]),
#  'nemanja': array([   2, 1474]),
#  'vidic': array([   2, 1475]),
#  'romabut': array([   2, 1476]),
#  'linguist': array([   2, 1481]),
#  'dad': array([  20, 1483]),
#  'comput': array([  12, 1484]),
#  'scientist': array([   2, 1485]),
#  'dumbest': array([   2, 1487]),
#  'famili': array([  16, 1489]),
#  'broken': array([  22, 1490]),
#  'ice': array([  70, 1494]),
#  'cream': array([  64, 1495]),
#  'pour': array([   2, 1496]),
#  'crash': array([  12, 1502]),
#  'scienc': array([   2, 1506]),
#  'resourc': array([   2, 1509]),
#  'vehicl': array([  10, 1513]),
#  'ate': array([  20, 1515]),
#  'ayex': array([   2, 1516]),
#  'eat': array([  54, 1517]),
#  'swear': array([  12, 1520]),
#  'lamon': array([   2, 1525]),
#  'scroll': array([   2, 1529]),
#  'curv': array([   4, 1533]),
#  'cement': array([   2, 1538]),
#  'cast': array([  10, 1539]),
#  'k': array([  20, 1542]),
#  'sign': array([  16, 1543]),
#  'zayn': array([  16, 1545]),
#  'bot': array([   2, 1546]),
#  'mention': array([  18, 1552]),
#  'becaus': array([  20, 1553]),
#  'jmu': array([   2, 1556]),
#  'camp': array([  14, 1557]),
#  'teas': array([   6, 1558]),
#  'sweetest': array([   2, 1563]),
#  'awuna': array([   2, 1568]),
#  'mbulelo': array([   2, 1569]),
#  'match': array([  14, 1577]),
#  'pig': array([   4, 1580]),
#  'although': array([  10, 1582]),
#  'crackl': array([   2, 1585]),
#  'nois': array([   6, 1586]),
#  'plug': array([   4, 1587]),
#  'fuse': array([   2, 1592]),
#  'dammit': array([   6, 1593]),
#  'tip': array([   4, 1594]),
#  'carlton': array([   4, 1595]),
#  'alex': array([  10, 1602]),
#  'hous': array([  32, 1603]),
#  'motorsport': array([   2, 1607]),
#  'seri': array([   6, 1608]),
#  'disc': array([   2, 1611]),
#  'right': array([  98, 1614]),
#  'a': array([  10, 1615]),
#  'cheeki': array([   2, 1617]),
#  'instead': array([   8, 1618]),
#  'seo': array([   2, 1621]),
#  'nl': array([   2, 1622]),
#  'bud': array([   2, 1627]),
#  'christi': array([   2, 1628]),
#  'xo': array([   2, 1634]),
#  'niec': array([   2, 1638]),
#  'summer': array([  28, 1640]),
#  'bloodi': array([   4, 1642]),
#  'sandwhich': array([   2, 1643]),
#  'buset': array([   2, 1644]),
#  'five': array([  10, 1645]),
#  'learn': array([  10, 1647]),
#  'pregnanc': array([   4, 1648]),
#  'discrimin': array([   4, 1649]),
#  'foot': array([  10, 1652]),
#  'f': array([   4, 1653]),
#  'matern': array([   2, 1654]),
#  'kick': array([  12, 1659]),
#  'law': array([   8, 1663]),
#  'domest': array([   2, 1666]),
#  'violenc': array([   4, 1667]),
#  'victim': array([   8, 1668]),
#  'fm': array([   2, 1669]),
#  'exactli': array([  10, 1675]),
#  'unfortun': array([  42, 1676]),
#  'such': array([   8, 1677]),
#  'yesterday': array([  26, 1681]),
#  'uk': array([  18, 1682]),
#  'govern': array([   2, 1683]),
#  'sapiosexu': array([   2, 1692]),
#  'damn': array([  54, 1698]),
#  'beta': array([   8, 1699]),
#  'hour': array([  70, 1701]),
#  'world': array([  34, 1703]),
#  'hulk': array([   6, 1704]),
#  'hogan': array([   6, 1705]),
#  'scrub': array([   2, 1706]),
#  'wwe': array([   4, 1707]),
#  'histori': array([   4, 1708]),
#  'iren': array([   8, 1720]),
#  'mistak': array([  12, 1724]),
#  'naa': array([   2, 1725]),
#  'sold': array([  12, 1729]),
#  'gtlt': array([   4, 1732]),
#  'lose': array([  14, 1734]),
#  'valentin': array([   4, 1735]),
#  'et': array([   6, 1736]),
#  'rship': array([   2, 1739]),
#  'btwn': array([   2, 1740]),
#  'homobiphob': array([   4, 1741]),
#  'comment': array([   8, 1742]),
#  'certain': array([  12, 1744]),
#  'disciplin': array([   4, 1745]),
#  'incl': array([   4, 1746]),
#  'european': array([   6, 1747]),
#  'lang': array([  12, 1748]),
#  'lit': array([   4, 1749]),
#  'educ': array([   4, 1750]),
#  'dream': array([  48, 1754]),
#  'gettin': array([   4, 1755]),
#  'realist': array([   8, 1756]),
#  'thx': array([   2, 1758]),
#  'real': array([  42, 1762]),
#  'isnt': array([  16, 1763]),
#  'prefer': array([   8, 1766]),
#  'benzema': array([   4, 1767]),
#  'hahahahahaah': array([   2, 1771]),
#  'donno': array([   2, 1772]),
#  'korean': array([   4, 1773]),
#  'languag': array([  10, 1774]),
#  'russian': array([   4, 1775]),
#  'waaaaa': array([   2, 1776]),
#  'boreddd': array([   2, 1781]),
#  'mug': array([   6, 1785]),
#  'piss': array([   6, 1786]),
#  'mgapinoypatama': array([   2, 1788]),
#  'tiddler': array([   2, 1799]),
#  'silli': array([   4, 1801]),
#  'least': array([  30, 1802]),
#  'card': array([  14, 1807]),
#  'chorong': array([   2, 1816]),
#  'leader': array([   2, 1817]),
#  'clan': array([   2, 1821]),
#  'slot': array([   4, 1822]),
#  'open': array([  34, 1823]),
#  'pffff': array([   2, 1824]),
#  'privat': array([   4, 1825]),
#  'selfxss': array([   2, 1827]),
#  'host': array([   4, 1828]),
#  'header': array([   6, 1829]),
#  'poison': array([   6, 1830]),
#  'code': array([  16, 1832]),
#  'execut': array([   2, 1833]),
#  'connect': array([   6, 1835]),
#  ...}

# %%
def sigmoid(s):
    return 1/(1+np.exp(-s))

def error(y_hat, y):
    errors = (y_hat-y)**2
    return errors.sum() / len(y)

def forward(X, W):
    s = X @ W
    y_pred = sigmoid(s)
    return y_pred

def loss(y_pred, y_):
    return sum((y_pred - y_)**2).item()

def sample(N, K):
    xs = list(range(N))
    return np.random.choice(xs, size=K, replace=False)

def split_train_test(X, y, ratio=0.3):
    N = len(X)
    idx = sample(N, int(N*ratio))
    not_idx = [n for n in range(N) if n not in idx]
    return X[not_idx], y[not_idx], X[idx], y[idx] 

X_train, y_train, X_test, y_test = split_train_test(X, y)
print(f"{sum(y_test)/len(y_test)}%, {sum(y_train)/len(y_train)}%")
# Out:
# [0.49436302]%, [0.50241429]%

# %%
epoch = 100000
W = np.random.random(2).reshape(-1,1)
N = len(X)
ni = 100

for e in range(0,epoch):
    y_pred = forward(X_train, W)
    L_train = loss(y_pred, y_train)
    acc_train = round((y_pred == y_train).sum()/N * 100, 3)
    
    ### Backward ###
    DL_dw = 1/N*sum((y_pred-y_train)*X_train)

    ### Stadt Abstieg ###
    W = W.T - ni*DL_dw
    W = W.reshape(2,1)
    
    ### L test ###
    y_pred = forward(X_test, W)
    L_test = loss(y_pred, y_test)
    acc_test = round((y_pred == y_test).sum()/N * 100, 3)
    
    print(f"{e}, {acc_train}%, train_loss={round(L_train, 3)}, test_loss={round(L_test, 3)}")
# Out:
# 0, 0.0%, train_loss=1393.648, test_loss=67.586
# 1, 13.404%, train_loss=180.074, test_loss=66.171
# 2, 12.796%, train_loss=177.185, test_loss=64.758
# 3, 12.086%, train_loss=174.267, test_loss=63.347
# 4, 11.511%, train_loss=171.319, test_loss=61.939
# 5, 10.97%, train_loss=168.341, test_loss=60.538
# 6, 10.446%, train_loss=165.332, test_loss=59.142
# 7, 9.99%, train_loss=162.294, test_loss=57.753
# 8, 9.398%, train_loss=159.227, test_loss=56.371
# 9, 8.79%, train_loss=156.134, test_loss=54.997
# 10, 8.249%, train_loss=153.016, test_loss=53.63
# 11, 7.488%, train_loss=149.878, test_loss=52.272
# 12, 6.575%, train_loss=146.721, test_loss=50.923
# 13, 5.984%, train_loss=143.551, test_loss=49.584
# 14, 5.646%, train_loss=140.372, test_loss=48.256
# 15, 5.291%, train_loss=137.187, test_loss=46.939
# 16, 5.156%, train_loss=134.001, test_loss=45.637
# 17, 4.868%, train_loss=130.818, test_loss=44.35
# 18, 4.716%, train_loss=127.642, test_loss=43.08
# 19, 4.581%, train_loss=124.479, test_loss=41.83
# 20, 4.496%, train_loss=121.332, test_loss=40.601
# 21, 4.462%, train_loss=118.206, test_loss=39.395
# 22, 4.446%, train_loss=115.108, test_loss=38.215
# 23, 4.344%, train_loss=112.042, test_loss=37.063
# 24, 4.243%, train_loss=109.016, test_loss=35.94
# 25, 4.226%, train_loss=106.034, test_loss=34.849
# 26, 4.091%, train_loss=103.106, test_loss=33.79
# 27, 4.006%, train_loss=100.237, test_loss=32.767
# 28, 3.955%, train_loss=97.435, test_loss=31.779
# 29, 3.905%, train_loss=94.709, test_loss=30.83
# 30, 3.786%, train_loss=92.065, test_loss=29.919
# 31, 3.753%, train_loss=89.511, test_loss=29.049
# 32, 3.702%, train_loss=87.053, test_loss=28.221
# 33, 3.634%, train_loss=84.698, test_loss=27.434
# 34, 3.584%, train_loss=82.449, test_loss=26.69
# 35, 3.567%, train_loss=80.312, test_loss=25.989
# 36, 3.499%, train_loss=78.29, test_loss=25.332
# 37, 3.465%, train_loss=76.384, test_loss=24.718
# 38, 3.398%, train_loss=74.596, test_loss=24.146
# 39, 3.347%, train_loss=72.925, test_loss=23.616
# 40, 3.313%, train_loss=71.37, test_loss=23.127
# 41, 3.313%, train_loss=69.929, test_loss=22.678
# 42, 3.245%, train_loss=68.599, test_loss=22.267
# 43, 3.245%, train_loss=67.375, test_loss=21.892
# 44, 3.212%, train_loss=66.254, test_loss=21.551
# 45, 3.212%, train_loss=65.23, test_loss=21.244
# 46, 3.195%, train_loss=64.299, test_loss=20.967
# 47, 3.161%, train_loss=63.454, test_loss=20.719
# 48, 3.144%, train_loss=62.689, test_loss=20.497
# 49, 3.11%, train_loss=62.0, test_loss=20.299
# 50, 3.043%, train_loss=61.38, test_loss=20.124
# 51, 3.043%, train_loss=60.824, test_loss=19.97
# 52, 3.043%, train_loss=60.327, test_loss=19.834
# 53, 3.009%, train_loss=59.883, test_loss=19.715
# 54, 2.992%, train_loss=59.489, test_loss=19.611
# 55, 2.992%, train_loss=59.138, test_loss=19.521
# 56, 2.975%, train_loss=58.828, test_loss=19.444
# 57, 2.958%, train_loss=58.554, test_loss=19.377
# 58, 2.907%, train_loss=58.313, test_loss=19.32
# 59, 2.857%, train_loss=58.101, test_loss=19.272
# 60, 2.84%, train_loss=57.916, test_loss=19.232
# 61, 2.823%, train_loss=57.754, test_loss=19.198
# 62, 2.823%, train_loss=57.614, test_loss=19.171
# 63, 2.789%, train_loss=57.494, test_loss=19.149
# 64, 2.789%, train_loss=57.39, test_loss=19.132
# 65, 2.772%, train_loss=57.302, test_loss=19.12
# 66, 2.755%, train_loss=57.228, test_loss=19.111
# 67, 2.721%, train_loss=57.167, test_loss=19.106
# 68, 2.671%, train_loss=57.116, test_loss=19.103
# 69, 2.671%, train_loss=57.076, test_loss=19.104
# 70, 2.62%, train_loss=57.045, test_loss=19.106
# 71, 2.62%, train_loss=57.022, test_loss=19.111
# 72, 2.603%, train_loss=57.006, test_loss=19.118
# 73, 2.569%, train_loss=56.997, test_loss=19.126
# 74, 2.569%, train_loss=56.994, test_loss=19.136
# 75, 2.569%, train_loss=56.996, test_loss=19.147
# 76, 2.552%, train_loss=57.003, test_loss=19.16
# 77, 2.552%, train_loss=57.015, test_loss=19.173
# 78, 2.535%, train_loss=57.031, test_loss=19.188
# 79, 2.535%, train_loss=57.05, test_loss=19.203
# 80, 2.535%, train_loss=57.072, test_loss=19.219
# 81, 2.502%, train_loss=57.098, test_loss=19.236
# 82, 2.502%, train_loss=57.126, test_loss=19.254
# 83, 2.468%, train_loss=57.157, test_loss=19.272
# 84, 2.451%, train_loss=57.19, test_loss=19.29
# 85, 2.434%, train_loss=57.225, test_loss=19.309
# 86, 2.417%, train_loss=57.262, test_loss=19.329
# 87, 2.366%, train_loss=57.301, test_loss=19.349
# 88, 2.366%, train_loss=57.341, test_loss=19.369
# 89, 2.35%, train_loss=57.382, test_loss=19.39
# 90, 2.35%, train_loss=57.425, test_loss=19.411
# 91, 2.333%, train_loss=57.469, test_loss=19.432
# 92, 2.316%, train_loss=57.515, test_loss=19.454
# 93, 2.265%, train_loss=57.561, test_loss=19.475
# 94, 2.231%, train_loss=57.608, test_loss=19.497
# 95, 2.214%, train_loss=57.656, test_loss=19.519
# 96, 2.197%, train_loss=57.704, test_loss=19.542
# 97, 2.181%, train_loss=57.754, test_loss=19.564
# 98, 2.181%, train_loss=57.804, test_loss=19.587
# 99, 2.181%, train_loss=57.854, test_loss=19.609
# 100, 2.181%, train_loss=57.905, test_loss=19.632
# 101, 2.13%, train_loss=57.957, test_loss=19.655
# 102, 2.113%, train_loss=58.009, test_loss=19.678
# 103, 2.096%, train_loss=58.061, test_loss=19.701
# 104, 2.096%, train_loss=58.114, test_loss=19.725
# 105, 2.096%, train_loss=58.167, test_loss=19.748
# 106, 2.079%, train_loss=58.22, test_loss=19.771
# 107, 2.062%, train_loss=58.274, test_loss=19.795
# 108, 2.045%, train_loss=58.328, test_loss=19.818
# 109, 2.045%, train_loss=58.382, test_loss=19.841
# 110, 2.028%, train_loss=58.436, test_loss=19.865
# 111, 2.028%, train_loss=58.491, test_loss=19.888
# 112, 2.011%, train_loss=58.545, test_loss=19.912
# 113, 2.011%, train_loss=58.6, test_loss=19.936
# 114, 1.995%, train_loss=58.655, test_loss=19.959
# 115, 1.978%, train_loss=58.709, test_loss=19.983
# 116, 1.944%, train_loss=58.764, test_loss=20.006
# 117, 1.91%, train_loss=58.819, test_loss=20.03
# 118, 1.91%, train_loss=58.874, test_loss=20.054
# 119, 1.91%, train_loss=58.929, test_loss=20.077
# 120, 1.893%, train_loss=58.984, test_loss=20.101
# 121, 1.893%, train_loss=59.039, test_loss=20.124
# 122, 1.876%, train_loss=59.094, test_loss=20.148
# 123, 1.876%, train_loss=59.149, test_loss=20.171
# 124, 1.859%, train_loss=59.204, test_loss=20.194
# 125, 1.859%, train_loss=59.259, test_loss=20.218
# 126, 1.859%, train_loss=59.314, test_loss=20.241
# 127, 1.859%, train_loss=59.368, test_loss=20.264
# 128, 1.842%, train_loss=59.423, test_loss=20.288
# 129, 1.826%, train_loss=59.477, test_loss=20.311
# 130, 1.792%, train_loss=59.532, test_loss=20.334
# 131, 1.792%, train_loss=59.586, test_loss=20.357
# 132, 1.775%, train_loss=59.64, test_loss=20.38
# 133, 1.775%, train_loss=59.694, test_loss=20.403
# 134, 1.758%, train_loss=59.748, test_loss=20.426
# 135, 1.741%, train_loss=59.802, test_loss=20.449
# 136, 1.741%, train_loss=59.856, test_loss=20.471
# 137, 1.741%, train_loss=59.909, test_loss=20.494
# 138, 1.724%, train_loss=59.962, test_loss=20.517
# 139, 1.724%, train_loss=60.015, test_loss=20.539
# 140, 1.69%, train_loss=60.068, test_loss=20.561
# 141, 1.69%, train_loss=60.121, test_loss=20.584
# 142, 1.69%, train_loss=60.173, test_loss=20.606
# 143, 1.64%, train_loss=60.226, test_loss=20.628
# 144, 1.64%, train_loss=60.278, test_loss=20.65
# 145, 1.606%, train_loss=60.329, test_loss=20.672
# 146, 1.606%, train_loss=60.381, test_loss=20.694
# 147, 1.606%, train_loss=60.432, test_loss=20.715
# 148, 1.589%, train_loss=60.483, test_loss=20.737
# 149, 1.572%, train_loss=60.534, test_loss=20.758
# 150, 1.572%, train_loss=60.585, test_loss=20.78
# 151, 1.572%, train_loss=60.635, test_loss=20.801
# 152, 1.572%, train_loss=60.685, test_loss=20.822
# 153, 1.555%, train_loss=60.735, test_loss=20.843
# 154, 1.555%, train_loss=60.784, test_loss=20.864
# 155, 1.555%, train_loss=60.834, test_loss=20.884
# 156, 1.555%, train_loss=60.883, test_loss=20.905
# 157, 1.538%, train_loss=60.931, test_loss=20.925
# 158, 1.538%, train_loss=60.98, test_loss=20.946
# 159, 1.538%, train_loss=61.028, test_loss=20.966
# 160, 1.538%, train_loss=61.075, test_loss=20.986
# 161, 1.521%, train_loss=61.123, test_loss=21.006
# 162, 1.521%, train_loss=61.17, test_loss=21.026
# 163, 1.521%, train_loss=61.217, test_loss=21.045
# 164, 1.487%, train_loss=61.263, test_loss=21.065
# 165, 1.487%, train_loss=61.309, test_loss=21.084
# 166, 1.487%, train_loss=61.355, test_loss=21.103
# 167, 1.487%, train_loss=61.4, test_loss=21.122
# 168, 1.487%, train_loss=61.445, test_loss=21.141
# 169, 1.471%, train_loss=61.49, test_loss=21.16
# 170, 1.437%, train_loss=61.535, test_loss=21.179
# 171, 1.42%, train_loss=61.579, test_loss=21.197
# 172, 1.403%, train_loss=61.622, test_loss=21.215
# 173, 1.403%, train_loss=61.666, test_loss=21.234
# 174, 1.403%, train_loss=61.709, test_loss=21.252
# 175, 1.403%, train_loss=61.751, test_loss=21.269
# 176, 1.403%, train_loss=61.794, test_loss=21.287
# 177, 1.403%, train_loss=61.835, test_loss=21.305
# 178, 1.403%, train_loss=61.877, test_loss=21.322
# 179, 1.403%, train_loss=61.918, test_loss=21.339
# 180, 1.403%, train_loss=61.959, test_loss=21.356
# 181, 1.403%, train_loss=61.999, test_loss=21.373
# 182, 1.403%, train_loss=62.039, test_loss=21.39
# 183, 1.403%, train_loss=62.079, test_loss=21.407
# 184, 1.403%, train_loss=62.118, test_loss=21.423
# 185, 1.403%, train_loss=62.157, test_loss=21.439
# 186, 1.403%, train_loss=62.196, test_loss=21.455
# 187, 1.403%, train_loss=62.234, test_loss=21.471
# 188, 1.403%, train_loss=62.272, test_loss=21.487
# 189, 1.386%, train_loss=62.309, test_loss=21.503
# 190, 1.386%, train_loss=62.346, test_loss=21.518
# 191, 1.386%, train_loss=62.383, test_loss=21.533
# 192, 1.386%, train_loss=62.419, test_loss=21.548
# 193, 1.386%, train_loss=62.455, test_loss=21.563
# 194, 1.386%, train_loss=62.491, test_loss=21.578
# 195, 1.386%, train_loss=62.526, test_loss=21.593
# 196, 1.386%, train_loss=62.561, test_loss=21.607
# 197, 1.386%, train_loss=62.595, test_loss=21.622
# 198, 1.386%, train_loss=62.629, test_loss=21.636
# 199, 1.369%, train_loss=62.663, test_loss=21.65
# 200, 1.369%, train_loss=62.696, test_loss=21.664
# 201, 1.352%, train_loss=62.729, test_loss=21.677
# 202, 1.352%, train_loss=62.761, test_loss=21.691
# 203, 1.352%, train_loss=62.794, test_loss=21.704
# 204, 1.352%, train_loss=62.825, test_loss=21.718
# 205, 1.352%, train_loss=62.857, test_loss=21.731
# 206, 1.352%, train_loss=62.888, test_loss=21.744
# 207, 1.352%, train_loss=62.919, test_loss=21.756
# 208, 1.352%, train_loss=62.949, test_loss=21.769
# 209, 1.352%, train_loss=62.979, test_loss=21.781
# 210, 1.352%, train_loss=63.008, test_loss=21.794
# 211, 1.352%, train_loss=63.038, test_loss=21.806
# 212, 1.352%, train_loss=63.066, test_loss=21.818
# 213, 1.352%, train_loss=63.095, test_loss=21.83
# 214, 1.352%, train_loss=63.123, test_loss=21.841
# 215, 1.352%, train_loss=63.151, test_loss=21.853
# 216, 1.352%, train_loss=63.178, test_loss=21.864
# 217, 1.352%, train_loss=63.205, test_loss=21.875
# 218, 1.352%, train_loss=63.232, test_loss=21.887
# 219, 1.335%, train_loss=63.259, test_loss=21.897
# 220, 1.302%, train_loss=63.285, test_loss=21.908
# 221, 1.302%, train_loss=63.31, test_loss=21.919
# 222, 1.302%, train_loss=63.336, test_loss=21.93
# 223, 1.302%, train_loss=63.361, test_loss=21.94
# 224, 1.302%, train_loss=63.385, test_loss=21.95
# 225, 1.302%, train_loss=63.41, test_loss=21.96
# 226, 1.302%, train_loss=63.434, test_loss=21.97
# 227, 1.285%, train_loss=63.458, test_loss=21.98
# 228, 1.285%, train_loss=63.481, test_loss=21.99
# 229, 1.285%, train_loss=63.504, test_loss=21.999
# 230, 1.285%, train_loss=63.527, test_loss=22.009
# 231, 1.285%, train_loss=63.549, test_loss=22.018
# 232, 1.268%, train_loss=63.571, test_loss=22.027
# 233, 1.268%, train_loss=63.593, test_loss=22.036
# 234, 1.268%, train_loss=63.615, test_loss=22.045
# 235, 1.268%, train_loss=63.636, test_loss=22.054
# 236, 1.268%, train_loss=63.657, test_loss=22.063
# 237, 1.268%, train_loss=63.678, test_loss=22.071
# 238, 1.268%, train_loss=63.698, test_loss=22.08
# 239, 1.268%, train_loss=63.718, test_loss=22.088
# 240, 1.268%, train_loss=63.738, test_loss=22.096
# 241, 1.268%, train_loss=63.757, test_loss=22.104
# 242, 1.268%, train_loss=63.776, test_loss=22.112
# 243, 1.268%, train_loss=63.795, test_loss=22.12
# 244, 1.268%, train_loss=63.814, test_loss=22.128
# 245, 1.268%, train_loss=63.832, test_loss=22.135
# 246, 1.268%, train_loss=63.85, test_loss=22.143
# 247, 1.268%, train_loss=63.868, test_loss=22.15
# 248, 1.268%, train_loss=63.886, test_loss=22.157
# 249, 1.268%, train_loss=63.903, test_loss=22.164
# 250, 1.268%, train_loss=63.92, test_loss=22.172
# 251, 1.268%, train_loss=63.937, test_loss=22.178
# 252, 1.268%, train_loss=63.953, test_loss=22.185
# 253, 1.268%, train_loss=63.97, test_loss=22.192
# 254, 1.268%, train_loss=63.986, test_loss=22.199
# 255, 1.268%, train_loss=64.002, test_loss=22.205
# 256, 1.268%, train_loss=64.017, test_loss=22.212
# 257, 1.268%, train_loss=64.032, test_loss=22.218
# 258, 1.268%, train_loss=64.047, test_loss=22.224
# 259, 1.268%, train_loss=64.062, test_loss=22.23
# 260, 1.251%, train_loss=64.077, test_loss=22.236
# 261, 1.234%, train_loss=64.091, test_loss=22.242
# 262, 1.234%, train_loss=64.105, test_loss=22.248
# 263, 1.234%, train_loss=64.119, test_loss=22.254
# 264, 1.234%, train_loss=64.133, test_loss=22.259
# 265, 1.234%, train_loss=64.147, test_loss=22.265
# 266, 1.234%, train_loss=64.16, test_loss=22.271
# 267, 1.234%, train_loss=64.173, test_loss=22.276
# 268, 1.234%, train_loss=64.186, test_loss=22.281
# 269, 1.234%, train_loss=64.198, test_loss=22.287
# 270, 1.217%, train_loss=64.211, test_loss=22.292
# 271, 1.217%, train_loss=64.223, test_loss=22.297
# 272, 1.217%, train_loss=64.235, test_loss=22.302
# 273, 1.2%, train_loss=64.247, test_loss=22.307
# 274, 1.2%, train_loss=64.259, test_loss=22.311
# 275, 1.2%, train_loss=64.27, test_loss=22.316
# 276, 1.2%, train_loss=64.282, test_loss=22.321
# 277, 1.2%, train_loss=64.293, test_loss=22.325
# 278, 1.2%, train_loss=64.304, test_loss=22.33
# 279, 1.2%, train_loss=64.315, test_loss=22.334
# 280, 1.2%, train_loss=64.325, test_loss=22.339
# 281, 1.2%, train_loss=64.336, test_loss=22.343
# 282, 1.2%, train_loss=64.346, test_loss=22.347
# 283, 1.2%, train_loss=64.356, test_loss=22.351
# 284, 1.2%, train_loss=64.366, test_loss=22.356
# 285, 1.2%, train_loss=64.376, test_loss=22.36
# 286, 1.2%, train_loss=64.385, test_loss=22.364
# 287, 1.2%, train_loss=64.395, test_loss=22.367
# 288, 1.2%, train_loss=64.404, test_loss=22.371
# 289, 1.2%, train_loss=64.413, test_loss=22.375
# 290, 1.2%, train_loss=64.422, test_loss=22.379
# 291, 1.183%, train_loss=64.431, test_loss=22.382
# 292, 1.183%, train_loss=64.44, test_loss=22.386
# 293, 1.183%, train_loss=64.448, test_loss=22.389
# 294, 1.183%, train_loss=64.457, test_loss=22.393
# 295, 1.183%, train_loss=64.465, test_loss=22.396
# 296, 1.183%, train_loss=64.473, test_loss=22.4
# 297, 1.183%, train_loss=64.481, test_loss=22.403
# 298, 1.183%, train_loss=64.489, test_loss=22.406
# 299, 1.183%, train_loss=64.496, test_loss=22.409
# 300, 1.183%, train_loss=64.504, test_loss=22.413
# 301, 1.183%, train_loss=64.511, test_loss=22.416
# 302, 1.183%, train_loss=64.519, test_loss=22.419
# 303, 1.183%, train_loss=64.526, test_loss=22.422
# 304, 1.166%, train_loss=64.533, test_loss=22.424
# 305, 1.166%, train_loss=64.54, test_loss=22.427
# 306, 1.166%, train_loss=64.547, test_loss=22.43
# 307, 1.166%, train_loss=64.554, test_loss=22.433
# 308, 1.166%, train_loss=64.56, test_loss=22.436
# 309, 1.166%, train_loss=64.567, test_loss=22.438
# 310, 1.166%, train_loss=64.573, test_loss=22.441
# 311, 1.166%, train_loss=64.579, test_loss=22.444
# 312, 1.166%, train_loss=64.586, test_loss=22.446
# 313, 1.166%, train_loss=64.592, test_loss=22.449
# 314, 1.166%, train_loss=64.598, test_loss=22.451
# 315, 1.166%, train_loss=64.604, test_loss=22.453
# 316, 1.166%, train_loss=64.609, test_loss=22.456
# 317, 1.149%, train_loss=64.615, test_loss=22.458
# 318, 1.149%, train_loss=64.62, test_loss=22.46
# 319, 1.149%, train_loss=64.626, test_loss=22.463
# 320, 1.149%, train_loss=64.631, test_loss=22.465
# 321, 1.149%, train_loss=64.637, test_loss=22.467
# 322, 1.149%, train_loss=64.642, test_loss=22.469
# 323, 1.149%, train_loss=64.647, test_loss=22.471
# 324, 1.149%, train_loss=64.652, test_loss=22.473
# 325, 1.149%, train_loss=64.657, test_loss=22.475
# 326, 1.149%, train_loss=64.662, test_loss=22.477
# 327, 1.149%, train_loss=64.666, test_loss=22.479
# 328, 1.149%, train_loss=64.671, test_loss=22.481
# 329, 1.149%, train_loss=64.676, test_loss=22.483
# 330, 1.149%, train_loss=64.68, test_loss=22.485
# 331, 1.149%, train_loss=64.685, test_loss=22.487
# 332, 1.149%, train_loss=64.689, test_loss=22.489
# 333, 1.149%, train_loss=64.693, test_loss=22.49
# 334, 1.149%, train_loss=64.697, test_loss=22.492
# 335, 1.149%, train_loss=64.702, test_loss=22.494
# 336, 1.149%, train_loss=64.706, test_loss=22.496
# 337, 1.149%, train_loss=64.71, test_loss=22.497
# 338, 1.149%, train_loss=64.714, test_loss=22.499
# 339, 1.149%, train_loss=64.717, test_loss=22.5
# 340, 1.149%, train_loss=64.721, test_loss=22.502
# 341, 1.149%, train_loss=64.725, test_loss=22.503
# 342, 1.149%, train_loss=64.729, test_loss=22.505
# 343, 1.149%, train_loss=64.732, test_loss=22.506
# 344, 1.149%, train_loss=64.736, test_loss=22.508
# 345, 1.149%, train_loss=64.739, test_loss=22.509
# 346, 1.149%, train_loss=64.743, test_loss=22.511
# 347, 1.149%, train_loss=64.746, test_loss=22.512
# 348, 1.149%, train_loss=64.749, test_loss=22.513
# 349, 1.149%, train_loss=64.752, test_loss=22.515
# 350, 1.149%, train_loss=64.756, test_loss=22.516
# 351, 1.149%, train_loss=64.759, test_loss=22.517
# 352, 1.149%, train_loss=64.762, test_loss=22.519
# 353, 1.149%, train_loss=64.765, test_loss=22.52
# 354, 1.149%, train_loss=64.768, test_loss=22.521
# 355, 1.149%, train_loss=64.771, test_loss=22.522
# 356, 1.149%, train_loss=64.773, test_loss=22.523
# 357, 1.149%, train_loss=64.776, test_loss=22.525
# 358, 1.149%, train_loss=64.779, test_loss=22.526
# 359, 1.149%, train_loss=64.782, test_loss=22.527
# 360, 1.149%, train_loss=64.784, test_loss=22.528
# 361, 1.149%, train_loss=64.787, test_loss=22.529
# 362, 1.149%, train_loss=64.789, test_loss=22.53
# 363, 1.149%, train_loss=64.792, test_loss=22.531
# 364, 1.149%, train_loss=64.794, test_loss=22.532
# 365, 1.149%, train_loss=64.797, test_loss=22.533
# 366, 1.149%, train_loss=64.799, test_loss=22.534
# 367, 1.149%, train_loss=64.802, test_loss=22.535
# 368, 1.149%, train_loss=64.804, test_loss=22.536
# 369, 1.149%, train_loss=64.806, test_loss=22.537
# 370, 1.149%, train_loss=64.808, test_loss=22.538
# 371, 1.149%, train_loss=64.81, test_loss=22.539
# 372, 1.149%, train_loss=64.813, test_loss=22.54
# 373, 1.149%, train_loss=64.815, test_loss=22.54
# 374, 1.149%, train_loss=64.817, test_loss=22.541
# 375, 1.149%, train_loss=64.819, test_loss=22.542
# 376, 1.149%, train_loss=64.821, test_loss=22.543
# 377, 1.149%, train_loss=64.823, test_loss=22.544
# 378, 1.149%, train_loss=64.825, test_loss=22.544
# 379, 1.149%, train_loss=64.826, test_loss=22.545
# 380, 1.149%, train_loss=64.828, test_loss=22.546
# 381, 1.149%, train_loss=64.83, test_loss=22.547
# 382, 1.149%, train_loss=64.832, test_loss=22.548
# 383, 1.149%, train_loss=64.834, test_loss=22.548
# 384, 1.149%, train_loss=64.835, test_loss=22.549
# 385, 1.149%, train_loss=64.837, test_loss=22.55
# 386, 1.149%, train_loss=64.839, test_loss=22.55
# 387, 1.149%, train_loss=64.84, test_loss=22.551
# 388, 1.149%, train_loss=64.842, test_loss=22.552
# 389, 1.149%, train_loss=64.844, test_loss=22.552
# 390, 1.149%, train_loss=64.845, test_loss=22.553
# 391, 1.149%, train_loss=64.847, test_loss=22.554
# 392, 1.149%, train_loss=64.848, test_loss=22.554
# 393, 1.149%, train_loss=64.85, test_loss=22.555
# 394, 1.149%, train_loss=64.851, test_loss=22.555
# 395, 1.149%, train_loss=64.852, test_loss=22.556
# 396, 1.149%, train_loss=64.854, test_loss=22.556
# 397, 1.149%, train_loss=64.855, test_loss=22.557
# 398, 1.149%, train_loss=64.856, test_loss=22.558
# 399, 1.149%, train_loss=64.858, test_loss=22.558
# 400, 1.149%, train_loss=64.859, test_loss=22.559
# 401, 1.149%, train_loss=64.86, test_loss=22.559
# 402, 1.149%, train_loss=64.862, test_loss=22.56
# 403, 1.149%, train_loss=64.863, test_loss=22.56
# 404, 1.149%, train_loss=64.864, test_loss=22.561
# 405, 1.149%, train_loss=64.865, test_loss=22.561
# 406, 1.149%, train_loss=64.866, test_loss=22.562
# 407, 1.149%, train_loss=64.867, test_loss=22.562
# 408, 1.149%, train_loss=64.869, test_loss=22.563
# 409, 1.149%, train_loss=64.87, test_loss=22.563
# 410, 1.149%, train_loss=64.871, test_loss=22.563
# 411, 1.149%, train_loss=64.872, test_loss=22.564
# 412, 1.149%, train_loss=64.873, test_loss=22.564
# 413, 1.149%, train_loss=64.874, test_loss=22.565
# 414, 1.149%, train_loss=64.875, test_loss=22.565
# 415, 1.149%, train_loss=64.876, test_loss=22.566
# 416, 1.149%, train_loss=64.877, test_loss=22.566
# 417, 1.149%, train_loss=64.878, test_loss=22.566
# 418, 1.149%, train_loss=64.879, test_loss=22.567
# 419, 1.149%, train_loss=64.879, test_loss=22.567
# 420, 1.149%, train_loss=64.88, test_loss=22.567
# 421, 1.149%, train_loss=64.881, test_loss=22.568
# 422, 1.149%, train_loss=64.882, test_loss=22.568
# 423, 1.149%, train_loss=64.883, test_loss=22.568
# 424, 1.149%, train_loss=64.884, test_loss=22.569
# 425, 1.149%, train_loss=64.885, test_loss=22.569
# 426, 1.149%, train_loss=64.885, test_loss=22.569
# 427, 1.149%, train_loss=64.886, test_loss=22.57
# 428, 1.149%, train_loss=64.887, test_loss=22.57
# 429, 1.149%, train_loss=64.888, test_loss=22.57
# 430, 1.149%, train_loss=64.888, test_loss=22.571
# 431, 1.149%, train_loss=64.889, test_loss=22.571
# 432, 1.149%, train_loss=64.89, test_loss=22.571
# 433, 1.149%, train_loss=64.891, test_loss=22.572
# 434, 1.149%, train_loss=64.891, test_loss=22.572
# 435, 1.149%, train_loss=64.892, test_loss=22.572
# 436, 1.149%, train_loss=64.893, test_loss=22.572
# 437, 1.149%, train_loss=64.893, test_loss=22.573
# 438, 1.149%, train_loss=64.894, test_loss=22.573
# 439, 1.149%, train_loss=64.895, test_loss=22.573
# 440, 1.149%, train_loss=64.895, test_loss=22.574
# 441, 1.149%, train_loss=64.896, test_loss=22.574
# 442, 1.149%, train_loss=64.896, test_loss=22.574
# 443, 1.149%, train_loss=64.897, test_loss=22.574
# 444, 1.149%, train_loss=64.898, test_loss=22.574
# 445, 1.149%, train_loss=64.898, test_loss=22.575
# 446, 1.149%, train_loss=64.899, test_loss=22.575
# 447, 1.149%, train_loss=64.899, test_loss=22.575
# 448, 1.149%, train_loss=64.9, test_loss=22.575
# 449, 1.149%, train_loss=64.9, test_loss=22.576
# 450, 1.149%, train_loss=64.901, test_loss=22.576
# 451, 1.149%, train_loss=64.901, test_loss=22.576
# 452, 1.149%, train_loss=64.902, test_loss=22.576
# 453, 1.149%, train_loss=64.902, test_loss=22.576
# 454, 1.149%, train_loss=64.903, test_loss=22.577
# 455, 1.149%, train_loss=64.903, test_loss=22.577
# 456, 1.149%, train_loss=64.904, test_loss=22.577
# 457, 1.149%, train_loss=64.904, test_loss=22.577
# 458, 1.149%, train_loss=64.905, test_loss=22.577
# 459, 1.149%, train_loss=64.905, test_loss=22.578
# 460, 1.149%, train_loss=64.905, test_loss=22.578
# 461, 1.149%, train_loss=64.906, test_loss=22.578
# 462, 1.149%, train_loss=64.906, test_loss=22.578
# 463, 1.149%, train_loss=64.907, test_loss=22.578
# 464, 1.149%, train_loss=64.907, test_loss=22.578
# 465, 1.149%, train_loss=64.907, test_loss=22.579
# 466, 1.149%, train_loss=64.908, test_loss=22.579
# 467, 1.149%, train_loss=64.908, test_loss=22.579
# 468, 1.149%, train_loss=64.909, test_loss=22.579
# 469, 1.149%, train_loss=64.909, test_loss=22.579
# 470, 1.149%, train_loss=64.909, test_loss=22.579
# 471, 1.149%, train_loss=64.91, test_loss=22.579
# 472, 1.149%, train_loss=64.91, test_loss=22.58
# 473, 1.149%, train_loss=64.91, test_loss=22.58
# 474, 1.149%, train_loss=64.911, test_loss=22.58
# 475, 1.149%, train_loss=64.911, test_loss=22.58
# 476, 1.149%, train_loss=64.911, test_loss=22.58
# 477, 1.149%, train_loss=64.912, test_loss=22.58
# 478, 1.149%, train_loss=64.912, test_loss=22.58
# 479, 1.149%, train_loss=64.912, test_loss=22.581
# 480, 1.149%, train_loss=64.913, test_loss=22.581
# 481, 1.149%, train_loss=64.913, test_loss=22.581
# 482, 1.149%, train_loss=64.913, test_loss=22.581
# 483, 1.149%, train_loss=64.913, test_loss=22.581
# 484, 1.149%, train_loss=64.914, test_loss=22.581
# 485, 1.149%, train_loss=64.914, test_loss=22.581
# 486, 1.149%, train_loss=64.914, test_loss=22.581
# 487, 1.149%, train_loss=64.914, test_loss=22.581
# 488, 1.149%, train_loss=64.915, test_loss=22.582
# 489, 1.149%, train_loss=64.915, test_loss=22.582
# 490, 1.149%, train_loss=64.915, test_loss=22.582
# 491, 1.149%, train_loss=64.915, test_loss=22.582
# 492, 1.149%, train_loss=64.916, test_loss=22.582
# 493, 1.149%, train_loss=64.916, test_loss=22.582
# 494, 1.149%, train_loss=64.916, test_loss=22.582
# 495, 1.149%, train_loss=64.916, test_loss=22.582
# 496, 1.149%, train_loss=64.917, test_loss=22.582
# 497, 1.149%, train_loss=64.917, test_loss=22.582
# 498, 1.149%, train_loss=64.917, test_loss=22.583
# 499, 1.149%, train_loss=64.917, test_loss=22.583
# 500, 1.149%, train_loss=64.917, test_loss=22.583
# 501, 1.149%, train_loss=64.918, test_loss=22.583
# 502, 1.149%, train_loss=64.918, test_loss=22.583
# 503, 1.149%, train_loss=64.918, test_loss=22.583
# 504, 1.149%, train_loss=64.918, test_loss=22.583
# 505, 1.149%, train_loss=64.918, test_loss=22.583
# 506, 1.149%, train_loss=64.919, test_loss=22.583
# 507, 1.149%, train_loss=64.919, test_loss=22.583
# 508, 1.149%, train_loss=64.919, test_loss=22.583
# 509, 1.149%, train_loss=64.919, test_loss=22.583
# 510, 1.149%, train_loss=64.919, test_loss=22.583
# 511, 1.149%, train_loss=64.92, test_loss=22.584
# 512, 1.149%, train_loss=64.92, test_loss=22.584
# 513, 1.149%, train_loss=64.92, test_loss=22.584
# 514, 1.149%, train_loss=64.92, test_loss=22.584
# 515, 1.149%, train_loss=64.92, test_loss=22.584
# 516, 1.149%, train_loss=64.92, test_loss=22.584
# 517, 1.149%, train_loss=64.92, test_loss=22.584
# 518, 1.149%, train_loss=64.921, test_loss=22.584
# 519, 1.149%, train_loss=64.921, test_loss=22.584
# 520, 1.149%, train_loss=64.921, test_loss=22.584
# 521, 1.149%, train_loss=64.921, test_loss=22.584
# 522, 1.149%, train_loss=64.921, test_loss=22.584
# 523, 1.149%, train_loss=64.921, test_loss=22.584
# 524, 1.149%, train_loss=64.921, test_loss=22.584
# 525, 1.149%, train_loss=64.922, test_loss=22.584
# 526, 1.149%, train_loss=64.922, test_loss=22.584
# 527, 1.149%, train_loss=64.922, test_loss=22.584
# 528, 1.149%, train_loss=64.922, test_loss=22.585
# 529, 1.149%, train_loss=64.922, test_loss=22.585
# 530, 1.149%, train_loss=64.922, test_loss=22.585
# 531, 1.149%, train_loss=64.922, test_loss=22.585
# 532, 1.149%, train_loss=64.922, test_loss=22.585
# 533, 1.149%, train_loss=64.923, test_loss=22.585
# 534, 1.149%, train_loss=64.923, test_loss=22.585
# 535, 1.149%, train_loss=64.923, test_loss=22.585
# 536, 1.149%, train_loss=64.923, test_loss=22.585
# 537, 1.149%, train_loss=64.923, test_loss=22.585
# 538, 1.149%, train_loss=64.923, test_loss=22.585
# 539, 1.149%, train_loss=64.923, test_loss=22.585
# 540, 1.149%, train_loss=64.923, test_loss=22.585
# 541, 1.149%, train_loss=64.923, test_loss=22.585
# 542, 1.149%, train_loss=64.923, test_loss=22.585
# 543, 1.149%, train_loss=64.924, test_loss=22.585
# 544, 1.149%, train_loss=64.924, test_loss=22.585
# 545, 1.149%, train_loss=64.924, test_loss=22.585
# 546, 1.149%, train_loss=64.924, test_loss=22.585
# 547, 1.149%, train_loss=64.924, test_loss=22.585
# 548, 1.149%, train_loss=64.924, test_loss=22.585
# 549, 1.149%, train_loss=64.924, test_loss=22.585
# 550, 1.149%, train_loss=64.924, test_loss=22.585
# 551, 1.149%, train_loss=64.924, test_loss=22.585
# 552, 1.149%, train_loss=64.924, test_loss=22.585
# 553, 1.149%, train_loss=64.924, test_loss=22.586
# 554, 1.149%, train_loss=64.924, test_loss=22.586
# 555, 1.149%, train_loss=64.925, test_loss=22.586
# 556, 1.149%, train_loss=64.925, test_loss=22.586
# 557, 1.149%, train_loss=64.925, test_loss=22.586
# 558, 1.149%, train_loss=64.925, test_loss=22.586
# 559, 1.149%, train_loss=64.925, test_loss=22.586
# 560, 1.149%, train_loss=64.925, test_loss=22.586
# 561, 1.149%, train_loss=64.925, test_loss=22.586
# 562, 1.149%, train_loss=64.925, test_loss=22.586
# 563, 1.149%, train_loss=64.925, test_loss=22.586
# 564, 1.149%, train_loss=64.925, test_loss=22.586
# 565, 1.149%, train_loss=64.925, test_loss=22.586
# 566, 1.149%, train_loss=64.925, test_loss=22.586
# 567, 1.149%, train_loss=64.925, test_loss=22.586
# 568, 1.149%, train_loss=64.925, test_loss=22.586
# 569, 1.149%, train_loss=64.925, test_loss=22.586
# 570, 1.149%, train_loss=64.926, test_loss=22.586
# 571, 1.149%, train_loss=64.926, test_loss=22.586
# 572, 1.149%, train_loss=64.926, test_loss=22.586
# 573, 1.149%, train_loss=64.926, test_loss=22.586
# 574, 1.149%, train_loss=64.926, test_loss=22.586
# 575, 1.149%, train_loss=64.926, test_loss=22.586
# 576, 1.149%, train_loss=64.926, test_loss=22.586
# 577, 1.149%, train_loss=64.926, test_loss=22.586
# 578, 1.149%, train_loss=64.926, test_loss=22.586
# 579, 1.149%, train_loss=64.926, test_loss=22.586
# 580, 1.149%, train_loss=64.926, test_loss=22.586
# 581, 1.149%, train_loss=64.926, test_loss=22.586
# 582, 1.149%, train_loss=64.926, test_loss=22.586
# 583, 1.149%, train_loss=64.926, test_loss=22.586
# 584, 1.149%, train_loss=64.926, test_loss=22.586
# 585, 1.149%, train_loss=64.926, test_loss=22.586
# 586, 1.149%, train_loss=64.926, test_loss=22.586
# 587, 1.149%, train_loss=64.926, test_loss=22.586
# 588, 1.149%, train_loss=64.926, test_loss=22.586
# 589, 1.149%, train_loss=64.926, test_loss=22.586
# 590, 1.149%, train_loss=64.926, test_loss=22.586
# 591, 1.149%, train_loss=64.926, test_loss=22.586
# 592, 1.149%, train_loss=64.927, test_loss=22.586
# 593, 1.149%, train_loss=64.927, test_loss=22.586
# 594, 1.149%, train_loss=64.927, test_loss=22.586
# 595, 1.149%, train_loss=64.927, test_loss=22.586
# 596, 1.149%, train_loss=64.927, test_loss=22.586
# 597, 1.149%, train_loss=64.927, test_loss=22.586
# 598, 1.149%, train_loss=64.927, test_loss=22.586
# 599, 1.149%, train_loss=64.927, test_loss=22.587
# 600, 1.149%, train_loss=64.927, test_loss=22.587
# 601, 1.149%, train_loss=64.927, test_loss=22.587
# 602, 1.149%, train_loss=64.927, test_loss=22.587
# 603, 1.149%, train_loss=64.927, test_loss=22.587
# 604, 1.149%, train_loss=64.927, test_loss=22.587
# 605, 1.149%, train_loss=64.927, test_loss=22.587
# 606, 1.149%, train_loss=64.927, test_loss=22.587
# 607, 1.149%, train_loss=64.927, test_loss=22.587
# 608, 1.149%, train_loss=64.927, test_loss=22.587
# 609, 1.149%, train_loss=64.927, test_loss=22.587
# 610, 1.149%, train_loss=64.927, test_loss=22.587
# 611, 1.149%, train_loss=64.927, test_loss=22.587
# 612, 1.149%, train_loss=64.927, test_loss=22.587
# 613, 1.149%, train_loss=64.927, test_loss=22.587
# 614, 1.149%, train_loss=64.927, test_loss=22.587
# 615, 1.149%, train_loss=64.927, test_loss=22.587
# 616, 1.149%, train_loss=64.927, test_loss=22.587
# 617, 1.149%, train_loss=64.927, test_loss=22.587
# 618, 1.149%, train_loss=64.927, test_loss=22.587
# 619, 1.149%, train_loss=64.927, test_loss=22.587
# 620, 1.149%, train_loss=64.927, test_loss=22.587
# 621, 1.149%, train_loss=64.927, test_loss=22.587
# 622, 1.149%, train_loss=64.927, test_loss=22.587
# 623, 1.149%, train_loss=64.927, test_loss=22.587
# 624, 1.149%, train_loss=64.927, test_loss=22.587
# 625, 1.149%, train_loss=64.927, test_loss=22.587
# 626, 1.149%, train_loss=64.927, test_loss=22.587
# 627, 1.149%, train_loss=64.928, test_loss=22.587
# 628, 1.149%, train_loss=64.928, test_loss=22.587
# 629, 1.149%, train_loss=64.928, test_loss=22.587
# 630, 1.149%, train_loss=64.928, test_loss=22.587
# 631, 1.149%, train_loss=64.928, test_loss=22.587
# 632, 1.149%, train_loss=64.928, test_loss=22.587
# 633, 1.149%, train_loss=64.928, test_loss=22.587
# 634, 1.149%, train_loss=64.928, test_loss=22.587
# 635, 1.149%, train_loss=64.928, test_loss=22.587
# 636, 1.149%, train_loss=64.928, test_loss=22.587
# 637, 1.149%, train_loss=64.928, test_loss=22.587
# 638, 1.149%, train_loss=64.928, test_loss=22.587
# 639, 1.149%, train_loss=64.928, test_loss=22.587
# 640, 1.149%, train_loss=64.928, test_loss=22.587
# 641, 1.149%, train_loss=64.928, test_loss=22.587
# 642, 1.149%, train_loss=64.928, test_loss=22.587
# 643, 1.149%, train_loss=64.928, test_loss=22.587
# 644, 1.149%, train_loss=64.928, test_loss=22.587
# 645, 1.149%, train_loss=64.928, test_loss=22.587
# 646, 1.149%, train_loss=64.928, test_loss=22.587
# 647, 1.149%, train_loss=64.928, test_loss=22.587
# 648, 1.149%, train_loss=64.928, test_loss=22.587
# 649, 1.149%, train_loss=64.928, test_loss=22.587
# 650, 1.149%, train_loss=64.928, test_loss=22.587
# 651, 1.149%, train_loss=64.928, test_loss=22.587
# 652, 1.149%, train_loss=64.928, test_loss=22.587
# 653, 1.149%, train_loss=64.928, test_loss=22.587
# 654, 1.149%, train_loss=64.928, test_loss=22.587
# 655, 1.149%, train_loss=64.928, test_loss=22.587
# 656, 1.149%, train_loss=64.928, test_loss=22.587
# 657, 1.149%, train_loss=64.928, test_loss=22.587
# 658, 1.149%, train_loss=64.928, test_loss=22.587
# 659, 1.149%, train_loss=64.928, test_loss=22.587
# 660, 1.149%, train_loss=64.928, test_loss=22.587
# 661, 1.149%, train_loss=64.928, test_loss=22.587
# 662, 1.149%, train_loss=64.928, test_loss=22.587
# 663, 1.149%, train_loss=64.928, test_loss=22.587
# 664, 1.149%, train_loss=64.928, test_loss=22.587
# 665, 1.149%, train_loss=64.928, test_loss=22.587
# 666, 1.149%, train_loss=64.928, test_loss=22.587
# 667, 1.149%, train_loss=64.928, test_loss=22.587
# 668, 1.149%, train_loss=64.928, test_loss=22.587
# 669, 1.149%, train_loss=64.928, test_loss=22.587
# 670, 1.149%, train_loss=64.928, test_loss=22.587
# 671, 1.149%, train_loss=64.928, test_loss=22.587
# 672, 1.149%, train_loss=64.928, test_loss=22.587
# 673, 1.149%, train_loss=64.928, test_loss=22.587
# 674, 1.149%, train_loss=64.928, test_loss=22.587
# 675, 1.149%, train_loss=64.928, test_loss=22.587
# 676, 1.149%, train_loss=64.928, test_loss=22.587
# 677, 1.149%, train_loss=64.928, test_loss=22.587
# 678, 1.149%, train_loss=64.928, test_loss=22.587
# 679, 1.149%, train_loss=64.928, test_loss=22.587
# 680, 1.149%, train_loss=64.928, test_loss=22.587
# 681, 1.149%, train_loss=64.928, test_loss=22.587
# 682, 1.149%, train_loss=64.928, test_loss=22.587
# 683, 1.149%, train_loss=64.928, test_loss=22.587
# 684, 1.149%, train_loss=64.928, test_loss=22.587
# 685, 1.149%, train_loss=64.928, test_loss=22.587
# 686, 1.149%, train_loss=64.928, test_loss=22.587
# 687, 1.149%, train_loss=64.928, test_loss=22.587
# 688, 1.149%, train_loss=64.928, test_loss=22.587
# 689, 1.149%, train_loss=64.928, test_loss=22.587
# 690, 1.149%, train_loss=64.928, test_loss=22.587
# 691, 1.149%, train_loss=64.928, test_loss=22.587
# 692, 1.149%, train_loss=64.928, test_loss=22.587
# 693, 1.149%, train_loss=64.928, test_loss=22.587
# 694, 1.149%, train_loss=64.928, test_loss=22.587
# 695, 1.149%, train_loss=64.928, test_loss=22.587
# 696, 1.149%, train_loss=64.928, test_loss=22.587
# 697, 1.149%, train_loss=64.928, test_loss=22.587
# 698, 1.149%, train_loss=64.928, test_loss=22.587
# 699, 1.149%, train_loss=64.928, test_loss=22.587
# 700, 1.149%, train_loss=64.928, test_loss=22.587
# 701, 1.149%, train_loss=64.928, test_loss=22.587
# 702, 1.149%, train_loss=64.928, test_loss=22.587
# 703, 1.149%, train_loss=64.928, test_loss=22.587
# 704, 1.149%, train_loss=64.928, test_loss=22.587
# 705, 1.149%, train_loss=64.928, test_loss=22.587
# 706, 1.149%, train_loss=64.928, test_loss=22.587
# 707, 1.149%, train_loss=64.928, test_loss=22.587
# 708, 1.149%, train_loss=64.928, test_loss=22.587
# 709, 1.149%, train_loss=64.928, test_loss=22.587
# 710, 1.149%, train_loss=64.928, test_loss=22.587
# 711, 1.149%, train_loss=64.928, test_loss=22.587
# 712, 1.149%, train_loss=64.928, test_loss=22.587
# 713, 1.149%, train_loss=64.928, test_loss=22.587
# 714, 1.149%, train_loss=64.928, test_loss=22.587
# 715, 1.149%, train_loss=64.928, test_loss=22.587
# 716, 1.149%, train_loss=64.928, test_loss=22.587
# 717, 1.149%, train_loss=64.928, test_loss=22.587
# 718, 1.149%, train_loss=64.928, test_loss=22.587
# 719, 1.149%, train_loss=64.928, test_loss=22.587
# 720, 1.149%, train_loss=64.928, test_loss=22.587
# 721, 1.149%, train_loss=64.928, test_loss=22.587
# 722, 1.149%, train_loss=64.928, test_loss=22.587
# 723, 1.149%, train_loss=64.928, test_loss=22.587
# 724, 1.149%, train_loss=64.928, test_loss=22.587
# 725, 1.149%, train_loss=64.928, test_loss=22.587
# 726, 1.149%, train_loss=64.928, test_loss=22.587
# 727, 1.149%, train_loss=64.928, test_loss=22.587
# 728, 1.149%, train_loss=64.928, test_loss=22.587
# 729, 1.149%, train_loss=64.928, test_loss=22.587
# 730, 1.149%, train_loss=64.928, test_loss=22.587
# 731, 1.149%, train_loss=64.928, test_loss=22.587
# 732, 1.149%, train_loss=64.928, test_loss=22.587
# 733, 1.149%, train_loss=64.928, test_loss=22.587
# 734, 1.149%, train_loss=64.928, test_loss=22.587
# 735, 1.149%, train_loss=64.928, test_loss=22.587
# 736, 1.149%, train_loss=64.928, test_loss=22.587
# 737, 1.149%, train_loss=64.928, test_loss=22.587
# 738, 1.149%, train_loss=64.928, test_loss=22.587
# 739, 1.149%, train_loss=64.928, test_loss=22.587
# 740, 1.149%, train_loss=64.928, test_loss=22.587
# 741, 1.149%, train_loss=64.928, test_loss=22.587
# 742, 1.149%, train_loss=64.928, test_loss=22.587
# 743, 1.149%, train_loss=64.928, test_loss=22.587
# 744, 1.149%, train_loss=64.928, test_loss=22.587
# 745, 1.149%, train_loss=64.928, test_loss=22.587
# 746, 1.149%, train_loss=64.928, test_loss=22.587
# 747, 1.149%, train_loss=64.928, test_loss=22.587
# 748, 1.149%, train_loss=64.928, test_loss=22.587
# 749, 1.149%, train_loss=64.928, test_loss=22.587
# 750, 1.149%, train_loss=64.928, test_loss=22.587
# 751, 1.149%, train_loss=64.928, test_loss=22.587
# 752, 1.149%, train_loss=64.928, test_loss=22.587
# 753, 1.149%, train_loss=64.928, test_loss=22.587
# 754, 1.149%, train_loss=64.928, test_loss=22.587
# 755, 1.149%, train_loss=64.928, test_loss=22.587
# 756, 1.149%, train_loss=64.928, test_loss=22.587
# 757, 1.149%, train_loss=64.928, test_loss=22.587
# 758, 1.149%, train_loss=64.928, test_loss=22.587
# 759, 1.149%, train_loss=64.928, test_loss=22.587
# 760, 1.149%, train_loss=64.928, test_loss=22.587
# 761, 1.149%, train_loss=64.928, test_loss=22.587
# 762, 1.149%, train_loss=64.928, test_loss=22.587
# 763, 1.149%, train_loss=64.928, test_loss=22.587
# 764, 1.149%, train_loss=64.928, test_loss=22.587
# 765, 1.149%, train_loss=64.928, test_loss=22.587
# 766, 1.149%, train_loss=64.928, test_loss=22.587
# 767, 1.149%, train_loss=64.928, test_loss=22.587
# 768, 1.149%, train_loss=64.928, test_loss=22.587
# 769, 1.149%, train_loss=64.928, test_loss=22.587
# 770, 1.149%, train_loss=64.928, test_loss=22.587
# 771, 1.149%, train_loss=64.928, test_loss=22.587
# 772, 1.149%, train_loss=64.929, test_loss=22.587
# 773, 1.149%, train_loss=64.929, test_loss=22.587
# 774, 1.149%, train_loss=64.929, test_loss=22.587
# 775, 1.149%, train_loss=64.929, test_loss=22.587
# 776, 1.149%, train_loss=64.929, test_loss=22.587
# 777, 1.149%, train_loss=64.929, test_loss=22.587
# 778, 1.149%, train_loss=64.929, test_loss=22.587
# 779, 1.149%, train_loss=64.929, test_loss=22.587
# 780, 1.149%, train_loss=64.929, test_loss=22.587
# 781, 1.149%, train_loss=64.929, test_loss=22.587
# 782, 1.149%, train_loss=64.929, test_loss=22.587
# 783, 1.149%, train_loss=64.929, test_loss=22.587
# 784, 1.149%, train_loss=64.929, test_loss=22.587
# 785, 1.149%, train_loss=64.929, test_loss=22.587
# 786, 1.149%, train_loss=64.929, test_loss=22.587
# 787, 1.149%, train_loss=64.929, test_loss=22.587
# 788, 1.149%, train_loss=64.929, test_loss=22.587
# 789, 1.149%, train_loss=64.929, test_loss=22.587
# 790, 1.149%, train_loss=64.929, test_loss=22.587
# 791, 1.149%, train_loss=64.929, test_loss=22.587
# 792, 1.149%, train_loss=64.929, test_loss=22.587
# 793, 1.149%, train_loss=64.929, test_loss=22.587
# 794, 1.149%, train_loss=64.929, test_loss=22.587
# 795, 1.149%, train_loss=64.929, test_loss=22.587
# 796, 1.149%, train_loss=64.929, test_loss=22.587
# 797, 1.149%, train_loss=64.929, test_loss=22.587
# 798, 1.149%, train_loss=64.929, test_loss=22.587
# 799, 1.149%, train_loss=64.929, test_loss=22.587
# 800, 1.149%, train_loss=64.929, test_loss=22.587
# 801, 1.149%, train_loss=64.929, test_loss=22.587
# 802, 1.149%, train_loss=64.929, test_loss=22.587
# 803, 1.149%, train_loss=64.929, test_loss=22.587
# 804, 1.149%, train_loss=64.929, test_loss=22.587
# 805, 1.149%, train_loss=64.929, test_loss=22.587
# 806, 1.149%, train_loss=64.929, test_loss=22.587
# 807, 1.149%, train_loss=64.929, test_loss=22.587
# 808, 1.149%, train_loss=64.929, test_loss=22.587
# 809, 1.149%, train_loss=64.929, test_loss=22.587
# 810, 1.149%, train_loss=64.929, test_loss=22.587
# 811, 1.149%, train_loss=64.929, test_loss=22.587
# 812, 1.149%, train_loss=64.929, test_loss=22.587
# 813, 1.149%, train_loss=64.929, test_loss=22.587
# 814, 1.149%, train_loss=64.929, test_loss=22.587
# 815, 1.149%, train_loss=64.929, test_loss=22.587
# 816, 1.149%, train_loss=64.929, test_loss=22.587
# 817, 1.149%, train_loss=64.929, test_loss=22.587
# 818, 1.149%, train_loss=64.929, test_loss=22.587
# 819, 1.149%, train_loss=64.929, test_loss=22.587
# 820, 1.149%, train_loss=64.929, test_loss=22.587
# 821, 1.149%, train_loss=64.929, test_loss=22.587
# 822, 1.149%, train_loss=64.929, test_loss=22.587
# 823, 1.149%, train_loss=64.929, test_loss=22.587
# 824, 1.149%, train_loss=64.929, test_loss=22.587
# 825, 1.149%, train_loss=64.929, test_loss=22.587
# 826, 1.149%, train_loss=64.929, test_loss=22.587
# 827, 1.149%, train_loss=64.929, test_loss=22.587
# 828, 1.149%, train_loss=64.929, test_loss=22.587
# 829, 1.149%, train_loss=64.929, test_loss=22.587
# 830, 1.149%, train_loss=64.929, test_loss=22.587
# 831, 1.149%, train_loss=64.929, test_loss=22.587
# 832, 1.149%, train_loss=64.929, test_loss=22.587
# 833, 1.149%, train_loss=64.929, test_loss=22.587
# 834, 1.149%, train_loss=64.929, test_loss=22.587
# 835, 1.149%, train_loss=64.929, test_loss=22.587
# 836, 1.149%, train_loss=64.929, test_loss=22.587
# 837, 1.149%, train_loss=64.929, test_loss=22.587
# 838, 1.149%, train_loss=64.929, test_loss=22.587
# 839, 1.149%, train_loss=64.929, test_loss=22.587
# 840, 1.149%, train_loss=64.929, test_loss=22.587
# 841, 1.149%, train_loss=64.929, test_loss=22.587
# 842, 1.149%, train_loss=64.929, test_loss=22.587
# 843, 1.149%, train_loss=64.929, test_loss=22.587
# 844, 1.149%, train_loss=64.929, test_loss=22.587
# 845, 1.149%, train_loss=64.929, test_loss=22.587
# 846, 1.149%, train_loss=64.929, test_loss=22.587
# 847, 1.149%, train_loss=64.929, test_loss=22.587
# 848, 1.149%, train_loss=64.929, test_loss=22.587
# 849, 1.149%, train_loss=64.929, test_loss=22.587
# 850, 1.149%, train_loss=64.929, test_loss=22.587
# 851, 1.149%, train_loss=64.929, test_loss=22.587
# 852, 1.149%, train_loss=64.929, test_loss=22.587
# 853, 1.149%, train_loss=64.929, test_loss=22.587
# 854, 1.149%, train_loss=64.929, test_loss=22.587
# 855, 1.149%, train_loss=64.929, test_loss=22.587
# 856, 1.149%, train_loss=64.929, test_loss=22.587
# 857, 1.149%, train_loss=64.929, test_loss=22.587
# 858, 1.149%, train_loss=64.929, test_loss=22.587
# 859, 1.149%, train_loss=64.929, test_loss=22.587
# 860, 1.149%, train_loss=64.929, test_loss=22.587
# 861, 1.149%, train_loss=64.929, test_loss=22.587
# 862, 1.149%, train_loss=64.929, test_loss=22.587
# 863, 1.149%, train_loss=64.929, test_loss=22.587
# 864, 1.149%, train_loss=64.929, test_loss=22.587
# 865, 1.149%, train_loss=64.929, test_loss=22.587
# 866, 1.149%, train_loss=64.929, test_loss=22.587
# 867, 1.149%, train_loss=64.929, test_loss=22.587
# 868, 1.149%, train_loss=64.929, test_loss=22.587
# 869, 1.149%, train_loss=64.929, test_loss=22.587
# 870, 1.149%, train_loss=64.929, test_loss=22.587
# 871, 1.149%, train_loss=64.929, test_loss=22.587
# 872, 1.149%, train_loss=64.929, test_loss=22.587
# 873, 1.149%, train_loss=64.929, test_loss=22.587
# 874, 1.149%, train_loss=64.929, test_loss=22.587
# 875, 1.149%, train_loss=64.929, test_loss=22.587
# 876, 1.149%, train_loss=64.929, test_loss=22.587
# 877, 1.149%, train_loss=64.929, test_loss=22.587
# 878, 1.149%, train_loss=64.929, test_loss=22.587
# 879, 1.149%, train_loss=64.929, test_loss=22.587
# 880, 1.149%, train_loss=64.929, test_loss=22.587
# 881, 1.149%, train_loss=64.929, test_loss=22.587
# 882, 1.149%, train_loss=64.929, test_loss=22.587
# 883, 1.149%, train_loss=64.929, test_loss=22.587
# 884, 1.149%, train_loss=64.929, test_loss=22.587
# 885, 1.149%, train_loss=64.929, test_loss=22.587
# 886, 1.149%, train_loss=64.929, test_loss=22.587
# 887, 1.149%, train_loss=64.929, test_loss=22.587
# 888, 1.149%, train_loss=64.929, test_loss=22.587
# 889, 1.149%, train_loss=64.929, test_loss=22.587
# 890, 1.149%, train_loss=64.929, test_loss=22.587
# 891, 1.149%, train_loss=64.929, test_loss=22.587
# 892, 1.149%, train_loss=64.929, test_loss=22.587
# 893, 1.149%, train_loss=64.929, test_loss=22.587
# 894, 1.149%, train_loss=64.929, test_loss=22.587
# 895, 1.149%, train_loss=64.929, test_loss=22.587
# 896, 1.149%, train_loss=64.929, test_loss=22.587
# 897, 1.149%, train_loss=64.929, test_loss=22.587
# 898, 1.149%, train_loss=64.929, test_loss=22.587
# 899, 1.149%, train_loss=64.929, test_loss=22.587
# 900, 1.149%, train_loss=64.929, test_loss=22.587
# 901, 1.149%, train_loss=64.929, test_loss=22.587
# 902, 1.149%, train_loss=64.929, test_loss=22.587
# 903, 1.149%, train_loss=64.929, test_loss=22.587
# 904, 1.149%, train_loss=64.929, test_loss=22.587
# 905, 1.149%, train_loss=64.929, test_loss=22.587
# 906, 1.149%, train_loss=64.929, test_loss=22.587
# 907, 1.149%, train_loss=64.929, test_loss=22.587
# 908, 1.149%, train_loss=64.929, test_loss=22.587
# 909, 1.149%, train_loss=64.929, test_loss=22.587
# 910, 1.149%, train_loss=64.929, test_loss=22.587
# 911, 1.149%, train_loss=64.929, test_loss=22.587
# 912, 1.149%, train_loss=64.929, test_loss=22.587
# 913, 1.149%, train_loss=64.929, test_loss=22.587
# 914, 1.149%, train_loss=64.929, test_loss=22.587
# 915, 1.149%, train_loss=64.929, test_loss=22.587
# 916, 1.149%, train_loss=64.929, test_loss=22.587
# 917, 1.149%, train_loss=64.929, test_loss=22.587
# 918, 1.149%, train_loss=64.929, test_loss=22.587
# 919, 1.149%, train_loss=64.929, test_loss=22.587
# 920, 1.149%, train_loss=64.929, test_loss=22.587
# 921, 1.149%, train_loss=64.929, test_loss=22.587
# 922, 1.149%, train_loss=64.929, test_loss=22.587
# 923, 1.149%, train_loss=64.929, test_loss=22.587
# 924, 1.149%, train_loss=64.929, test_loss=22.587
# 925, 1.149%, train_loss=64.929, test_loss=22.587
# 926, 1.149%, train_loss=64.929, test_loss=22.587
# 927, 1.149%, train_loss=64.929, test_loss=22.587
# 928, 1.149%, train_loss=64.929, test_loss=22.587
# 929, 1.149%, train_loss=64.929, test_loss=22.587
# 930, 1.149%, train_loss=64.929, test_loss=22.587
# 931, 1.149%, train_loss=64.929, test_loss=22.587
# 932, 1.149%, train_loss=64.929, test_loss=22.587
# 933, 1.149%, train_loss=64.929, test_loss=22.587
# 934, 1.149%, train_loss=64.929, test_loss=22.587
# 935, 1.149%, train_loss=64.929, test_loss=22.587
# 936, 1.149%, train_loss=64.929, test_loss=22.587
# 937, 1.149%, train_loss=64.929, test_loss=22.587
# 938, 1.149%, train_loss=64.929, test_loss=22.587
# 939, 1.149%, train_loss=64.929, test_loss=22.587
# 940, 1.149%, train_loss=64.929, test_loss=22.587
# 941, 1.149%, train_loss=64.929, test_loss=22.587
# 942, 1.149%, train_loss=64.929, test_loss=22.587
# 943, 1.149%, train_loss=64.929, test_loss=22.587
# 944, 1.149%, train_loss=64.929, test_loss=22.587
# 945, 1.149%, train_loss=64.929, test_loss=22.587
# 946, 1.149%, train_loss=64.929, test_loss=22.587
# 947, 1.149%, train_loss=64.929, test_loss=22.587
# 948, 1.149%, train_loss=64.929, test_loss=22.587
# 949, 1.149%, train_loss=64.929, test_loss=22.587
# 950, 1.149%, train_loss=64.929, test_loss=22.587
# 951, 1.149%, train_loss=64.929, test_loss=22.587
# 952, 1.149%, train_loss=64.929, test_loss=22.587
# 953, 1.149%, train_loss=64.929, test_loss=22.587
# 954, 1.149%, train_loss=64.929, test_loss=22.587
# 955, 1.149%, train_loss=64.929, test_loss=22.587
# 956, 1.149%, train_loss=64.929, test_loss=22.587
# 957, 1.149%, train_loss=64.929, test_loss=22.587
# 958, 1.149%, train_loss=64.929, test_loss=22.587
# 959, 1.149%, train_loss=64.929, test_loss=22.587
# 960, 1.149%, train_loss=64.929, test_loss=22.587
# 961, 1.149%, train_loss=64.929, test_loss=22.587
# 962, 1.149%, train_loss=64.929, test_loss=22.587
# 963, 1.149%, train_loss=64.929, test_loss=22.587
# 964, 1.149%, train_loss=64.929, test_loss=22.587
# 965, 1.149%, train_loss=64.929, test_loss=22.587
# 966, 1.149%, train_loss=64.929, test_loss=22.587
# 967, 1.149%, train_loss=64.929, test_loss=22.587
# 968, 1.149%, train_loss=64.929, test_loss=22.587
# 969, 1.149%, train_loss=64.929, test_loss=22.587
# 970, 1.149%, train_loss=64.929, test_loss=22.587
# 971, 1.149%, train_loss=64.929, test_loss=22.587
# 972, 1.149%, train_loss=64.929, test_loss=22.587
# 973, 1.149%, train_loss=64.929, test_loss=22.587
# 974, 1.149%, train_loss=64.929, test_loss=22.587
# 975, 1.149%, train_loss=64.929, test_loss=22.587
# 976, 1.149%, train_loss=64.929, test_loss=22.587
# 977, 1.149%, train_loss=64.929, test_loss=22.587
# 978, 1.149%, train_loss=64.929, test_loss=22.587
# 979, 1.149%, train_loss=64.929, test_loss=22.587
# 980, 1.149%, train_loss=64.929, test_loss=22.587
# 981, 1.149%, train_loss=64.929, test_loss=22.587
# 982, 1.149%, train_loss=64.929, test_loss=22.587
# 983, 1.149%, train_loss=64.929, test_loss=22.587
# ...
# 8349, 1.149%, train_loss=64.929, test_loss=22.587
# 8350, 1.149%, train_loss=64.929, test_loss=22.587
# 8351, 1.149%, train_loss=64.929, test_loss=22.587
# 8352, 1.149%, train_loss=64.929, test_loss=22.587
# 8353, 1.149%, train_loss=64.929, test_loss=22.587
# 8354, 1.149%, train_loss=64.929, test_loss=22.587
# 8355, 1.149%, train_loss=64.929, test_loss=22.587
# 8356, 1.149%, train_loss=64.929, test_loss=22.587
# 8357, 1.149%, train_loss=64.929, test_loss=22.587
# 8358, 1.149%, train_loss=64.929, test_loss=22.587
# 8359, 1.149%, train_loss=64.929, test_loss=22.587
# 8360, 1.149%, train_loss=64.929, test_loss=22.587
# 8361, 1.149%, train_loss=64.929, test_loss=22.587
# 8362, 1.149%, train_loss=64.929, test_loss=22.587
# 8363, 1.149%, train_loss=64.929, test_loss=22.587
# 8364, 1.149%, train_loss=64.929, test_loss=22.587
# 8365, 1.149%, train_loss=64.929, test_loss=22.587
# 8366, 1.149%, train_loss=64.929, test_loss=22.587
# 8367, 1.149%, train_loss=64.929, test_loss=22.587
# 8368, 1.149%, train_loss=64.929, test_loss=22.587
# 8369, 1.149%, train_loss=64.929, test_loss=22.587
# 8370, 1.149%, train_loss=64.929, test_loss=22.587
# 8371, 1.149%, train_loss=64.929, test_loss=22.587
# 8372, 1.149%, train_loss=64.929, test_loss=22.587
# 8373, 1.149%, train_loss=64.929, test_loss=22.587
# 8374, 1.149%, train_loss=64.929, test_loss=22.587
# 8375, 1.149%, train_loss=64.929, test_loss=22.587
# 8376, 1.149%, train_loss=64.929, test_loss=22.587
# 8377, 1.149%, train_loss=64.929, test_loss=22.587
# 8378, 1.149%, train_loss=64.929, test_loss=22.587
# 8379, 1.149%, train_loss=64.929, test_loss=22.587
# 8380, 1.149%, train_loss=64.929, test_loss=22.587
# 8381, 1.149%, train_loss=64.929, test_loss=22.587
# 8382, 1.149%, train_loss=64.929, test_loss=22.587
# 8383, 1.149%, train_loss=64.929, test_loss=22.587
# 8384, 1.149%, train_loss=64.929, test_loss=22.587
# 8385, 1.149%, train_loss=64.929, test_loss=22.587
# 8386, 1.149%, train_loss=64.929, test_loss=22.587
# 8387, 1.149%, train_loss=64.929, test_loss=22.587
# 8388, 1.149%, train_loss=64.929, test_loss=22.587
# 8389, 1.149%, train_loss=64.929, test_loss=22.587
# 8390, 1.149%, train_loss=64.929, test_loss=22.587
# 8391, 1.149%, train_loss=64.929, test_loss=22.587
# 8392, 1.149%, train_loss=64.929, test_loss=22.587
# 8393, 1.149%, train_loss=64.929, test_loss=22.587
# 8394, 1.149%, train_loss=64.929, test_loss=22.587
# 8395, 1.149%, train_loss=64.929, test_loss=22.587
# 8396, 1.149%, train_loss=64.929, test_loss=22.587
# 8397, 1.149%, train_loss=64.929, test_loss=22.587
# 8398, 1.149%, train_loss=64.929, test_loss=22.587
# 8399, 1.149%, train_loss=64.929, test_loss=22.587
# 8400, 1.149%, train_loss=64.929, test_loss=22.587
# 8401, 1.149%, train_loss=64.929, test_loss=22.587
# 8402, 1.149%, train_loss=64.929, test_loss=22.587
# 8403, 1.149%, train_loss=64.929, test_loss=22.587
# 8404, 1.149%, train_loss=64.929, test_loss=22.587
# 8405, 1.149%, train_loss=64.929, test_loss=22.587
# 8406, 1.149%, train_loss=64.929, test_loss=22.587
# 8407, 1.149%, train_loss=64.929, test_loss=22.587
# 8408, 1.149%, train_loss=64.929, test_loss=22.587
# 8409, 1.149%, train_loss=64.929, test_loss=22.587
# 8410, 1.149%, train_loss=64.929, test_loss=22.587
# 8411, 1.149%, train_loss=64.929, test_loss=22.587
# 8412, 1.149%, train_loss=64.929, test_loss=22.587
# 8413, 1.149%, train_loss=64.929, test_loss=22.587
# 8414, 1.149%, train_loss=64.929, test_loss=22.587
# 8415, 1.149%, train_loss=64.929, test_loss=22.587
# 8416, 1.149%, train_loss=64.929, test_loss=22.587
# 8417, 1.149%, train_loss=64.929, test_loss=22.587
# 8418, 1.149%, train_loss=64.929, test_loss=22.587
# 8419, 1.149%, train_loss=64.929, test_loss=22.587
# 8420, 1.149%, train_loss=64.929, test_loss=22.587
# 8421, 1.149%, train_loss=64.929, test_loss=22.587
# 8422, 1.149%, train_loss=64.929, test_loss=22.587
# 8423, 1.149%, train_loss=64.929, test_loss=22.587
# 8424, 1.149%, train_loss=64.929, test_loss=22.587
# 8425, 1.149%, train_loss=64.929, test_loss=22.587
# 8426, 1.149%, train_loss=64.929, test_loss=22.587
# 8427, 1.149%, train_loss=64.929, test_loss=22.587
# 8428, 1.149%, train_loss=64.929, test_loss=22.587
# 8429, 1.149%, train_loss=64.929, test_loss=22.587
# 8430, 1.149%, train_loss=64.929, test_loss=22.587
# 8431, 1.149%, train_loss=64.929, test_loss=22.587
# 8432, 1.149%, train_loss=64.929, test_loss=22.587
# 8433, 1.149%, train_loss=64.929, test_loss=22.587
# 8434, 1.149%, train_loss=64.929, test_loss=22.587
# 8435, 1.149%, train_loss=64.929, test_loss=22.587
# 8436, 1.149%, train_loss=64.929, test_loss=22.587
# 8437, 1.149%, train_loss=64.929, test_loss=22.587
# 8438, 1.149%, train_loss=64.929, test_loss=22.587
# 8439, 1.149%, train_loss=64.929, test_loss=22.587
# 8440, 1.149%, train_loss=64.929, test_loss=22.587
# 8441, 1.149%, train_loss=64.929, test_loss=22.587
# 8442, 1.149%, train_loss=64.929, test_loss=22.587
# 8443, 1.149%, train_loss=64.929, test_loss=22.587
# 8444, 1.149%, train_loss=64.929, test_loss=22.587
# 8445, 1.149%, train_loss=64.929, test_loss=22.587
# 8446, 1.149%, train_loss=64.929, test_loss=22.587
# 8447, 1.149%, train_loss=64.929, test_loss=22.587
# 8448, 1.149%, train_loss=64.929, test_loss=22.587
# 8449, 1.149%, train_loss=64.929, test_loss=22.587
# 8450, 1.149%, train_loss=64.929, test_loss=22.587
# 8451, 1.149%, train_loss=64.929, test_loss=22.587
# 8452, 1.149%, train_loss=64.929, test_loss=22.587
# 8453, 1.149%, train_loss=64.929, test_loss=22.587
# 8454, 1.149%, train_loss=64.929, test_loss=22.587
# 8455, 1.149%, train_loss=64.929, test_loss=22.587
# 8456, 1.149%, train_loss=64.929, test_loss=22.587
# 8457, 1.149%, train_loss=64.929, test_loss=22.587
# 8458, 1.149%, train_loss=64.929, test_loss=22.587
# 8459, 1.149%, train_loss=64.929, test_loss=22.587
# 8460, 1.149%, train_loss=64.929, test_loss=22.587
# 8461, 1.149%, train_loss=64.929, test_loss=22.587
# 8462, 1.149%, train_loss=64.929, test_loss=22.587
# 8463, 1.149%, train_loss=64.929, test_loss=22.587
# 8464, 1.149%, train_loss=64.929, test_loss=22.587
# 8465, 1.149%, train_loss=64.929, test_loss=22.587
# 8466, 1.149%, train_loss=64.929, test_loss=22.587
# 8467, 1.149%, train_loss=64.929, test_loss=22.587
# 8468, 1.149%, train_loss=64.929, test_loss=22.587
# 8469, 1.149%, train_loss=64.929, test_loss=22.587
# 8470, 1.149%, train_loss=64.929, test_loss=22.587
# 8471, 1.149%, train_loss=64.929, test_loss=22.587
# 8472, 1.149%, train_loss=64.929, test_loss=22.587
# 8473, 1.149%, train_loss=64.929, test_loss=22.587
# 8474, 1.149%, train_loss=64.929, test_loss=22.587
# 8475, 1.149%, train_loss=64.929, test_loss=22.587
# 8476, 1.149%, train_loss=64.929, test_loss=22.587
# 8477, 1.149%, train_loss=64.929, test_loss=22.587
# 8478, 1.149%, train_loss=64.929, test_loss=22.587
# 8479, 1.149%, train_loss=64.929, test_loss=22.587
# 8480, 1.149%, train_loss=64.929, test_loss=22.587
# 8481, 1.149%, train_loss=64.929, test_loss=22.587
# 8482, 1.149%, train_loss=64.929, test_loss=22.587
# 8483, 1.149%, train_loss=64.929, test_loss=22.587
# 8484, 1.149%, train_loss=64.929, test_loss=22.587
# 8485, 1.149%, train_loss=64.929, test_loss=22.587
# 8486, 1.149%, train_loss=64.929, test_loss=22.587
# 8487, 1.149%, train_loss=64.929, test_loss=22.587
# 8488, 1.149%, train_loss=64.929, test_loss=22.587
# 8489, 1.149%, train_loss=64.929, test_loss=22.587
# 8490, 1.149%, train_loss=64.929, test_loss=22.587
# 8491, 1.149%, train_loss=64.929, test_loss=22.587
# 8492, 1.149%, train_loss=64.929, test_loss=22.587
# 8493, 1.149%, train_loss=64.929, test_loss=22.587
# 8494, 1.149%, train_loss=64.929, test_loss=22.587
# 8495, 1.149%, train_loss=64.929, test_loss=22.587
# 8496, 1.149%, train_loss=64.929, test_loss=22.587
# 8497, 1.149%, train_loss=64.929, test_loss=22.587
# 8498, 1.149%, train_loss=64.929, test_loss=22.587
# 8499, 1.149%, train_loss=64.929, test_loss=22.587
# 8500, 1.149%, train_loss=64.929, test_loss=22.587
# 8501, 1.149%, train_loss=64.929, test_loss=22.587
# 8502, 1.149%, train_loss=64.929, test_loss=22.587
# 8503, 1.149%, train_loss=64.929, test_loss=22.587
# 8504, 1.149%, train_loss=64.929, test_loss=22.587
# 8505, 1.149%, train_loss=64.929, test_loss=22.587
# 8506, 1.149%, train_loss=64.929, test_loss=22.587
# 8507, 1.149%, train_loss=64.929, test_loss=22.587
# 8508, 1.149%, train_loss=64.929, test_loss=22.587
# 8509, 1.149%, train_loss=64.929, test_loss=22.587
# 8510, 1.149%, train_loss=64.929, test_loss=22.587
# 8511, 1.149%, train_loss=64.929, test_loss=22.587
# 8512, 1.149%, train_loss=64.929, test_loss=22.587
# 8513, 1.149%, train_loss=64.929, test_loss=22.587
# 8514, 1.149%, train_loss=64.929, test_loss=22.587
# 8515, 1.149%, train_loss=64.929, test_loss=22.587
# 8516, 1.149%, train_loss=64.929, test_loss=22.587
# 8517, 1.149%, train_loss=64.929, test_loss=22.587
# 8518, 1.149%, train_loss=64.929, test_loss=22.587
# 8519, 1.149%, train_loss=64.929, test_loss=22.587
# 8520, 1.149%, train_loss=64.929, test_loss=22.587
# 8521, 1.149%, train_loss=64.929, test_loss=22.587
# 8522, 1.149%, train_loss=64.929, test_loss=22.587
# 8523, 1.149%, train_loss=64.929, test_loss=22.587
# 8524, 1.149%, train_loss=64.929, test_loss=22.587
# 8525, 1.149%, train_loss=64.929, test_loss=22.587
# 8526, 1.149%, train_loss=64.929, test_loss=22.587
# 8527, 1.149%, train_loss=64.929, test_loss=22.587
# 8528, 1.149%, train_loss=64.929, test_loss=22.587
# 8529, 1.149%, train_loss=64.929, test_loss=22.587
# 8530, 1.149%, train_loss=64.929, test_loss=22.587
# 8531, 1.149%, train_loss=64.929, test_loss=22.587
# 8532, 1.149%, train_loss=64.929, test_loss=22.587
# 8533, 1.149%, train_loss=64.929, test_loss=22.587
# 8534, 1.149%, train_loss=64.929, test_loss=22.587
# 8535, 1.149%, train_loss=64.929, test_loss=22.587
# 8536, 1.149%, train_loss=64.929, test_loss=22.587
# 8537, 1.149%, train_loss=64.929, test_loss=22.587
# 8538, 1.149%, train_loss=64.929, test_loss=22.587
# 8539, 1.149%, train_loss=64.929, test_loss=22.587
# 8540, 1.149%, train_loss=64.929, test_loss=22.587
# 8541, 1.149%, train_loss=64.929, test_loss=22.587
# 8542, 1.149%, train_loss=64.929, test_loss=22.587
# 8543, 1.149%, train_loss=64.929, test_loss=22.587
# 8544, 1.149%, train_loss=64.929, test_loss=22.587
# 8545, 1.149%, train_loss=64.929, test_loss=22.587
# 8546, 1.149%, train_loss=64.929, test_loss=22.587
# 8547, 1.149%, train_loss=64.929, test_loss=22.587
# 8548, 1.149%, train_loss=64.929, test_loss=22.587
# 8549, 1.149%, train_loss=64.929, test_loss=22.587
# 8550, 1.149%, train_loss=64.929, test_loss=22.587
# 8551, 1.149%, train_loss=64.929, test_loss=22.587
# 8552, 1.149%, train_loss=64.929, test_loss=22.587
# 8553, 1.149%, train_loss=64.929, test_loss=22.587
# 8554, 1.149%, train_loss=64.929, test_loss=22.587
# 8555, 1.149%, train_loss=64.929, test_loss=22.587
# 8556, 1.149%, train_loss=64.929, test_loss=22.587
# 8557, 1.149%, train_loss=64.929, test_loss=22.587
# 8558, 1.149%, train_loss=64.929, test_loss=22.587
# 8559, 1.149%, train_loss=64.929, test_loss=22.587
# 8560, 1.149%, train_loss=64.929, test_loss=22.587
# 8561, 1.149%, train_loss=64.929, test_loss=22.587
# 8562, 1.149%, train_loss=64.929, test_loss=22.587
# 8563, 1.149%, train_loss=64.929, test_loss=22.587
# 8564, 1.149%, train_loss=64.929, test_loss=22.587
# 8565, 1.149%, train_loss=64.929, test_loss=22.587
# 8566, 1.149%, train_loss=64.929, test_loss=22.587
# 8567, 1.149%, train_loss=64.929, test_loss=22.587
# 8568, 1.149%, train_loss=64.929, test_loss=22.587
# 8569, 1.149%, train_loss=64.929, test_loss=22.587
# 8570, 1.149%, train_loss=64.929, test_loss=22.587
# 8571, 1.149%, train_loss=64.929, test_loss=22.587
# 8572, 1.149%, train_loss=64.929, test_loss=22.587
# 8573, 1.149%, train_loss=64.929, test_loss=22.587
# 8574, 1.149%, train_loss=64.929, test_loss=22.587
# 8575, 1.149%, train_loss=64.929, test_loss=22.587
# 8576, 1.149%, train_loss=64.929, test_loss=22.587
# 8577, 1.149%, train_loss=64.929, test_loss=22.587
# 8578, 1.149%, train_loss=64.929, test_loss=22.587
# 8579, 1.149%, train_loss=64.929, test_loss=22.587
# 8580, 1.149%, train_loss=64.929, test_loss=22.587
# 8581, 1.149%, train_loss=64.929, test_loss=22.587
# 8582, 1.149%, train_loss=64.929, test_loss=22.587
# 8583, 1.149%, train_loss=64.929, test_loss=22.587
# 8584, 1.149%, train_loss=64.929, test_loss=22.587
# 8585, 1.149%, train_loss=64.929, test_loss=22.587
# 8586, 1.149%, train_loss=64.929, test_loss=22.587
# 8587, 1.149%, train_loss=64.929, test_loss=22.587
# 8588, 1.149%, train_loss=64.929, test_loss=22.587
# 8589, 1.149%, train_loss=64.929, test_loss=22.587
# 8590, 1.149%, train_loss=64.929, test_loss=22.587
# 8591, 1.149%, train_loss=64.929, test_loss=22.587
# 8592, 1.149%, train_loss=64.929, test_loss=22.587
# 8593, 1.149%, train_loss=64.929, test_loss=22.587
# 8594, 1.149%, train_loss=64.929, test_loss=22.587
# 8595, 1.149%, train_loss=64.929, test_loss=22.587
# 8596, 1.149%, train_loss=64.929, test_loss=22.587
# 8597, 1.149%, train_loss=64.929, test_loss=22.587
# 8598, 1.149%, train_loss=64.929, test_loss=22.587
# 8599, 1.149%, train_loss=64.929, test_loss=22.587
# 8600, 1.149%, train_loss=64.929, test_loss=22.587
# 8601, 1.149%, train_loss=64.929, test_loss=22.587
# 8602, 1.149%, train_loss=64.929, test_loss=22.587
# 8603, 1.149%, train_loss=64.929, test_loss=22.587
# 8604, 1.149%, train_loss=64.929, test_loss=22.587
# 8605, 1.149%, train_loss=64.929, test_loss=22.587
# 8606, 1.149%, train_loss=64.929, test_loss=22.587
# 8607, 1.149%, train_loss=64.929, test_loss=22.587
# 8608, 1.149%, train_loss=64.929, test_loss=22.587
# 8609, 1.149%, train_loss=64.929, test_loss=22.587
# 8610, 1.149%, train_loss=64.929, test_loss=22.587
# 8611, 1.149%, train_loss=64.929, test_loss=22.587
# 8612, 1.149%, train_loss=64.929, test_loss=22.587
# 8613, 1.149%, train_loss=64.929, test_loss=22.587
# 8614, 1.149%, train_loss=64.929, test_loss=22.587
# 8615, 1.149%, train_loss=64.929, test_loss=22.587
# 8616, 1.149%, train_loss=64.929, test_loss=22.587
# 8617, 1.149%, train_loss=64.929, test_loss=22.587
# 8618, 1.149%, train_loss=64.929, test_loss=22.587
# 8619, 1.149%, train_loss=64.929, test_loss=22.587
# 8620, 1.149%, train_loss=64.929, test_loss=22.587
# 8621, 1.149%, train_loss=64.929, test_loss=22.587
# 8622, 1.149%, train_loss=64.929, test_loss=22.587
# 8623, 1.149%, train_loss=64.929, test_loss=22.587
# 8624, 1.149%, train_loss=64.929, test_loss=22.587
# 8625, 1.149%, train_loss=64.929, test_loss=22.587
# 8626, 1.149%, train_loss=64.929, test_loss=22.587
# 8627, 1.149%, train_loss=64.929, test_loss=22.587
# 8628, 1.149%, train_loss=64.929, test_loss=22.587
# 8629, 1.149%, train_loss=64.929, test_loss=22.587
# 8630, 1.149%, train_loss=64.929, test_loss=22.587
# 8631, 1.149%, train_loss=64.929, test_loss=22.587
# 8632, 1.149%, train_loss=64.929, test_loss=22.587
# 8633, 1.149%, train_loss=64.929, test_loss=22.587
# 8634, 1.149%, train_loss=64.929, test_loss=22.587
# 8635, 1.149%, train_loss=64.929, test_loss=22.587
# 8636, 1.149%, train_loss=64.929, test_loss=22.587
# 8637, 1.149%, train_loss=64.929, test_loss=22.587
# 8638, 1.149%, train_loss=64.929, test_loss=22.587
# 8639, 1.149%, train_loss=64.929, test_loss=22.587
# 8640, 1.149%, train_loss=64.929, test_loss=22.587
# 8641, 1.149%, train_loss=64.929, test_loss=22.587
# 8642, 1.149%, train_loss=64.929, test_loss=22.587
# 8643, 1.149%, train_loss=64.929, test_loss=22.587
# 8644, 1.149%, train_loss=64.929, test_loss=22.587
# 8645, 1.149%, train_loss=64.929, test_loss=22.587
# 8646, 1.149%, train_loss=64.929, test_loss=22.587
# 8647, 1.149%, train_loss=64.929, test_loss=22.587
# 8648, 1.149%, train_loss=64.929, test_loss=22.587
# 8649, 1.149%, train_loss=64.929, test_loss=22.587
# 8650, 1.149%, train_loss=64.929, test_loss=22.587
# 8651, 1.149%, train_loss=64.929, test_loss=22.587
# 8652, 1.149%, train_loss=64.929, test_loss=22.587
# 8653, 1.149%, train_loss=64.929, test_loss=22.587
# 8654, 1.149%, train_loss=64.929, test_loss=22.587
# 8655, 1.149%, train_loss=64.929, test_loss=22.587
# 8656, 1.149%, train_loss=64.929, test_loss=22.587
# 8657, 1.149%, train_loss=64.929, test_loss=22.587
# 8658, 1.149%, train_loss=64.929, test_loss=22.587
# 8659, 1.149%, train_loss=64.929, test_loss=22.587
# 8660, 1.149%, train_loss=64.929, test_loss=22.587
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[551], line 12
#       9 acc_train = round((y_pred == y_train).sum()/N * 100, 3)
#      11 ### Backward ###
# ---> 12 DL_dw = 1/N*sum((y_pred-y_train)*X_train)
#      14 ### Stadt Abstieg ###
#      15 W = W.T - ni*DL_dw
#
# KeyboardInterrupt:

# %%
import torch
from torch import nn
import torch.nn.functional as F

Xt = torch.from_numpy(X_train).float()
yt = torch.from_numpy(y_train).float()
print(Xt.shape, yt.shape)

linear = nn.Linear(2, 1)
h = linear(Xt)
s = F.sigmoid(h)
loss = nn.CrossEntropyLoss()
Xt

loss(Xt, yt)
# Out:
# torch.Size([4142, 2]) torch.Size([4142, 1])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[552], line 15
#      12 loss = nn.CrossEntropyLoss()
#      13 Xt
# ---> 15 loss(Xt, yt)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/loss.py:1188, in CrossEntropyLoss.forward(self, input, target)
#    1187 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# -> 1188     return F.cross_entropy(input, target, weight=self.weight,
#    1189                            ignore_index=self.ignore_index, reduction=self.reduction,
#    1190                            label_smoothing=self.label_smoothing)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/functional.py:3104, in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction, label_smoothing)
#    3102 if size_average is not None or reduce is not None:
#    3103     reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3104 return torch._C._nn.cross_entropy_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index, label_smoothing)
#
# RuntimeError: 0D or 1D target tensor expected, multi-target not supported
