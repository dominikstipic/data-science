# %% [markdown]
# # Analysis of the next browsing topic

# %%
import sqlite3
import pandas as pd
import argparse
from datetime import datetime, timedelta

def parse_args():
    parser = argparse.ArgumentParser(description="Path to the history file")
    parser.add_argument("--path", default="/home/doms/snap/firefox/common/.mozilla/firefox/g93bal4w.default", type=str, help="Path to the history file")
    args = parser.parse_args()
    return args.__dict__ 

def process(path: str) -> pd.DataFrame:
    SQL = """select origin, last_access_time from origin"""
    con = sqlite3.connect(f"{path}/storage.sqlite")
    cur = con.cursor()
    result = cur.execute(SQL)
    df = pd.DataFrame([], columns=["url", "last_visit_time"])
    for row in result.fetchall():
        d = dict(list(zip(df.columns, row)))
        d = {k: [v] for k,v in d.items()}
        df_new = pd.DataFrame(d, columns=df.columns)
        df = pd.concat([df, df_new])
    df = df.reset_index()[["url", "last_visit_time"]]
    df = df.sort_values("last_visit_time", ascending=False)
    df["last_visit_time"] = df["last_visit_time"].apply(lambda d: datetime(1970, 1, 1, 2, 0, 0) + timedelta(microseconds = d))
    return df 

df = process("/home/doms/snap/firefox/common/.mozilla/firefox/g93bal4w.default")
df
# Out:
#                                                     url  \
# 93                            https://www.perplexity.ai
# 519                              https://www.google.com
# 624                        https://www.shutterstock.com
# 549                           https://www.dataexpert.io
# 220   moz-extension://edabc34d-306d-43f9-988e-73a81f...
# ...                                                 ...
# 718                           https://www.legalzoom.com
# 1318                       https://accounts.firefox.com
# 985                 https://www.netherlandsworldwide.nl
# 611   https://www.google.com^partitionKey=%28https%2...
# 152                                  https://y2meta.app
#
#                 last_visit_time
# 93   2024-10-17 14:21:26.630065
# 519  2024-10-17 14:21:26.626737
# 624  2024-10-17 14:21:26.623520
# 549  2024-10-17 14:21:26.620636
# 220  2024-10-17 14:21:26.607129
# ...                         ...
# 718  2024-08-12 19:08:01.919563
# 1318 2024-08-12 18:12:09.746082
# 985  2024-08-12 18:11:14.715288
# 611  2024-08-12 15:27:56.905986
# 152  2024-08-11 22:41:39.336188
#
# [2105 rows x 2 columns]

# %%
from datetime import datetime, timedelta
import requests
from bs4 import BeautifulSoup
import langdetect


def extract_desc(link):
    try:
        html = requests.get(link).text
        soup = BeautifulSoup(html, 'html.parser')
        metas = soup.find_all("meta")
        content = None
        for meta in metas:
            if meta.attrs.get("name") == "description":
                content = meta.attrs["content"]
    except Exception:
        return None
    return content

def get_lang(sentence):
    try:
        if sentence == None:
            return None
        ds = langdetect.detect_langs(sentence)
        M, arg_max = 0, -1
        for i, d in enumerate(ds):
            if d.prob > M:
                M = d.prob
                arg_max = i
        return ds[arg_max].lang
    except Exception:
        return None 

sample = df.iloc[0:20]
sample.apply(lambda r : extract_desc(r))
sample["desc"] = sample["url"].apply(extract_desc)
sample["lang"] = sample["desc"].apply(get_lang)
sample
# Out:
# /tmp/ipykernel_22853/3021669048.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample["desc"] = sample["url"].apply(extract_desc)
# /tmp/ipykernel_22853/3021669048.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample["lang"] = sample["desc"].apply(get_lang)
#                                                     url  \
# 93                            https://www.perplexity.ai
# 519                              https://www.google.com
# 624                        https://www.shutterstock.com
# 549                           https://www.dataexpert.io
# 220   moz-extension://edabc34d-306d-43f9-988e-73a81f...
# 390   moz-extension://edabc34d-306d-43f9-988e-73a81f...
# 511                         https://accounts.google.com
# 69                             https://www.whatsapp.com
# 1993                          https://stackoverflow.com
# 1749                            https://www.njuskalo.hr
# 526                             https://mail.google.com
# 783                             https://www.youtube.com
# 1016                                      https://x.com
# 523                             https://chat.google.com
# 516                             https://meet.google.com
# 1504                           https://www.linkedin.com
# 586                                 https://www.wsj.com
# 1863  https://www.youtube.com^partitionKey=%28https%...
# 521                         https://calendar.google.com
# 334                              https://www.amazon.com
#
#                 last_visit_time  lang  \
# 93   2024-10-17 14:21:26.630065  None
# 519  2024-10-17 14:21:26.626737  None
# 624  2024-10-17 14:21:26.623520    en
# 549  2024-10-17 14:21:26.620636    en
# 220  2024-10-17 14:21:26.607129  None
# 390  2024-10-17 14:21:26.606137  None
# 511  2024-10-17 14:21:26.500744  None
# 69   2024-10-17 14:15:48.421649    en
# 1993 2024-10-17 14:15:34.991592    en
# 1749 2024-10-17 14:13:25.443272    hr
# 526  2024-10-17 13:58:25.699118    en
# 783  2024-10-17 13:58:25.698603    hr
# 1016 2024-10-17 13:58:25.698525  None
# 523  2024-10-17 13:58:25.693863    en
# 516  2024-10-17 13:58:25.646064    en
# 1504 2024-10-17 13:58:25.645881    en
# 586  2024-10-17 13:58:25.644989    en
# 1863 2024-10-17 13:58:25.644155  None
# 521  2024-10-17 13:58:25.614780    en
# 334  2024-10-17 13:58:25.589364  None
#
#                                                    desc
# 93                                                 None
# 519                                                None
# 624   Download the best royalty free images from Shu...
# 549   Join the ultimate data engineering academy to ...
# 220                                                None
# 390                                                None
# 511
# 69    Use WhatsApp Messenger to stay in touch with f...
# 1993  Stack Overflow is the largest, most trusted on...
# 1749  Oglasnik sa više od 500.000 posjeta dnevno i v...
# 526   Gmail is email that’s intuitive, efficient, an...
# 783   Uživajte u videozapisima i glazbi koja vam se ...
# 1016                                               None
# 523   Sign in to Google Chat and access powerful gro...
# 516   Real-time meetings by Google. Using your brows...
# 1504  1 billion members | Manage your professional i...
# 586         We can’t find the page you are looking for.
# 1863                                               None
# 521   Learn how Google Calendar helps you stay on to...
# 334                                                None

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[182], line 1
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
desc = sample.apply(lambda x : extract_desc(x))

# %%
desc.apply(lambda s : get_lang(s))
# Out:
# ---------------------------------------------------------------------------
# LangDetectException                       Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 desc.apply(lambda s : get_lang(s))
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[160], line 1, in <lambda>(s)
# ----> 1 desc.apply(lambda s : get_lang(s))
#
# Cell In[159], line 23, in get_lang(sentence)
#      21 if sentence == None:
#      22     return None
# ---> 23 ds = detect_langs(sentence)
#      24 M, arg_max = 0, -1
#      25 for i, d in enumerate(ds):
#
# File ~/miniconda3/lib/python3.12/site-packages/langdetect/detector_factory.py:137, in detect_langs(text)
#     135 detector = _factory.create()
#     136 detector.append(text)
# --> 137 return detector.get_probabilities()
#
# File ~/miniconda3/lib/python3.12/site-packages/langdetect/detector.py:143, in Detector.get_probabilities(self)
#     141 def get_probabilities(self):
#     142     if self.langprob is None:
# --> 143         self._detect_block()
#     144     return self._sort_probability(self.langprob)
#
# File ~/miniconda3/lib/python3.12/site-packages/langdetect/detector.py:150, in Detector._detect_block(self)
#     148 ngrams = self._extract_ngrams()
#     149 if not ngrams:
# --> 150     raise LangDetectException(ErrorCode.CantDetectError, 'No features in text.')
#     152 self.langprob = [0.0] * len(self.langlist)
#     154 self.random.seed(self.seed)
#
# LangDetectException: No features in text.

# %%
# Out:
# [en:0.999997159440808]
