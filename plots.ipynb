# %%
import random
import matplotlib.pyplot as plt
random_numbers = [random.randint(0, 100) for _ in range(100)]
print(random_numbers)
# Out:
# [55, 75, 64, 35, 48, 53, 80, 100, 5, 31, 18, 93, 39, 46, 58, 93, 48, 36, 97, 4, 39, 53, 27, 19, 74, 90, 90, 28, 59, 55, 91, 0, 97, 29, 61, 10, 78, 69, 93, 64, 17, 53, 21, 29, 36, 20, 84, 6, 31, 1, 62, 81, 12, 70, 16, 100, 29, 49, 51, 74, 55, 88, 51, 77, 73, 12, 20, 1, 58, 48, 23, 79, 62, 17, 27, 27, 39, 71, 26, 62, 100, 25, 64, 4, 1, 92, 51, 81, 74, 1, 80, 1, 80, 75, 99, 6, 79, 46, 3, 41]

# %%
#plt.hist(random_numbers)

plt.boxplot(random_numbers)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x74bf5ec745c0>,
#   <matplotlib.lines.Line2D at 0x74bf5ec742f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x74bf5ec77500>,
#   <matplotlib.lines.Line2D at 0x74bf5ec778c0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x74bf5ec74770>],
#  'medians': [<matplotlib.lines.Line2D at 0x74bf5ec76300>],
#  'fliers': [<matplotlib.lines.Line2D at 0x74bf5ec75430>],
#  'means': []}

# %%
import numpy as np

# Parameters for the first normal distribution
mean1 = 20
std_dev1 = 5
size1 = 500

mean2 = 70
std_dev2 = 10
size2 = 1000

data1 = np.random.normal(loc=mean1, scale=std_dev1, size=size1)
data2 = np.random.normal(loc=mean2, scale=std_dev2, size=size2)
bimodal_data = np.concatenate([data1, data2])
print(bimodal_data)
# Out:
# [20.81887303 17.97261734 32.98134541 ... 57.86121114 78.82439677
#  64.68030747]

# %%
plt.hist(bimodal_data)
# Out:
# (array([ 63., 326., 110.,   6.,  38., 199., 363., 297.,  83.,  15.]),
#  array([  5.29353028,  14.89249549,  24.4914607 ,  34.09042591,
#          43.68939113,  53.28835634,  62.88732155,  72.48628676,
#          82.08525197,  91.68421718, 101.28318239]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(bimodal_data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x74bf5e967770>,
#   <matplotlib.lines.Line2D at 0x74bf5e967a70>],
#  'caps': [<matplotlib.lines.Line2D at 0x74bf5e967da0>,
#   <matplotlib.lines.Line2D at 0x74bf5e9680e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x74bf5e965610>],
#  'medians': [<matplotlib.lines.Line2D at 0x74bf5e9683b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x74bf5e968680>],
#  'means': []}
