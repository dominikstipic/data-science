# %%
from bs4 import BeautifulSoup

with open("a.html") as fp:
    text = fp.readlines()
text = "\n".join(text)

bs = BeautifulSoup(text)
scripts = bs.find_all("script")

for s in scripts:
    print(s["src"])
# Out:
# Hrvatski%20zavod%20za%20zapo%C5%A1ljavanje%20-%20Burza%20rada%20-%20Radna%20mjesta_files/js_004
# Hrvatski%20zavod%20za%20zapo%C5%A1ljavanje%20-%20Burza%20rada%20-%20Radna%20mjesta_files/destination
# Hrvatski%20zavod%20za%20zapo%C5%A1ljavanje%20-%20Burza%20rada%20-%20Radna%20mjesta_files/analytics.js
# Hrvatski%20zavod%20za%20zapo%C5%A1ljavanje%20-%20Burza%20rada%20-%20Radna%20mjesta_files/1639849129377256.js
# Hrvatski%20zavod%20za%20zapo%C5%A1ljavanje%20-%20Burza%20rada%20-%20Radna%20mjesta_files/1117865981678274.js
# Hrvatski%20zavod%20za%20zapo%C5%A1ljavanje%20-%20Burza%20rada%20-%20Radna%20mjesta_files/fbevents.js
# Hrvatski%20zavod%20za%20zapo%C5%A1ljavanje%20-%20Burza%20rada%20-%20Radna%20mjesta_files/js_002
# Hrvatski%20zavod%20za%20zapo%C5%A1ljavanje%20-%20Burza%20rada%20-%20Radna%20mjesta_files/js
# Hrvatski%20zavod%20za%20zapo%C5%A1ljavanje%20-%20Burza%20rada%20-%20Radna%20mjesta_files/zaglavlje.js
# ...

# %%
from bs4 import BeautifulSoup
import requests

html = requests.get("https://burzarada.hzz.hr/Posloprimac_RadnaMjesta.aspx")
text = html.text

bs = BeautifulSoup(text, "html.parser")

def children(xs):
    xs = list(bs.children)
    xs = [x for x in xs if x != "\n"]
    return xs


for child in bs.body:
    print(child)


#text = "\n".join(text)


#bs = BeautifulSoup(text)
#scripts = bs.find_all("script")

#for s in scripts:
    #print(s["src"])
# Out:
#  Google Tag Manager (noscript)
#
#
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5JMWVTX" style="display: none; visibility: hidden" width="0"></iframe>
# </noscript>
#
#
#  End Google Tag Manager (noscript)
#
#
#  Google Tag Manager (noscript)
#
#
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WTQDQ8L" style="display: none; visibility: hidden" width="0"></iframe>
# </noscript>
#
#
#  End Google Tag Manager (noscript)
#
#
# <form action="./Posloprimac_RadnaMjesta.aspx?AspxAutoDetectCookieSupport=1" autocomplete="off" id="aspnetForm" method="post" name="aspnetForm">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
# <script src="/WebResource.axd?d=yoO3yeJFJkKB9eCPrjd7AAqVMtNt9Pb87hxknhZ9scFkjfMvw3FOr85AJrDMcN1nD5536kaxsvo7SWUN9R92YlkYJfJq1_YlXIArQx_BhtYOmyT4HorzHQziHk2adnTTIy13Ag2&amp;t=634020902747188492" type="text/javascript"></script>
# ...

# %%
from bs4 import BeautifulSoup
import requests

with open("a.html") as fp:
    text = fp.readlines()
    text = "".join(text)

html = requests.get("https://burzarada.hzz.hr/Posloprimac_RadnaMjesta.aspx")
text = html.text

bs = BeautifulSoup(text, "html.parser")
bs
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head id="ctl00_Head1"><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->
# <meta machinename="PR-WEB02" userhostaddress="31.217.55.2"/><meta name="description"/><meta name="author"/>
# <!-- Google Tag Manager -->
# <meta content="677204172473486" property="fb:app_id"/><link href="/favicon.ico" rel="icon"/><title>
# 	Hrvatski zavod za zapošljavanje - Burza rada - Radna mjesta
# </title>
# <!-- Sidebar -->
# <link href="/css/sidebar.css" rel="stylesheet"/>
# <!-- Bootstrap core CSS -->
# <link href="/css/bootstrap.css" rel="stylesheet">
# <!-- Bootstrap theme -->
# <link href="/css/theme2.css" rel="stylesheet"/>
# <!-- custom style -->
# <link href="css/master.css?ver=a2e206e6-bba6-47bb-9818-938f0d16cfdd" rel="stylesheet"/>
# ...

# %%
body = bs.body
for line in body.descendants:
    if not line.name :
        continue
    import pdb; pdb.set_trace()
    if len(list(line.descendants)) == 0:
        print(line.name)
# Out:
# iframe
# iframe
# input
# script
# script
# script
# input
# input
# div
# script
# iframe
# iframe
# img
# span
# span
# span
# img
# input
# input
# span
# input
# i
# i
# i
# input
# br
# input
# br
# input
# br
# input
# br
# input
# br
# input
# br
# input
# br
# input
# br
# input
# br
# input
# br
# input
# br
# input
# br
# input
# br
# input
# br
# input
# br
# input
# br
# input
# br
# input
# br
# input
# br
# input
# br
# input
# br
# input
# br
# input
# a
# a
# br
# br
# br
# input
# br
# img
# img
# img
# img
# img
# img
# br
# img
# img
# img
# img
# img
# img
# br
# img
# img
# img
# img
# img
# img
# br
# img
# img
# img
# img
# img
# img
# br
# img
# img
# img
# img
# img
# img
# br
# img
# img
# img
# img
# img
# img
# br
# img
# img
# img
# img
# div
# div
# div
# div
# div
# div
# br
# br
# br
# br
# br
# br
# br
# br
# br
# br
# span
# p
# br
# img
# br
# img
# br
# img
# img
# img
# img
# br
# br
# br
# br
# img
# script
# script
# script

# %% [markdown]
# https://www.artofmanliness.com/character/knowledge-of-men/strauss-howe-generational-cycle-theory/

# %%
from bs4 import BeautifulSoup
import re


with open("language.js") as fp:
    text = fp.readlines()
text = "\n".join(text)

lines = text.split(";")

results = []
for line in lines:
    links = re.findall("http.+ ", line)
    links = [l.strip() for l in links]
    results += links
print( results)
# Out:
# ['https://www.java.com/en/download/manual.jsp"', 'https://www.java.com/en/download/manual.jsp"', 'https://www.java.com/en/download/manual.jsp"']

# %%
# https://time.com/archive/6794406/people-the-younger-generation/

# Magarska
# Out:
#   Cell In[25], line 1
#     https://time.com/archive/6794406/people-the-younger-generation/
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# DFS

# %%
from bs4 import BeautifulSoup, NavigableString
import re
import bs4

with open("a.html") as fp:
    text = fp.readlines()
text = "\n".join(text)

bs = BeautifulSoup(text, "html.parser")
body = bs.body

def children(text):
    chs = list(text.children)
    result = []
    for c in chs:
        if c != "\n":
            result.append(c)
    return result

def email_filter(children):
    pass

cs = children(children(body)[0])
c = children(cs[4])[-2]
c
# Out:
# <a href="https://www.google.com">this link</a>

# %%
type(NavigableString(c.strip()))
# Out:
# bs4.element.NavigableString
