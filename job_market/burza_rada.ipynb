# %%
import requests
from bs4 import BeautifulSoup

def get_occupations():
    pass

html = requests.get("https://burzarada.hzz.hr/Posloprimac_RadnaMjesta.aspx")
text = html.text

bs = BeautifulSoup(text, "html.parser")
trs = bs.find("table", id="ctl00_MainContent_gwSearch")
print(trs)
# Out:
# None

# %%
bs.find("table")
# Out:
# <table class="NKZSkBoxT">
# <tr class="SkupinaBoxHover">
# <td class="NKZSkBoxTD">
# <a class="Kategorije" href="javascript:__doPostBack('ctl00$MainContent$DataList1$ctl00$Skupine$rptSkupine$ctl01$lnkSkupina','')" id="ctl00_MainContent_DataList1_ctl00_Skupine_rptSkupine_ctl01_lnkSkupina"> Razvojni inženjeri i analitičari/razvojne inženjerke i analitičarke za razvoj programske podrške d. n. <span class="badge alert-info">1</span></a>
# </td>
# </tr>
# <tr class="SkupinaBoxHover">
# <td class="NKZSkBoxTD">
# <a class="Kategorije" href="javascript:__doPostBack('ctl00$MainContent$DataList1$ctl00$Skupine$rptSkupine$ctl02$lnkSkupina','')" id="ctl00_MainContent_DataList1_ctl00_Skupine_rptSkupine_ctl02_lnkSkupina">Analitičari/analitičarke sustava <span class="badge alert-info">9</span></a>
# </td>
# </tr>
# <tr class="SkupinaBoxHover">
# <td class="NKZSkBoxTD">
# ...

# %%
url = "https://burzarada.hzz.hr/Posloprimac_RadnaMjesta.aspx?AspxAutoDetectCookieSupport=1"

html = requests.get(url).text
body = BeautifulSoup(html, "html.parser").body

body.find
# Out:
# <span class="sr-only">Toggle navigation</span>
