# %%
from bs4 import BeautifulSoup
import requests

url = "https://jobs.avl.com/?locale=en_US&utm_source=careersite&utm_campaign=avl.com"
headers = {
    "User-Agent": "Mozilla/5.0"
}
out = requests.get(url, headers=headers).text


bs = BeautifulSoup(out)
divs = bs.find_all("thead")
divs[0].tr
# Out:
# <tr>
# <th class="col-sm-2" scope="col">Provider</th>
# <th class="col-sm-9" scope="col">Description</th>
# <th class="col-sm-1" scope="col"><span class="pull-right">Enabled</span></th>
# </tr>
